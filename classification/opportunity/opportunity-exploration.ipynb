# %% [markdown]
# ### High Level Goals:
# 1. **currently**: train a topic model on the opportunity ads, visualize opportunity ads in terms of these topics
# 2. test what a simple classification approach with logistic regression or SVMs would look like for classifying opportunities; treat this as baseline
# 3. finetune a LLM on opportunity ads; does it perform significantly better than the baseline?

# %%
# classification tutorial: https://towardsdatascience.com/text-classification-with-nlp-tf-idf-vs-word2vec-vs-bert-41ff868d1794

# %%
import pandas as pd
import numpy as np
import os

from gensim.corpora.dictionary import Dictionary
from gensim.parsing.preprocessing import preprocess_string
from gensim import models, utils

# %%
coded = pd.read_csv('../data/text_data_annotated.csv')    # total = 32,084
opportunity_ads = coded[coded['opportunity'] == 1]    # opportunity =  2,274

# %% [markdown]
# ### Topic Modeling

# %%
opportunity_texts = opportunity_ads['text'].dropna().tolist()
# tokenize texts
texts_tokenized = [preprocess_string(t) for t in opportunity_texts]
# tokenizing manually
# texts_tokenized = [list(utils.tokenize(t)) for t in opportunity_texts]

# build dictionary of tokens
dict_opportunity = Dictionary(texts_tokenized)
# build BOW mapping of all texts based on dictionary
opportunity_texts_processed = [dict_opportunity.doc2bow(t) for t in texts_tokenized]

# %%
lda = models.ldamodel.LdaModel(opportunity_texts_processed, num_topics=7)

# %%
for i in range(7):
    print(f'=== topic {i} ===')
    terms = lda.get_topic_terms(i)
    for wid, prob in terms:
        print(dict_opportunity.get(wid), wid, prob)
    
    print('\n')
# Out:
# === topic 0 ===
# com 90 0.0249541
# class 213 0.012157648
# job 437 0.011724807
# time 187 0.011613171
# join 142 0.010429956
# free 38 0.008994422
# learn 54 0.00894235
# todai 61 0.008489231
# career 193 0.008040525
# start 112 0.0074167084
#
#
# === topic 1 ===
# com 90 0.024189373
# earn 49 0.02183597
# shasta 4557 0.011172712
# work 19 0.010717492
# want 177 0.009511888
# home 676 0.009353182
# free 38 0.0090760095
# grant 67 0.00901813
# join 142 0.00899255
# card 639 0.0088354
#
#
# === topic 2 ===
# com 90 0.021314884
# earn 49 0.017034918
# free 38 0.01460819
# start 112 0.014286659
# facebook 216 0.014200148
# form 217 0.013351128
# amazon 544 0.012220311
# work 19 0.010913717
# cours 92 0.009985787
# onlin 41 0.009201662
#
#
# === topic 3 ===
# onlin 41 0.027828455
# scholarship 28 0.025577221
# edu 37 0.019441608
# degre 36 0.018807022
# career 193 0.018388389
# learn 54 0.01428539
# cours 92 0.012127982
# com 90 0.010891082
# class 213 0.009719211
# busi 64 0.008813099
#
#
# === topic 4 ===
# com 90 0.030129235
# job 437 0.018829772
# join 142 0.016670017
# career 193 0.015470632
# role 238 0.01267294
# free 38 0.011246984
# data 253 0.01059633
# learn 54 0.010061142
# new 22 0.008555662
# onlin 41 0.00844782
#
#
# === topic 5 ===
# free 38 0.023032451
# com 90 0.018446092
# learn 54 0.01816051
# studi 305 0.014554544
# onlin 41 0.014287659
# start 112 0.01139588
# todai 61 0.009514634
# student 72 0.009451494
# earn 49 0.009067038
# edu 37 0.008795777
#
#
# === topic 6 ===
# onlin 41 0.018211003
# com 90 0.015678251
# cours 92 0.014322563
# drug 1688 0.012954565
# code 695 0.011440164
# amazon 544 0.011223245
# aw 680 0.010796552
# develop 130 0.01055056
# earn 49 0.010175139
# skill 13 0.009493611

# %%
# I believe topic #1 has some lower quality opportunities

for i in range(len(opportunity_texts_processed)):
    topics = lda.get_document_topics(opportunity_texts_processed[i])
    topic_ids = [i for (i, _) in topics]
    if 1 in topic_ids and len(topic_ids) == 1:
        print(opportunity_texts[i])
        print(topics)
        print('\n')
# Out:
# We are hiring for multiple positions and shifts! Check out all of our open jobs and apply: roguefitness.com/jobs
# Maximum Wage: $55/Hour with both Adders*
# Minimum Wage: $23/Hour with both Adders
# [(1, 0.9570161)]
#
#
# g2.com
# G2 wants to hear about your experiences with software at work! https://g2.co/3cYLh4j
# Compare the best business software and services based on user ratings and social data. Reviews for CRM, ERP, HR, CAD, PDM and Marketing software.
# $10 Amazon gift card for your opinion!
# [(1, 0.97132945)]
#
#
# g2.com
# G2 wants to hear about your experiences with software at work! https://g2.co/3xxReyJ
# $10 Starbucks gift card for your opinion!
# Compare the best business software and services based on user ratings and social data. Reviews for CRM, ERP, HR, CAD, PDM and Marketing software.
# [(1, 0.9713335)]
#
#
# g2.com
# Limit 1 reward per user. Gift cards will be sent to your email within 3 business days pending review approval!
# $10 Starbucks gift card for your opinion!
# G2 wants to hear about your experiences with software at work! https://g2.co/2QIgOPW
# [(1, 0.9656046)]
#
#
# Career Advancement & Benefits
# PayPal is Hiring Remote Customer Service Reps
# Get Started Now
# Work From Your Home
# jobsflag.com
# Click Apply for Information
# [(1, 0.9520836)]
#
#
# SAKARA.COM
# No prep or cleaning required
# Your New Year Detox
# Detoxify, energize, and reset with Sakara’s Signature Nutrition Program—chef-crafted, nutritionally-designed meals delivered right to your door.
# [(1, 0.96250767)]
#
#
# Join our community for teachers
# Over 70.000 teachers are taking free certified courses with CanopyLAB.
# Take free certified courses
# TEACHERLAB.CANOPYLAB.COM
# [(1, 0.9461595)]
#
#
# 21-323 | 21-323 - Online Survey Software
# ClearView is looking for vegetarian and vegans to do an online focus group on December 13,14,15 or 16.  It will last 2 hours and you will be paid $200 if you qualify and participate.  Click this link to see if you qualify:https://www.questionpro.com/t/AQbsTZp68r
# [(1, 0.96403843)]
#
#
# Music Teacher PT
# Introduce students to basic musical concepts through playing their instruments, listening, and responding to music with movement.
# Stratford · Part-time
# [(1, 0.94610655)]
#
#
# Research Square’s team of user researchers wants to hear from you.
# Do you want to help make research faster, fairer, and more useful?
# Research Square is looking for Ph.D.’s who want to help move the research publication industry forward.
# Do you have an opinion on the proper use of  “et al.”?
# calendly.com
# [(1, 0.9702881)]
#
#
# Research Square’s team of user researchers wants to hear from you.
# Do you want to help make research faster, fairer, and more useful?
# Research Square is looking for Ph.D.’s who want to help move the research publication industry forward.
# Do you have an opinion on the proper use of  “et al.”?
# calendly.com
# [(1, 0.97028744)]
#
#
# Research Square is looking for PhDs who want to help move the research publication industry forward.
# Research Square’s team of user researchers wants to hear from you.
# Do you want to help make research faster, fairer, and more useful?
# Do you have an opinion on the proper use of  “et al.”?
# calendly.com
# [(1, 0.9712771)]
#
#
# At ACE, we love our jobs, our mission and what we can do together.
# Want to help get young people registered to vote? Get paid $25/hour as an ACE Field Canvasser.
# go.acespace.org
# Now Hiring: Field Canvassers
# [(1, 0.9590388)]
#
#
# At ACE, we love our jobs, our mission and what we can do together.
# Want to help get young people registered to vote? Get paid $25/hour as an ACE Field Canvasser.
# go.acespace.org
# Now Hiring: Field Canvassers
# [(1, 0.9590459)]
#
#
# At ACE, we love our jobs, our mission and what we can do together.
# Want to help get young people registered to vote? Get paid $25/hour as an ACE Field Canvasser.
# go.acespace.org
# Now Hiring: Field Canvassers
# [(1, 0.95904)]
#
#
# Earn a $10 Amazon gift card for your first review on any software you use #reviews #review #reviewer #feedback #softwarereview #amazon #software #capterra
# capterra.com
# Get rewarded for your first published review.
# 5 minutes = $10 Gift Card
# [(1, 0.96421015)]
#
#
# Earn a $10 Amazon gift card for your first review on any software you use #reviews #review #reviewer #feedback #softwarereview #amazon #software #capterra
# capterra.com
# Get rewarded for your first published review.
# 5 minutes = $10 Gift Card
# [(1, 0.96420884)]
#
#
# Earn a $10 Amazon gift card for your first review on any software you use.
# capterra.com
# Get rewarded for your first published review.
# 5 minutes = $10 Gift Card
# [(1, 0.9463179)]
#
#
# Earn a $10 Amazon gift card for your first review on any software you use #reviews #review #reviewer #feedback #softwarereview #amazon #software #capterra
# Get rewarded for your first published review on GetApp.
# 5 minutes = $10 Gift Card
# getapp.com
# [(1, 0.9656423)]
#
#
# Use software? Earn a $10 gift card for your first review of any product.
# Get rewarded for your first published review on GetApp.
# 5 minutes = $10 Gift Card
# getapp.com
# [(1, 0.9494589)]
#
#
# This is a nationwide study for people who own a Mazda CX-5. It consists of a 2-hour webcam interview taking place throughout the entire month of December. All participants will receive $125!
# If interested please fill in the questionnaire below.… See more
# $125 for your time! 2017 or newer Mazda CX-5!
# [(1, 0.9589208)]
#
#
# Feeling Lucky?
# PCH.com/SWEEPSTAKES
# $5,000.00 A Week “Forever”could get you the keys to the houseof your dreams! Want to WIN? Enter Now!
# Lights on – you home…??
# [(1, 0.94610256)]
#
#
# Anaheim, CA ~ Orange County residents aged 18 and older are needed for a 2-day opinion study being held on Wednesday, December 1 & Thursday, December 2 in Anaheim. The group runs from 9am-5pm on Wednesday and 9am – 3pm on Thursday. Continental breakfast, deli lunch and refreshments provided. To thank you for your time, you will receive an incentive of $400 for participating. The research will involve listening to a presentation, filling out questionnaires (reading & writing) … See more
# [(1, 0.9784675)]
#
#
# Product Testers Needed | Make $11-$27/Hour This Fall
# So… I'm getting paid and getting new clothes?! Fall wardrobe here I come
# WWW.FINDDREAMJOBS.COM
# [(1, 0.9521366)]
#
#
# harvardx-onlinecourses.getsmarter.com
# Realize the potential of gene-editing and CRISPR when fighting disease, optimizing food microbes, and innovating biofuel.
# Online CRISPR course
# Study gene-editing
# [(1, 0.96250516)]
#
#
# pathrise.com
# Get A New Job Faster & Earn More
# We are entering the most talent friendly hiring economy in years. Work with the experts at Pathrise to achieve the best personal outcome.
# [(1, 0.9570131)]
#
#
# Oculus Quest Research
# Oculus Quest users can earn an Amazon gift card for participating in this important user experience study!
# Oculus Quest users can earn an Amazon gift card for participating in this user experience study!
# surveys.clearvoicemetrics.com
# [(1, 0.9713001)]
#
#
# Join the Community
# Put your opinions and feedback to work and be rewarded in the process. Voicepark makes finding companies to review easier and more lucrative than ever before. #UseYourVoice
# The more you participate in our online discussions, the more points you will earn. Points translate directly into gift cards, with the potential to earn $15-$50 per activity.
# learn-more.voicepark.com
# [(1, 0.9731249)]
#
#
# The more you participate in our online discussions, the more points you will earn. Points translate directly into gift cards, with the potential to earn $15-$50 per activity.
# If you need extra for the holidays, join the Voicepark Community. Put your opinions and feedback to work and be rewarded in the process.
# Earn More For The Holiday
# learn-more.voicepark.com
# [(1, 0.9713124)]
#
#
# Join the Community
# The more you participate in our online discussions, the more points you will earn. Points translate directly into gift cards, with the potential to earn $15-$50 per activity.
# learn-more.voicepark.com
# [(1, 0.95475227)]
#
#
# Earn Extra Money as a Mystery Shopper
# We are a BBB-rated mystery shopping company that has been in business for 25+ years.
# A-Closer-Look.com
# [(1, 0.94631034)]
#
#
# JOB OPENINGS AVAILABLE FOR IMMEDIATE HIRE IN YOUR CITY Warehouse, Stocker & More! $17-37/HR (benefits included)
# Hiring Immediately. No experience needed. New Hire Bonus
# jubilee.news
# [(1, 0.9570064)]
#
#
# Monetize your opinion! Eat. Survey. Get Reimbursed. Repeat. Over USD 1,000,000 reimbursed in cash-back (up to 100% of your meal).
# Monetize your opinion! Your next order could be on us! Check our www.freatz.com to learn how it works.
# Freatz - Eat. Survey. Get Reimbursed. Repeat.
# [(1, 0.9656204)]
#
#
# GUMMYPROFESSIONAL.COM
# #gummyprofessional #barber #barbershop #barberlife #haircut #fade #hair #beard #moustache #barbers #hairstyle #cologne
# Gummy
# That’s the refreshness that we are talking about! WOW!
# [(1, 0.95681196)]
#
#
# www.JobsOnDemand.com
# I don't know about you… but I'm feeling a new job in 2022
# Work From Home Jobs | Now Hiring | Make $21-$41/Hour This Winter
# [(1, 0.9426537)]
# arcadia.edu
# Arcadia University’s hybrid Doctor of Physical Therapy (DPT) program prepares aspiring physical therapists to become the next generation of innovative, patient-centered practitioners.
# Hybrid DPT from Arcadia: A Top-25 PT School
# Earn your hybrid DPT from Arcadia in 25 months. Participate in 32 weeks of clinical experience. GRE req’d.
# [(1, 0.97538906)]
#
#
# Earn Your Hybrid DPT from Arcadia. GRE req’d.
# Learn from Arcadia’s expert DPT faculty in a hybrid, online program. Complete in 25 months.
# arcadia.edu
# Arcadia University’s hybrid Doctor of Physical Therapy (DPT) program prepares aspiring physical therapists to become the next generation of innovative, patient-centered practitioners.
# [(1, 0.97609586)]
#
#
# wp.wpi.edu/touchtomorrow/register
# Don’t miss it!
# Free STEM festival for all ages
# Join us April 2 for a day full of free STEM activities.
# [(1, 0.9492364)]
#
#
# pathrise.com
# Get A New Job Faster & Earn More
# We are entering the most talent friendly hiring economy in years. Work with the experts at Pathrise to achieve the best personal outcome.
# [(1, 0.95701253)]
#
#
# Register here: https://cutt.ly/grantcoord
# Solve Education! seeks student leaders who are able to coordinate and establish the Social Grant Program on their campuses.
# [(1, 0.9491676)]
#
#
# Kabbalah 1 is an hour-long, weekly online course, designed to help you answer your big life questions through community support, discussion groups, and personal application of Kabbalah’s foundational spiritual tools guided by teachers and mentors. Join a community of students in pursuit of their next level, and take the next step towards finding yours.
# KABBALAH.COM
# [(1, 0.9754266)]
#
#
# www.appen.com/shasta
# Join Project Shasta
# Tired of doing the same thing all day? Work on a variety of tasks with Project Shasta.
# Become a map search evaluator
# [(1, 0.9548157)]
#
#
# www.appen.com/shasta
# Work from home at your own pace, and take a break whenever you want with Project Shasta.
# Become a map search evaluator
# Join Project Shasta
# [(1, 0.9523171)]
#
#
# Kabbalah 1 is an hour-long, weekly online course, designed to help you answer your big life questions through community support, discussion groups, and personal application of Kabbalah’s foundational spiritual tools guided by teachers and mentors. Join a community of students in pursuit of their next level, and take the next step towards finding yours.
# KABBALAH.COM
# [(1, 0.9754276)]
#
#
# www.appen.com/shasta
# Dynamic work opportunities
# Become a map search evaluator
# Future-proof yourself. Build a foundation in machine learning and AI with Project Shasta.
# [(1, 0.9546897)]
#
#
# app-work.org
# No test assignments or checks.
# Register and take any task you want!
# Join a unique platform.
# 1-2 hours on average per assignment
# No special skills required!
# [(1, 0.95477754)]
#
#
# Earn a little extra cash and spoil yourself or your partner with Project Shasta.
# www.appen.com/shasta
# Join Project Shasta
# Become a map search evaluator
# [(1, 0.9545779)]
#
#
# 16 + years old
# jobs.cedarfair.com
# We’re not just looking for self-starters, we’re looking for funstarters! Valleyfair is hiring, positions earning up to $17/hr.
# Valleyfair is Hiring
# [(1, 0.95473206)]

# %% [markdown]
# ### Simplistic Classification

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, confusion_matrix, precision_score, recall_score

vectorizer = TfidfVectorizer()

# %%
nas = coded['text'].isna()
all_texts = coded[~nas]['text'].tolist()
all_texts_tfidf = vectorizer.fit_transform(all_texts)
opportunity_labels = np.array(coded[~nas]['opportunity'])

# split into train, val, test
X_train, X_test, y_train, y_test = train_test_split(all_texts_tfidf, opportunity_labels, test_size=0.33)

# %%
# fit logistic regression
logit_model = LogisticRegression()
logit_model.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
# test classification
test_preds = logit_model.predict(X_test)
print('Accuracy:', accuracy_score(y_test, test_preds))
print('Precision:', precision_score(y_test, test_preds))
print('Recall:', recall_score(y_test, test_preds))

print('\nConfusion Matrix:\n', confusion_matrix(y_test, test_preds, normalize='true'))
# Out:
# Accuracy: 0.9545324835917436
# Precision: 0.8809523809523809
# Recall: 0.36894586894586895
#
# Confusion Matrix:
#  [[0.99643258 0.00356742]
#  [0.63105413 0.36894587]]

# %%
# TODO: unpack accuracy, is this high due to data imbalance?
# the model could just be saying no?

# aha yes, it's a pretty low recall model
# Out:
# 319
