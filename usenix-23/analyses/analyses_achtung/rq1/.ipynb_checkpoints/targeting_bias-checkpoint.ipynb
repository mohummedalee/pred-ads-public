# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from collections import defaultdict, Counter
# %matplotlib inline

plt.rcParams['font.family'] = 'Helvetica'

# %%
import os
# !pwd
# Out:
# /home/ali/pred-ads/analyses/rq1

# %%
codes_file = '../data/ad_codes.tsv'
codes = pd.read_csv(codes_file, sep='\t')
adid_codes = dict(zip(codes['adid'], [r.split(';') for r in codes['codes']]))

# %%
targeting_params = pd.read_csv('/home/piotr/targeting_params.csv', low_memory=False)

# %%
targeting_params
# Out:
#                     adid  age_min  age_max  gender  \
# 0      23849001865970603     18.0     48.0     NaN
# 1      23848595585360569     24.0     52.0     NaN
# 2          6273318007601      NaN      NaN     NaN
# 3          6240889607481      NaN      NaN     NaN
# 4          6228753841633     14.0     52.0     NaN
# ...                  ...      ...      ...     ...
# 88504  23852360365710287      NaN      NaN     NaN
# 88505  23851682175480543      NaN      NaN     NaN
# 88506  23850350071350620     10.0     38.0     NaN
# 88507      6296277221165      NaN      NaN     NaN
# 88508  23849548017210198      NaN      NaN     NaN
#
#                                                 location  \
# 0                                                    NaN
# 1      {'serialized': {'location_granularity': 'city'...
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 88504                                                NaN
# 88505  {'serialized': {'location_granularity': 'count...
# 88506                                                NaN
# 88507                                                NaN
# 88508  {'serialized': {'location_granularity': 'city'...
#
#                                     WAISTUIInterestsType  \
# 0      {'interest_ids': [6003109292833, 6003221485467...
# 1                                                    NaN
# 2      {'interest_ids': [6003109292833, 6003221485467...
# 3                                                    NaN
# 4      {'interest_ids': [6003111829635, 6003117588868...
# ...                                                  ...
# 88504                                                NaN
# 88505  {'interest_ids': [6002936693259, 6003108268433...
# 88506  {'interest_ids': [6004160395895, 6002985584323...
# 88507                                                NaN
# 88508                                                NaN
#
#           WAISTUILocaleType  estimate_mau  \
# 0      {'locales': [24, 6]}    65300000.0
# 1                       NaN           NaN
# 2      {'locales': [24, 6]}   144200000.0
# 3                       NaN   256700000.0
# 4          {'locales': [6]}     9500000.0
# ...                     ...           ...
# 88504                   NaN   256700000.0
# 88505                   NaN    20200000.0
# 88506                   NaN   132200000.0
# 88507                   NaN   256700000.0
# 88508                   NaN      299500.0
#
#                           WAISTUICustomAudienceType WAISTUIBCTType  ...  \
# 0                                               NaN            NaN  ...
# 1      {'ca_type': 4, 'ca_fbid': 23848465134600569}            NaN  ...
# 2                                               NaN            NaN  ...
# 3                                               NaN            NaN  ...
# 4                                               NaN            NaN  ...
# ...                                             ...            ...  ...
# 88504                                           NaN            NaN  ...
# 88505                                           NaN            NaN  ...
# 88506                                           NaN            NaN  ...
# 88507                                           NaN            NaN  ...
# 88508                                           NaN            NaN  ...
#
#       WAISTUIDPAType WAISTUIActionableInsightsType  \
# 0                NaN                           NaN
# 1                NaN                           NaN
# 2                NaN                           NaN
# 3                NaN                           NaN
# 4                NaN                           NaN
# ...              ...                           ...
# 88504            NaN                           NaN
# 88505            NaN                           NaN
# 88506            NaN                           NaN
# 88507            NaN                           NaN
# 88508            NaN                           NaN
#
#       WAISTUIFriendsOfConnectionType WAISTUIRelationshipType  \
# 0                                NaN                     NaN
# 1                                NaN                     NaN
# 2                                NaN                     NaN
# 3                                NaN                     NaN
# 4                                NaN                     NaN
# ...                              ...                     ...
# 88504                            NaN                     NaN
# 88505                            NaN                     NaN
# 88506                            NaN                     NaN
# 88507                            NaN                     NaN
# 88508                            NaN                     NaN
#
#       WAISTUIWorkEmployerType WAISTUILocalReachType WAISTUIEduSchoolsType  \
# 0                         NaN                   NaN                   NaN
# 1                         NaN                   NaN                   NaN
# 2                         NaN                   NaN                   NaN
# 3                         NaN                   NaN                   NaN
# 4                         NaN                   NaN                   NaN
# ...                       ...                   ...                   ...
# 88504                     NaN                   NaN                   NaN
# 88505                     NaN                   NaN                   NaN
# 88506                     NaN                   NaN                   NaN
# 88507                     NaN                   NaN                   NaN
# 88508                     NaN                   NaN                   NaN
#
#       WAISTUIConnectionType WAISTUICollaborativeAdsStoreVisitsType  \
# 0                       NaN                                    NaN
# 1                       NaN                                    NaN
# 2                       NaN                                    NaN
# 3                       NaN                                    NaN
# 4                       NaN                                    NaN
# ...                     ...                                    ...
# 88504                   NaN                                    NaN
# 88505                   NaN                                    NaN
# 88506                   NaN                                    NaN
# 88507                   NaN                                    NaN
# 88508                   NaN                                    NaN
#
#       WAISTUIJobTitleType
# 0                     NaN
# 1                     NaN
# 2                     NaN
# 3                     NaN
# 4                     NaN
# ...                   ...
# 88504                 NaN
# 88505                 NaN
# 88506                 NaN
# 88507                 NaN
# 88508                 NaN
#
# [88509 rows x 21 columns]

# %%
maus = {row['adid']: row['estimate_mau'] for idx, row in targeting_params.iterrows()}

# %%
data = []
for adid, adcodes in adid_codes.items():
    row = {code: 1 for code in adcodes}
    row['adid'] = adid
    try:
        row['estimate_mau'] = maus[adid]
    except:
        row['estimate_mau'] = float('nan')
    data.append(row)

# %%
data = pd.DataFrame(data)

# %%
def ecdf(a):
    x, counts = np.unique(a, return_counts=True)
    cusum = np.cumsum(counts)
    return x, cusum / cusum[-1]

for column in data.columns[:9]:
    if column == 'estimate_mau':
        continue
    a = np.sort(data.loc[(data[column]==1) & (data['estimate_mau'] >= 0), 'estimate_mau'])
    x, y = ecdf(a)
    
    plt.plot(x, y, label=column)
plt.legend()

plt.ylabel('fraction of ads')
plt.xlabel('targeted audience size')
#plt.xscale('log')
plt.xlim(1e3, 0.3e8)
    #plt.title(column)
    #plt.show()
# Out:
# (1000.0, 30000000.0)

# %%
# now let's find out what interests are the most popular in each category

# %%
import json
interests = json.loads(open('/home/piotr/interest_lookup.json').read())

# %%
from collections import defaultdict
use_counts = defaultdict(lambda: defaultdict(int))
import ast

totals = {code: data[code].sum() for code in data.columns}

for idx, row in targeting_params.iterrows():
    try:
        codes = adid_codes[row['adid']]
    except:
        continue
        
    if row['WAISTUIInterestsType'] is not None and type(row['WAISTUIInterestsType'])==str:
        for interest_id in ast.literal_eval(row['WAISTUIInterestsType'])['interest_ids']:
            for code in codes:
                try:
                    use_counts[code][interests[str(interest_id)]] += 1/totals[code]
                except:
                    continue
    else:
        for code in codes:
            use_counts[code]['None'] += 1/totals[code]

# %%
use_counts.keys()
# Out:
# dict_keys(['Benign', 'Opportunity', 'Healthcare', 'Clickbait', 'Study', 'Financial', 'Sensitive', 'CA Lawsuit', 'Political', 'Potentially Prohibited', 'Potentially Harmful', "Can't determine, return to this one", 'UNCAT'])

# %%
from operator import itemgetter
for code in use_counts:
    items = sorted(use_counts[code].items(), key=itemgetter(1), reverse=True)
    print(code)
    print(items[:10])
    print()
# Out:
# Benign
# [('None', 0.7270378200611517), ('Online shopping', 0.0124970636598544), ('Health & wellness', 0.007892882311486979), ('Family', 0.006530420483908865), ('Physical fitness', 0.006530420483908865), ('Entertainment', 0.006389476156918025), ('Yoga', 0.006154568945266626), ('Dogs', 0.005966643175945507), ('Physical exercise', 0.0058726802912849475), ('Coupons', 0.004886070002349072)]
#
# Opportunity
# [('None', 0.6895338610378036), ('Higher education', 0.024626209322779216), ('Employment', 0.024626209322779216), ('Education', 0.023306948109058902), ('Technology', 0.016270888302550558), ('Career', 0.014511873350923472), ('Psychology', 0.013192612137203158), ('Job hunting', 0.012313104661389615), ('Personal development', 0.011873350923482844), ('Digital marketing', 0.011433597185576072)]
#
# Healthcare
# [('None', 0.7705355441204625), ('Health & wellness', 0.023632551934438712), ('Clinical trial', 0.021536115875738504), ('Physical fitness', 0.016580903373356194), ('Physical exercise', 0.014675052410901458), ('Medicine', 0.009529254812273675), ('Health care', 0.009338669716028201), ('Beauty', 0.00819515913855536), ('Healthy diet', 0.007813988946064413), ('Skin care', 0.00705164856108252)]
#
# Clickbait
# [('None', 0.808922558922574), ('Online shopping', 0.011784511784511781), ('Personal finance', 0.009259259259259257), ('Amazon.com', 0.008417508417508416), ('Home improvement', 0.007575757575757574), ('Business', 0.006734006734006733), ('Investment', 0.006734006734006733), ('Advertising', 0.0058922558922558915), ('Bitcoin', 0.00505050505050505), ('Technology', 0.00505050505050505)]
#
# Study
# [('None', 0.7193347193346902), ('Clinical trial', 0.03700623700623701), ('Health & wellness', 0.01995841995841996), ('Physical fitness', 0.014553014553014554), ('Medical research', 0.014137214137214138), ('Research', 0.012058212058212059), ('Parenting', 0.010395010395010396), ('Medicine', 0.009563409563409564), ('Physical exercise', 0.009147609147609148), ('Clinical research', 0.009147609147609148)]
#
# Financial
# [('None', 0.7654836464857248), ('Personal finance', 0.04801670146137784), ('Investment', 0.03201113430758524), ('Online banking', 0.02853166318719554), ('Credit cards', 0.02644398051496172), ('Financial services', 0.01809324982602645), ('Finance', 0.015309672929714692), ('Banking', 0.012526096033402928), ('Bitcoin', 0.011830201809324987), ('Investor', 0.010438413361169106)]
#
# Sensitive
# [('None', 0.7542242703533039), ('Gambling', 0.029185867895545305), ('Alcoholic beverages', 0.023041474654377874), ('Bars', 0.021505376344086016), ('Beer', 0.0184331797235023), ('Vodka', 0.013824884792626727), ('Healthy diet', 0.01228878648233487), ('Nightclubs', 0.01228878648233487), ('Soft drinks', 0.01228878648233487), ('Fast food', 0.010752688172043012)]
#
# CA Lawsuit
# [('None', 0.8031674208144775), ('Cancer awareness', 0.013574660633484165), ('Motherhood', 0.013574660633484165), ('Parenting', 0.013574660633484165), ('Infant', 0.00904977375565611), ('Online shopping', 0.00904977375565611), ('Lawsuit', 0.00904977375565611), ('Health & wellness', 0.00904977375565611), ('Amazon.com', 0.006787330316742082), ('Agriculture', 0.006787330316742082)]
#
# Political
# [('None', 0.7574626865671621), ('Joe Biden', 0.022388059701492536), ('NPR', 0.018656716417910446), ('Community issues', 0.018656716417910446), ('The Washington Post', 0.014925373134328358), ('Republican Party (United States)', 0.014925373134328358), ('Business', 0.014925373134328358), ('Conservatism in the United States', 0.014925373134328358), ('Politics and social issues', 0.014925373134328358), ('Time (magazine)', 0.011194029850746268)]
#
# Potentially Prohibited
# [('None', 0.8181818181818151), ('Health & wellness', 0.02371541501976284), ('Meditation', 0.015810276679841896), ('Entertainment', 0.015810276679841896), ('Physical fitness', 0.011857707509881422), ('Credit cards', 0.011857707509881422), ('House Hunting', 0.011857707509881422), ('Entrepreneurship', 0.011857707509881422), ('Loan', 0.011857707509881422), ('Personal finance', 0.007905138339920948)]
#
# Potentially Harmful
# [('None', 0.7127272727272764), ('Online shopping', 0.03454545454545455), ('Shopping', 0.01818181818181818), ('Technology', 0.014545454545454544), ('Digital marketing', 0.014545454545454544), ('Amazon.com', 0.012727272727272726), ('Clothing', 0.012727272727272726), ('Online advertising', 0.012727272727272726), ('Discount stores', 0.010909090909090908), ('Bitcoin', 0.010909090909090908)]
#
# Can't determine, return to this one
# [('None', 0.6379310344827587), ('Justin Bieber', 0.034482758620689655), ('Travel', 0.034482758620689655), ('Online shopping', 0.034482758620689655), ('Entertainment', 0.034482758620689655), ('IPhone', 0.034482758620689655), ('Health & wellness', 0.034482758620689655), ('Business', 0.034482758620689655), ('Japanese cuisine', 0.017241379310344827), ('The Walt Disney Company', 0.017241379310344827)]
#
# UNCAT
# [('None', 0.615384615384615), ('Shopping', 0.07692307692307693), ('Online shopping', 0.07692307692307693), ('Employment', 0.046153846153846156), ('Education', 0.046153846153846156), ('Entertainment', 0.03076923076923077), ('Digital marketing', 0.03076923076923077), ('Higher education', 0.03076923076923077), ('Sports', 0.03076923076923077), ('Social media marketing', 0.03076923076923077)]

# %%
use_counts['code'].items()
# Out:
# dict_items([])

# %%
data
# Out:
#        Benign               adid  estimate_mau  Clickbait  Financial  \
# 0         1.0  23849336815680703     1800000.0        NaN        NaN
# 1         NaN  23848834321790690   256700000.0        1.0        1.0
# 2         NaN  23848832828510285    10700000.0        NaN        1.0
# 3         1.0      6242765307776    22100000.0        NaN        NaN
# 4         1.0  23849342920860340     2200000.0        NaN        NaN
# ...       ...                ...           ...        ...        ...
# 32581     NaN      6298418662041   155800000.0        1.0        NaN
# 32582     NaN  23850740455080331     6800000.0        NaN        1.0
# 32583     NaN  23849720664260612    85300000.0        NaN        NaN
# 32584     NaN  23849702408680621   244500000.0        NaN        1.0
# 32585     1.0  23849761340000073    27700000.0        NaN        NaN
#
#        Opportunity  Healthcare  Sensitive  Potentially Prohibited  \
# 0              NaN         NaN        NaN                     NaN
# 1              NaN         NaN        NaN                     NaN
# 2              NaN         NaN        NaN                     NaN
# 3              NaN         NaN        NaN                     NaN
# 4              NaN         NaN        NaN                     NaN
# ...            ...         ...        ...                     ...
# 32581          NaN         NaN        NaN                     NaN
# 32582          NaN         NaN        NaN                     NaN
# 32583          NaN         1.0        1.0                     NaN
# 32584          NaN         NaN        NaN                     1.0
# 32585          NaN         NaN        NaN                     NaN
#
#        Potentially Harmful  Study  CA Lawsuit  Political  \
# 0                      NaN    NaN         NaN        NaN
# 1                      NaN    NaN         NaN        NaN
# 2                      NaN    NaN         NaN        NaN
# 3                      NaN    NaN         NaN        NaN
# 4                      NaN    NaN         NaN        NaN
# ...                    ...    ...         ...        ...
# 32581                  NaN    NaN         NaN        NaN
# 32582                  1.0    NaN         NaN        NaN
# 32583                  1.0    NaN         NaN        NaN
# 32584                  NaN    NaN         NaN        NaN
# 32585                  NaN    NaN         NaN        NaN
#
#        Can't determine, return to this one  UNCAT
# 0                                      NaN    NaN
# 1                                      NaN    NaN
# 2                                      NaN    NaN
# 3                                      NaN    NaN
# 4                                      NaN    NaN
# ...                                    ...    ...
# 32581                                  NaN    NaN
# 32582                                  NaN    NaN
# 32583                                  NaN    NaN
# 32584                                  NaN    NaN
# 32585                                  NaN    NaN
#
# [32586 rows x 15 columns]

# %%
# Usage of different targeting _types_ per ad category

from tqdm import tqdm

# %%
params_df = targeting_params.set_index('adid')
categories = ['Benign', 'Financial', 'Opportunity', 'Healthcare', 'Potentially Prohibited', 
              'Potentially Harmful', 'Clickbait', 'Sensitive']

# %%
usage_counter = defaultdict(lambda: defaultdict(int))
any_counter = defaultdict(int)
for idx, row in (tqdm(data.iterrows())):
    try:
        params = params_df.loc[row['adid']]
        used = []
        for k in params.keys():
            if k in ['adid', 'estimate_mau']: continue
            if not pd.isna(params[k]):
                used.append(k)
        if used == []:
            used = ['default']
            
        for category in row.keys():
            if category in ['adid', 'estimate_mau']: continue
            any_counter[category] += 1
            if not pd.isna(row[category]):
                for param in used:
                    usage_counter[category][param] += 1
    except:
        pass
# Out:
# 32586it [00:15, 2122.33it/s]

# %%
usage_counter['Benign'].keys()
# Out:
# dict_keys(['age_min', 'location', 'default', 'WAISTUIInterestsType', 'age_max', 'WAISTUILocaleType', 'WAISTUICustomAudienceType', 'gender', 'WAISTUIBCTType', 'WAISTUIDPAType', 'WAISTUILocalReachType', 'WAISTUIRelationshipType', 'WAISTUIEduStatusType', 'WAISTUIJobTitleType', 'WAISTUIActionableInsightsType', 'WAISTUIConnectionType', 'WAISTUIWorkEmployerType', 'WAISTUIFriendsOfConnectionType'])

# %%
usage_counter
# Out:
# defaultdict(<function __main__.<lambda>()>,
#             {'Benign': defaultdict(int,
#                          {'age_min': 3699,
#                           'location': 1979,
#                           'default': 1494,
#                           'WAISTUIInterestsType': 2649,
#                           'age_max': 2826,
#                           'WAISTUILocaleType': 1389,
#                           'WAISTUICustomAudienceType': 2525,
#                           'gender': 1306,
#                           'WAISTUIBCTType': 264,
#                           'WAISTUIDPAType': 66,
#                           'WAISTUILocalReachType': 10,
#                           'WAISTUIRelationshipType': 58,
#                           'WAISTUIEduStatusType': 60,
#                           'WAISTUIJobTitleType': 8,
#                           'WAISTUIActionableInsightsType': 2,
#                           'WAISTUIConnectionType': 6,
#                           'WAISTUIWorkEmployerType': 2,
#                           'WAISTUIFriendsOfConnectionType': 5}),
#              'Financial': defaultdict(int,
#                          {'age_min': 178,
#                           'WAISTUIInterestsType': 138,
#                           'WAISTUILocaleType': 105,
#                           'age_max': 124,
#                           'WAISTUICustomAudienceType': 187,
#                           'default': 106,
#                           'location': 166,
#                           'WAISTUIBCTType': 11,
#                           'gender': 33,
#                           'WAISTUILocalReachType': 1,
#                           'WAISTUIEduStatusType': 3,
#                           'WAISTUIRelationshipType': 1}),
#              'Opportunity': defaultdict(int,
#                          {'WAISTUIInterestsType': 259,
#                           'location': 449,
#                           'age_min': 396,
#                           'age_max': 431,
#                           'WAISTUILocaleType': 238,
#                           'WAISTUICustomAudienceType': 280,
#                           'default': 88,
#                           'WAISTUIEduStatusType': 82,
#                           'WAISTUIEduSchoolsType': 2,
#                           'gender': 39,
#                           'WAISTUIBCTType': 5,
#                           'WAISTUIJobTitleType': 1,
#                           'WAISTUIDPAType': 1}),
#              'Healthcare': defaultdict(int,
#                          {'age_min': 743,
#                           'age_max': 694,
#                           'gender': 294,
#                           'WAISTUIInterestsType': 460,
#                           'WAISTUILocaleType': 349,
#                           'WAISTUICustomAudienceType': 442,
#                           'location': 775,
#                           'default': 259,
#                           'WAISTUIBCTType': 45,
#                           'WAISTUIEduStatusType': 16,
#                           'WAISTUIRelationshipType': 13,
#                           'WAISTUIFriendsOfConnectionType': 1,
#                           'WAISTUIConnectionType': 1,
#                           'WAISTUIJobTitleType': 1}),
#              'Potentially Prohibited': defaultdict(int,
#                          {'age_max': 45,
#                           'gender': 28,
#                           'location': 42,
#                           'WAISTUICustomAudienceType': 16,
#                           'age_min': 40,
#                           'WAISTUIRelationshipType': 4,
#                           'WAISTUIInterestsType': 17,
#                           'default': 9,
#                           'WAISTUILocaleType': 7,
#                           'WAISTUIBCTType': 2,
#                           'WAISTUIDPAType': 1}),
#              'Potentially Harmful': defaultdict(int,
#                          {'age_max': 65,
#                           'location': 66,
#                           'age_min': 101,
#                           'WAISTUIInterestsType': 74,
#                           'WAISTUILocaleType': 39,
#                           'WAISTUICustomAudienceType': 28,
#                           'default': 35,
#                           'gender': 30,
#                           'WAISTUIBCTType': 9,
#                           'WAISTUIRelationshipType': 3,
#                           'WAISTUIEduStatusType': 1,
#                           'WAISTUIDPAType': 1}),
#              'Clickbait': defaultdict(int,
#                          {'WAISTUILocaleType': 92,
#                           'default': 64,
#                           'age_min': 216,
#                           'age_max': 111,
#                           'WAISTUIInterestsType': 96,
#                           'WAISTUICustomAudienceType': 72,
#                           'location': 109,
#                           'WAISTUIBCTType': 15,
#                           'gender': 44,
#                           'WAISTUIEduStatusType': 2,
#                           'WAISTUIRelationshipType': 4}),
#              'CA Lawsuit': defaultdict(int,
#                          {'location': 47,
#                           'age_max': 39,
#                           'age_min': 77,
#                           'WAISTUIInterestsType': 32,
#                           'default': 24,
#                           'gender': 31,
#                           'WAISTUILocaleType': 25,
#                           'WAISTUICustomAudienceType': 34,
#                           'WAISTUIEduStatusType': 2}),
#              'Sensitive': defaultdict(int,
#                          {'WAISTUICustomAudienceType': 76,
#                           'age_min': 128,
#                           'age_max': 86,
#                           'WAISTUIInterestsType': 55,
#                           'location': 105,
#                           'default': 13,
#                           'WAISTUILocaleType': 10,
#                           'gender': 28,
#                           'WAISTUIEduStatusType': 1,
#                           'WAISTUIBCTType': 2,
#                           'WAISTUIRelationshipType': 1}),
#              'Political': defaultdict(int,
#                          {'WAISTUICustomAudienceType': 46,
#                           'location': 39,
#                           'WAISTUIBCTType': 6,
#                           'default': 12,
#                           'age_min': 33,
#                           'WAISTUIInterestsType': 30,
#                           'age_max': 13,
#                           'gender': 3,
#                           'WAISTUILocaleType': 13,
#                           'WAISTUIFriendsOfConnectionType': 1,
#                           'WAISTUIConnectionType': 1}),
#              'Study': defaultdict(int,
#                          {'location': 384,
#                           'age_min': 288,
#                           'age_max': 335,
#                           'WAISTUIInterestsType': 286,
#                           'WAISTUILocaleType': 182,
#                           'WAISTUICustomAudienceType': 150,
#                           'gender': 152,
#                           'default': 168,
#                           'WAISTUIBCTType': 23,
#                           'WAISTUIEduStatusType': 7,
#                           'WAISTUIRelationshipType': 5,
#                           'WAISTUIConnectionType': 1,
#                           'WAISTUIFriendsOfConnectionType': 2}),
#              "Can't determine, return to this one": defaultdict(int,
#                          {'age_min': 8,
#                           'location': 7,
#                           'age_max': 5,
#                           'WAISTUIInterestsType': 8,
#                           'WAISTUILocaleType': 4,
#                           'WAISTUIBCTType': 1,
#                           'gender': 1}),
#              'UNCAT': defaultdict(int,
#                          {'age_min': 13,
#                           'WAISTUIInterestsType': 11,
#                           'age_max': 15,
#                           'location': 6,
#                           'default': 5,
#                           'WAISTUILocaleType': 3,
#                           'gender': 3,
#                           'WAISTUIEduStatusType': 1,
#                           'WAISTUICustomAudienceType': 2})})

# %%
parameters = ['age_min', 'age_max','gender', 'location', 'WAISTUILocaleType', 'WAISTUIInterestsType', 'WAISTUICustomAudienceType', 'default']

# %%
f, axes = plt.subplots(2, 4, sharey = True, sharex = True)
for pidx, parameter in enumerate(parameters):
    ax = axes[pidx//4, pidx%4]
    for cidx, category in enumerate(categories):
        try:
            frac = usage_counter[category][parameter] / sum(usage_counter[category].values())
        except:
            frac = 0
        ax.bar(cidx, frac)
    ax.set_title(parameter.replace('WAISTUI', '').replace('Type', ''))
    
    if pidx%4 == 0:
        ax.set_ylabel('Fraction of ads')
    if pidx//4 == 1:
        ax.set_xticks(range(0, len(categories)))
        ax.set_xticklabels(categories, rotation=90)
    ax.set_ylim(0, 1)

# %%
usage_counter['Benign']
# Out:
# defaultdict(int,
#             {'age_min': 3699,
#              'location': 1979,
#              'estimate_mau': 7228,
#              'WAISTUIInterestsType': 2649,
#              'age_max': 2826,
#              'WAISTUILocaleType': 1389,
#              'WAISTUICustomAudienceType': 2525,
#              'gender': 1306,
#              'WAISTUIBCTType': 264,
#              'WAISTUIDPAType': 66,
#              'WAISTUILocalReachType': 10,
#              'WAISTUIRelationshipType': 58,
#              'WAISTUIEduStatusType': 60,
#              'WAISTUIJobTitleType': 8,
#              'WAISTUIActionableInsightsType': 2,
#              'WAISTUIConnectionType': 6,
#              'WAISTUIWorkEmployerType': 2,
#              'WAISTUIFriendsOfConnectionType': 5,
#              'default': 0})

# %%
[] == []
# Out:
# True
