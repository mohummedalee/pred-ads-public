# %% [markdown]
# ## Forms of Harm
#
# For now, throw away Manjot's codes.
# Two broad forms of harms:
# - global: harmful + clickbait. Bad for everyone
# - contextual: sensitive. Bad in certain contexts
#
# For both of these, we need a better sense of the demographics of people consuming the top 20 percentile of the harm.
#
# Consider evaluating fairness metrics such as TPR bias on these differences, both on the content and the targeting differences.

# %%
import pandas as pd
import numpy as np
import csv
import json
import sys
sys.path.insert(0, '../')
import analysis_utils
import matplotlib.pyplot as plt
plt.rcParams["font.family"] = "Helvetica"

# %%
ca_advertisers = {}
# 'ca_owner_name': 'Klarna'

def get_targeting(ut, aid):
    # also updates global list of CA advertisers
    global ca_advertisers
    
    # there is always an el['__typename'] == 'WAISTUIAgeGenderType'
    all_targetings = {'id': aid}
    for el in ut['data']['waist_targeting_data']:
        if el['__typename'] == 'WAISTUIInterestsType':
            all_targetings['interests'] = set([i['name'] for i in el['interests']])
        elif el['__typename'] == 'WAISTUICustomAudienceType':
            ca_advertisers[aid] = el['dfca_data']['ca_owner_name']
            all_targetings['custom'] = True
        elif el['__typename'] == 'WAISTUILocationType':
            gran = json.loads(el['serialized_data'])['location_granularity']
            loc = el['location_name']
            all_targetings['location'] = {'loc': loc, 'gran': gran}
        elif el['__typename'] == 'WAISTUIAgeGenderType':
            all_targetings['age-gender'] = {
                'age_min': el['age_min'],
                'age_max': el['age_max'],
                'gender': el['gender']
            }        
        
    return all_targetings

# %%
from collections import defaultdict

def count_code_props(codes, norm=True):
    # takes dict from adid -> codes and returns dict of code proportions
    counts = defaultdict(lambda: 0)
    for aid in codes:
        # in case of multiple codes, count each one -- essentially computing fraction of codes and not ads here
        for code in codes[aid].split(';'):
            if "Can't determine" not in code and code != 'Study':
                counts[code] += 1
                
    if norm:
        return {c: counts[c]/sum(counts.values()) for c in counts}
    else:
        return counts

# %%
pid_adid_files = ['../../db-processing/surveys/survey-1/survey1_coding_subsample.tsv',
                  '../../db-processing/surveys/survey-1/survey1_batch2_coding_subsample.tsv',
                 '../../db-processing/surveys/survey-2/survey2_coding_subsample.tsv',
                 '../../db-processing/surveys/survey-3/survey3_coding_subsample.tsv']

pid_adid = pd.read_csv(pid_adid_files[0], sep='\t')
for f in pid_adid_files[1:]:
    pid_adid = pd.concat([pid_adid, pd.read_csv(f, sep='\t')], ignore_index=True)
pids = set(pid_adid['pid'])
# part_ad_counts = pid_adid.groupby('pid').count().to_dict()['adid']

codes_file = '../../db-processing/ad_codes.tsv'
codes = pd.read_csv(codes_file, sep='\t')
# drop Manjot's codes
codes = codes[codes['codes_manjot'].isna()]

# make sure Manjot's codes are dropped before computing part_ad_counts
part_ad_counts = pid_adid.merge(codes, how='inner', left_on='adid', right_on='adid')\
    .groupby('pid').count().to_dict()['adid']

# global and contextual harms
global_harms = codes[codes['codes'].str.contains('Clickbait|Harmful|Prohibited')]
cont_harms = codes[codes['codes'].str.contains('Sensitive')]
healthcare_harms = codes[codes['codes'].str.contains('Healthcare;Sensitive')]

# load targeting data
# load targetings
ad_targetings = {}
with open('../../db-processing/ad-targetings.tsv', 'r') as fh:
    for line in fh:
        ad_id, targeting = line.split('\t')
        targeting = json.loads(targeting.strip())
        ad_targetings[ad_id] = targeting

# %%
print('Total:', codes.shape[0])
print('Sensitive (contextual harms):', codes[codes['codes'].str.contains('Sensitive')].shape[0])
print('Prohibited or Harmful or Clickbait (global harms):',
      codes[codes['codes'].str.contains('Clickbait|Harmful|Prohibited')].shape[0])
# Out:
# Total: 13264
# Sensitive (contextual harms): 292
# Prohibited or Harmful or Clickbait (global harms): 555

# %%
pd.set_option('display.min_rows', 200)
cont_harms
# Out:
#                     adid codes_manjot  \
# 20     23848814950330329          NaN
# 155    23848885154560765          NaN
# 205    23848993482500605          NaN
# 294    23848643725350179          NaN
# 392    23849189135900061          NaN
# 505    23848903114260235          NaN
# 574    23848873531490112          NaN
# 630        6268714766572          NaN
# 710    23848355086780232          NaN
# 791        6295676510323          NaN
# 838        6296456389123          NaN
# 986    23849352161670311          NaN
# 1140   23849008124890061          NaN
# 1150   23849110441030061          NaN
# 1526       6295898683523          NaN
# 2154   23849130087880061          NaN
# 2206   23848222290460553          NaN
# 2336       6243709972505          NaN
# 2392       6245095347305          NaN
# 2393       6247147347434          NaN
# 2394       6247726266515          NaN
# 2515       6255445813400          NaN
# 2516       6255578050381          NaN
# 3206       6275513875993          NaN
# 3343       6297140992070          NaN
# 3344       6299139649723          NaN
# 3553   23848472962520068          NaN
# 3554   23848519249870093          NaN
# 3822   23848777835490755          NaN
# 3823   23848778885390481          NaN
# ...                  ...          ...
# 17729  23849578398560061          NaN
# 17764  23849598455730661          NaN
# 17775  23849601910040449          NaN
# 17834  23849630406950446          NaN
# 17859  23849640948700683          NaN
# 17895  23849657020110061          NaN
# 17906  23849662087860061          NaN
# 17913  23849666621350174          NaN
# 17934  23849679768600385          NaN
# 17951  23849695378540294          NaN
# 17959  23849692357450061          NaN
# 18036  23849733215860384          NaN
# 18048  23849737834330308          NaN
# 18049  23849742486970311          NaN
# 18062  23849749747330061          NaN
# 18064  23849750938990061          NaN
# 18081  23849759081740061          NaN
# 18082  23849759669980061          NaN
# 18109  23849779293470739          NaN
# 18163  23849816379320650          NaN
# 18167  23849820179520311          NaN
# 18185  23849831949780193          NaN
# 18245  23849888141880150          NaN
# 18345  23849971854030530          NaN
# 18357  23849991753200716          NaN
# 18394  23850054489730530          NaN
# 18552  23850404429140543          NaN
# 18584  23850812808450426          NaN
# 18588  23850858639970491          NaN
# 18598  23851114711590491          NaN
#
#                                           codes
# 20                                    Sensitive
# 155                                   Sensitive
# 205                                   Sensitive
# 294                                   Sensitive
# 392                        Healthcare;Sensitive
# 505                                   Sensitive
# 574                                   Sensitive
# 630                                   Sensitive
# 710                                   Sensitive
# 791                                   Sensitive
# 838                                   Sensitive
# 986                        Healthcare;Sensitive
# 1140                       Healthcare;Sensitive
# 1150                       Healthcare;Sensitive
# 1526                                  Sensitive
# 2154                       Healthcare;Sensitive
# 2206                                  Sensitive
# 2336                                  Sensitive
# 2392                                  Sensitive
# 2393                                  Sensitive
# 2394                       Healthcare;Sensitive
# 2515                                  Sensitive
# 2516                       Healthcare;Sensitive
# 3206              Potentially Harmful;Sensitive
# 3343                                  Sensitive
# 3344                                  Sensitive
# 3553                       Healthcare;Sensitive
# 3554                       Healthcare;Sensitive
# 3822                                  Sensitive
# 3823                                  Sensitive
# ...                                         ...
# 17729                      Healthcare;Sensitive
# 17764                      Healthcare;Sensitive
# 17775                                 Sensitive
# 17834                                 Sensitive
# 17859          Potentially Prohibited;Sensitive
# 17895                      Healthcare;Sensitive
# 17906                      Healthcare;Sensitive
# 17913                Healthcare;Sensitive;Study
# 17934                                 Sensitive
# 17951                                 Sensitive
# 17959                      Healthcare;Sensitive
# 18036                      Healthcare;Sensitive
# 18048                      Healthcare;Sensitive
# 18049                      Healthcare;Sensitive
# 18062                      Healthcare;Sensitive
# 18064                      Healthcare;Sensitive
# 18081  Healthcare;Potentially Harmful;Sensitive
# 18082                      Healthcare;Sensitive
# 18109                                 Sensitive
# 18163                      Healthcare;Sensitive
# 18167                      Healthcare;Sensitive
# 18185                                 Sensitive
# 18245                       Clickbait;Sensitive
# 18345                                 Sensitive
# 18357                                 Sensitive
# 18394                                 Sensitive
# 18552                      Healthcare;Sensitive
# 18584                                 Sensitive
# 18588                      Healthcare;Sensitive
# 18598                      Healthcare;Sensitive
#
# [292 rows x 3 columns]

# %%
dems_file = '../../db-processing/participant-demographics/ALLDEMS.csv'
dems_rec = pd.read_csv(dems_file, index_col='pid')
dems_rec.drop_duplicates(inplace=True)
dems_dict = dems_rec.to_dict(orient='index')

# %%
# Count frequency of codes by participants
part_code_props = {}
part_code_counts = {}

for pid in pids:
    joiner = pid_adid[pid_adid['pid'] == pid]
    joined = joiner.merge(codes, how='inner', left_on='adid', right_on='adid')
    
    code_props = count_code_props(dict(joined[['adid', 'codes']].values), norm=True)
    part_code_props[pid] = code_props
    
    code_counts = count_code_props(dict(joined[['adid', 'codes']].values), norm=False)
    part_code_counts[pid] = code_counts

# %% [markdown]
# ## Do Global and Contextual harms focus on different people?

# %%
global_harm_counts = {}
cont_harm_counts = {}
healthcare_harm_counts = {}

for pid in pids:
    joiner = pid_adid[pid_adid['pid'] == pid]    
    
    joined = joiner.merge(global_harms, how='inner', left_on='adid', right_on='adid')
    global_harm_counts[pid] = joined.shape[0]
    
    joined = joiner.merge(cont_harms, how='inner', left_on='adid', right_on='adid')
    cont_harm_counts[pid] = joined.shape[0]
    
    joined = joiner.merge(healthcare_harms, how='inner', left_on='adid', right_on='adid')
    healthcare_harm_counts[pid] = joined.shape[0]
    
# output these to a file for reusability elsewhere
allrows = []
for pid in pids:
    allrows.append([pid, global_harm_counts[pid], cont_harm_counts[pid], healthcare_harm_counts[pid]])
    
# pd.DataFrame(allrows, columns=['pid', 'global', 'contextual', 'healthcare'])\
#   .to_csv('global_contextual_harmscounts.csv', index=False)

# %%
# for plotting
global_vals = [global_harm_counts[pid] for pid in list(pids)]
global_props = [global_harm_counts[pid]/part_ad_counts[pid] for pid in list(pids)]
cont_vals = [cont_harm_counts[pid] for pid in list(pids)]
cont_props = [cont_harm_counts[pid]/part_ad_counts[pid] for pid in list(pids)]
# convert to frequencies for histograms
cont_freqs, global_freqs = [], []
for i in range(len(pids)):
    # pid index repeated cont_vals[i] times (+1 for smoothing in case of zero)
    cont_freqs.extend([i] * (cont_vals[i]+1))
    global_freqs.extend([i] * (global_vals[i]+1))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-9-4551d753643b> in <module>
#       1 # for plotting
#       2 global_vals = [global_harm_counts[pid] for pid in list(pids)]
# ----> 3 global_props = [global_harm_counts[pid]/part_ad_counts[pid] for pid in list(pids)]
#       4 cont_vals = [cont_harm_counts[pid] for pid in list(pids)]
#       5 cont_props = [cont_harm_counts[pid]/part_ad_counts[pid] for pid in list(pids)]
#
# <ipython-input-9-4551d753643b> in <listcomp>(.0)
#       1 # for plotting
#       2 global_vals = [global_harm_counts[pid] for pid in list(pids)]
# ----> 3 global_props = [global_harm_counts[pid]/part_ad_counts[pid] for pid in list(pids)]
#       4 cont_vals = [cont_harm_counts[pid] for pid in list(pids)]
#       5 cont_props = [cont_harm_counts[pid]/part_ad_counts[pid] for pid in list(pids)]
#
# KeyError: '137679'

# %%
plt.subplots(1, 1, figsize=(15, 6))

x = np.arange(len(pids))
width = .2
rects1 = plt.bar(x - width/2, global_vals, width, label='Clickbait+Harmful+Prohibited')
rects2 = plt.bar(x + width/2, cont_vals, width, label='Sensitive')
plt.legend()

# %%
plt.subplots(1, 1, figsize=(10, 6))

cont_harm_counts[pid]
# order of participants on x-axis
part_order = [p for p in pids if p in part_ad_counts]
# part_order = sorted(list(part_order), key=lambda p: part_code_props[p].get('Benign', 0), reverse=True)
part_order = [p for p in part_order if part_ad_counts[p] >= 25]

# cdf of global harms
counts = [global_harm_counts[pid] for pid in part_order]
props = [global_harm_counts[pid]/part_ad_counts[pid] for pid in part_order]
pdf = np.array(counts) / sum(counts)
plt.hist(props, bins=50, label='Harmful+Prohibited+Clickbait', facecolor='None', edgecolor=colors['Potentially Harmful'])
# plt.plot(np.arange(len(pdf)), np.cumsum(pdf), label='Harmful+Prohibited+Clickbait',
#          color=colors['Potentially Harmful'])

# cdf of contextual harms
counts = [cont_harm_counts[pid] for pid in part_order]
props = [cont_harm_counts[pid]/part_ad_counts[pid] for pid in part_order]
pdf = np.array(counts) / sum(counts)
plt.hist(props, bins=50, label='Sensitive', edgecolor='tab:blue', facecolor='None')
# plt.plot(np.arange(len(pdf)), np.cumsum(pdf), label='Sensitive', color='tab:blue')

# cdf of healthcare harms
counts = [healthcare_harm_counts[pid] for pid in part_order]
props = [healthcare_harm_counts[pid]/part_ad_counts[pid] for pid in part_order]
# plt.hist(props, bins=50, label='Healthcare+Sensitive', facecolor='None', edgecolor='darkorange')
pdf = np.array(counts) / sum(counts)
# plt.plot(np.arange(len(pdf)), np.cumsum(pdf), label='Healthcare+Sensitive', color='darkorange')

# benign
counts = [part_code_counts[p].get('Benign', 0) for p in part_order]
props = [part_code_props[p].get('Benign', 0) for p in part_order]
# plt.hist(props, bins=50, label='Benign', facecolor='white', edgecolor='darkgray', alpha=.6)
pdf = np.array(counts) / sum(counts)
# plt.plot(np.arange(len(pdf)), np.cumsum(pdf), label='Benign', color='darkgray')

# plt.plot(np.arange(len(pdf)+1), np.arange(0, 1, 1.0/len(pdf)), ls='--', label='Uniform Dist.', color='k')
    
plt.legend()
# plt.xlabel('Participant (decreasing order of fraction benign)')
# plt.ylabel('CDF')
plt.xlabel('Fraction of ads')
plt.ylabel('# participants')
plt.grid(ls=':')

# plt.savefig('../figures/healthcareharms-vs-global-hist.pdf', bbox_inches='tight', dpi=150)
plt.savefig('../figures/contharms-vs-global-hist.pdf', bbox_inches='tight', dpi=150)

# %%
plt.subplots(1, 1, figsize=(10, 6))
part_order = sorted(pids, key=lambda pid: part_code_props[pid].get('Benign', 0), reverse=True)

# cdf of contextual harms
counts = [cont_harm_counts[pid] for pid in part_order]
pdf = np.array(counts) / sum(counts)
# plt.plot(np.arange(len(pdf)), np.cumsum(sorted(pdf)), label='Sensitive', color='tab:blue')
plt.plot(np.arange(len(pdf)), np.cumsum(sorted(pdf, reverse=True)), label='Sensitive', color='tab:blue')

# cdf of global harms
counts = [global_harm_counts[pid] for pid in part_order]
pdf = np.array(counts) / sum(counts)
# plt.plot(np.arange(len(pdf)), np.cumsum(sorted(pdf)), label='Harmful+Prohibited+Clickbait',
#          color=analysis_utils.colors['Potentially Harmful'])
plt.plot(np.arange(len(pdf)), np.cumsum(sorted(pdf, reverse=True)), label='Harmful+Prohibited+Clickbait',
         color=analysis_utils.colors['Potentially Harmful'])

# cdf of healthcare harms
counts = [healthcare_harm_counts[pid] for pid in part_order]
pdf = np.array(counts) / sum(counts)
# plt.plot(np.arange(len(pdf)), np.cumsum(sorted(pdf)), label='Healthcare+Sensitive', color='darkorange')

# benign
counts = [part_code_counts[p].get('Benign', 0) for p in part_order]
pdf = np.array(counts) / sum(counts)
# plt.plot(np.arange(len(pdf)), np.cumsum(sorted(pdf)), label='Benign', color='darkgray')
plt.plot(np.arange(len(pdf)), np.cumsum(sorted(pdf, reverse=True)), label='Benign', color='darkgray')

plt.plot(np.arange(len(pdf)), np.arange(0, 1, 1.0/len(pdf)), ls='--', label='Uniform Dist.', color='k')
    
plt.legend()
# plt.xlabel('Participant (in increasing order of contributions for the ad type)')
plt.xlabel('Participant')
plt.ylabel('CDF')
plt.grid(ls=':')

# plt.savefig('../figures/harms-w-frequencies-cdf.pdf', bbox_inches='tight', dpi=150)

# %% [markdown]
# #### Statistically Comparing the Distributions

# %%
import scipy.stats as stats

# comparing the two distributions shown in the CDF plot; H0 = both distributions are identical
print('=== Global vs. Sensitive ===')
print(stats.mannwhitneyu([global_harm_counts[pid] for pid in part_order],
                        [cont_harm_counts[pid] for pid in part_order]))

# comparing via Kolmogorov-Smirnov test; H0 = both distributions are identical
print(stats.kstest([global_harm_counts[pid] for pid in part_order],
                  [cont_harm_counts[pid] for pid in part_order]))

print('\n=== Global vs. Healthcare Sensitive ===')
print(stats.mannwhitneyu([global_harm_counts[pid] for pid in part_order],
                        [healthcare_harm_counts[pid] for pid in part_order]))
print(stats.kstest([global_harm_counts[pid] for pid in part_order],
                  [healthcare_harm_counts[pid] for pid in part_order]))
# Out:
# === Global vs. Sensitive ===
# MannwhitneyuResult(statistic=3301.0, pvalue=6.725094769535624e-05)
# KstestResult(statistic=0.25510204081632654, pvalue=0.00327343720783562)
#
# === Global vs. Healthcare Sensitive ===
# MannwhitneyuResult(statistic=2032.0, pvalue=4.607871212197361e-13)
# KstestResult(statistic=0.4489795918367347, pvalue=2.856481715990826e-09)

# %% [markdown]
# **Result**: $p < 0.05$ (or 0.025 if corrected here), so $H_0$ (both distributions are equal) for both tests can be rejected.

# %% [markdown]
# ### Descriptive Comparison of global vs. contextual Harms
# For each individual person who experiences these, I'd like to compare:
# 1. fraction of global vs. contextual harms
# 2. percentile position of global vs. contextual harms, particularly for people over the 90th percentile (top consumers of harms)

# %%
plt.subplots(1, 1, figsize=(7, 6))

# == healthcare vs. scams ==
plt.scatter([global_harm_counts[pid]/part_ad_counts[pid] for pid in part_order],
        [healthcare_harm_counts[pid]/part_ad_counts[pid] for pid in part_order], facecolor='white', edgecolor='k')
plt.ylabel('Fraction of Ads healthcare+sensitive')
plt.xlabel('Fraction of Ads hamful/prohibited/clickbait')
plt.grid(ls=':')
plt.xlim(right=0.25); plt.ylim(top=0.2)
plt.title('Each point is a participant')
plt.savefig('../figures/global-vs-healtcare-scatter.pdf', bbox_inches='tight', dpi=150)

# == sensitive vs. scams ==
# plt.scatter([global_harm_counts[pid]/part_ad_counts[pid] for pid in part_order],
#         [cont_harm_counts[pid]/part_ad_counts[pid] for pid in part_order], facecolor='white', edgecolor='k')
# plt.ylabel('Fraction of Ads sensitive')
# plt.xlabel('Fraction of Ads hamful/prohibited/clickbait')
# plt.grid(ls=':')
# plt.xlim(right=0.25); plt.ylim(top=0.2)
# plt.title('Each point is a participant')
# plt.savefig('../figures/global-vs-cont-scatter.pdf', bbox_inches='tight', dpi=150)

# %%
from tabulate import tabulate

global_counts = [global_harm_counts[pid]/part_ad_counts[pid] for pid in part_order]
cont_counts = [cont_harm_counts[pid]/part_ad_counts[pid] for pid in part_order]

percentile_90_global = np.percentile(global_counts, 90)
percentile_90_cont = np.percentile(cont_counts, 90)
# NOTE: can also reproduce this for healthcare harms
print(f'90th percentile prohibited+clickbait+sensitive: {percentile_90_global}')
print(f'90th percentile sensitive: {percentile_90_cont}\n')

x, y, tab = [], [], []
for pid in part_order:
    gh_prop = round(global_harm_counts[pid]/part_ad_counts[pid], 3)
    ch_prop = round(cont_harm_counts[pid]/part_ad_counts[pid], 3)
    if gh_prop >= percentile_90_global or ch_prop >= percentile_90_cont:
        tab.append([pid, 
            f'{int(stats.percentileofscore(global_counts, gh_prop))} ({gh_prop})',
            f'{int(stats.percentileofscore(cont_counts, ch_prop))} ({ch_prop})'])
        
        x.append(stats.percentileofscore(global_counts, gh_prop))
        y.append(stats.percentileofscore(cont_counts, ch_prop))
        
print(tabulate(tab, headers=['PID', 'Percentile (frac. P/H/C)', 'Percentile (frac. Sensitive)']))

plt.subplots(1, 1, figsize=(7, 6))
plt.scatter(x, y, color='tab:red')
plt.xlabel('Percentile of *fraction* hamful/prohibited/clickbait distribution', fontsize=13, fontweight='bold')
plt.ylabel('Percentile of *fraction* sensitive distribution', fontsize=13, fontweight='bold')
plt.grid(ls=':')
plt.axvline(90, ls='--', color='grey')
plt.axhline(90, ls='--', color='grey')
plt.title('Each point is a participant, dashed lines 90th percentile')

plt.savefig('../figures/global-vs-cont-percentile-fraction-scatter.pdf', dpi=150, bbox_inches='tight')
# Out:
# 90th percentile prohibited+clickbait+sensitive: 0.08949494949494949
# 90th percentile sensitive: 0.04225757575757575
#
# PID                       Percentile (frac. P/H/C)    Percentile (frac. Sensitive)
# ------------------------  --------------------------  ------------------------------
# 849164                    50 (0.031)                  98 (0.125)
# 597658                    90 (0.091)                  42 (0.01)
# 805102                    95 (0.167)                  71 (0.026)
# 5db1142453bf830017fc744c  30 (0.016)                  94 (0.092)
# 6130e3db169db34eb3cde8cc  98 (0.224)                  16 (0.0)
# 588623                    97 (0.218)                  83 (0.034)
# 105905                    43 (0.026)                  92 (0.053)
# 340500                    77 (0.056)                  95 (0.111)
# 326424                    50 (0.031)                  90 (0.046)
# 825119                    94 (0.139)                  16 (0.0)
# 601387b4aa37e127b0544497  84 (0.067)                  96 (0.122)
# 5e5ab88a43f33029b119a48c  48 (0.028)                  98 (0.128)
# 5f786ddd6f28d63e71e631b6  69 (0.04)                   90 (0.044)
# 504234                    90 (0.106)                  57 (0.021)
# 981199                    96 (0.191)                  45 (0.011)
# 100538                    95 (0.143)                  88 (0.041)
# 978584                    93 (0.124)                  77 (0.031)
# 606e4eb2a56685e5593304cd  7 (0.0)                     93 (0.081)
# 298154                    91 (0.112)                  83 (0.034)
# 525028                    45 (0.027)                  93 (0.058)

# %%
from tabulate import tabulate

global_counts = [global_harm_counts[pid] for pid in part_order]
cont_counts = [cont_harm_counts[pid] for pid in part_order]

percentile_90_global = np.percentile(global_counts, 90)
percentile_90_cont = np.percentile(cont_counts, 90)
print(f'90th percentile prohibited+clickbait+sensitive: {percentile_90_global}')
print(f'90th percentile sensitive: {percentile_90_cont}\n')

x, y, tab = [], [], []
for pid in part_order:
    if global_harm_counts[pid] >= percentile_90_global or cont_harm_counts[pid] >= percentile_90_cont:
        tab.append([pid, 
            f'{int(stats.percentileofscore(global_counts, global_harm_counts[pid]))} ({global_harm_counts[pid]})',
            f'{int(stats.percentileofscore(cont_counts, cont_harm_counts[pid]))} ({cont_harm_counts[pid]})'])
        
        x.append(stats.percentileofscore(global_counts, global_harm_counts[pid]))
        y.append(stats.percentileofscore(cont_counts, cont_harm_counts[pid]))
        
print(tabulate(tab, headers=['PID', 'Percentile (# P/H/C)', 'Percentile (# Sensitive)']))

plt.subplots(1, 1, figsize=(7, 6))
plt.scatter(x, y, color='tab:red')
plt.xlabel('Percentile of hamful/prohibited/clickbait distribution', fontsize=13, fontweight='bold')
plt.ylabel('Percentile of sensitive distribution', fontsize=13, fontweight='bold')
plt.grid(ls=':')
plt.axvline(90, ls='--', color='grey')
plt.axhline(90, ls='--', color='grey')
plt.title('Each point is a participant, dashed lines 90th percentile')

plt.savefig('../figures/global-vs-cont-percentile-scatter.pdf', dpi=150, bbox_inches='tight')
# Out:
# 90th percentile prohibited+clickbait+sensitive: 12.599999999999994
# 90th percentile sensitive: 8.299999999999997
#
# PID                       Percentile (# P/H/C)    Percentile (# Sensitive)
# ------------------------  ----------------------  --------------------------
# 5c315f577626080001a88cb2  94 (17)                 89 (8)
# 805102                    98 (45)                 87 (7)
# 5db1142453bf830017fc744c  73 (7)                  100 (41)
# 60ee4077cdf4f24a1c607783  94 (17)                 85 (6)
# 6130e3db169db34eb3cde8cc  97 (39)                 16 (0)
# 588623                    100 (58)                91 (9)
# 825119                    91 (15)                 16 (0)
# 601387b4aa37e127b0544497  68 (6)                  95 (11)
# 5ae5b7e26735bd0001d7dfe3  96 (19)                 93 (10)
# 61648bb6ad1eceeee2c056ee  78 (8)                  93 (10)
# 441420                    92 (16)                 56 (2)
# 603e370c5ed1c2db2c3bde24  68 (6)                  93 (10)
# 5e5ab88a43f33029b119a48c  44 (3)                  97 (14)
# 5f786ddd6f28d63e71e631b6  88 (11)                 96 (12)
# 6107ae1b4c627841741dd5e8  35 (2)                  91 (9)
# 981199                    95 (18)                 40 (1)
# 100538                    90 (14)                 78 (4)
# 525028                    73 (7)                  98 (15)

# %%
plot_names = {
    'Benign': 'Neutral',
    'Healthcare': 'Healthcare',
    'Opportunity': 'Opportunity',
    'Clickbait': 'Clickbait',
    'Financial': 'Financial',
    'Potentially Harmful': 'Potentially Harmful',
    'Political': 'Political',
    'Potentially Prohibited': 'Potentially\nProhibited',
    'CA Lawsuit': 'Class Action\nLawsuit',
    'Harmful': 'Problematic',
    'Other': 'Other',
    'Sensitive': 'Sensitive'
}

colors = {
    'Benign': 'dimgray',
    'Financial': 'palegreen',
    'Healthcare': 'lightseagreen',
    'Opportunity': 'gold',
    'Harmful': 'tab:red',
    'Potentially Harmful': 'tab:red',
    'Potentially Prohibited': 'purple',
    'Clickbait': 'tab:orange',
    'Sensitive': 'pink',
    'Other': 'lightgray'
}

bar_order = ['Potentially Harmful', 'Clickbait', 'Potentially Prohibited', 'Sensitive']
# bar_order = ['Sensitive']

# visualize in descending order of fraction benign
part_order = sorted(pids, key=lambda pid: part_code_props[pid].get('Benign', 0), reverse=True)
# exclude participants with < 25 ads
part_order = [p for p in part_order if part_ad_counts[p] >= 25]
f, ax = plt.subplots(figsize=(17, 8))

# total across categories we care about
totals = {p: 0 for p in part_order}
for p in part_order:
    for code in bar_order:
        totals[p] += part_code_counts[p].get(code, 0)

last = np.zeros(len(part_order))
for code in bar_order:
    curr = [part_code_counts[p].get(code, 0) for p in part_order]
        
#     errs = [normal_bin_conf(curr[i], totals[p]) if (totals[p]*curr[i]) >= 5 else 0 \
#             for i, p in enumerate(part_order)]
    errs = None
    ax.bar(np.arange(len(part_order)), curr, .5, yerr=errs, label=plot_names[code], bottom=last,
           color=colors[code], alpha=.8, ecolor=colors[code])
    last += np.array(curr)
    
ax.set_ylabel('Number of Ads')
ax.set_xlabel('Participant')
# ax.set_ylim(top=1.01)
ax.grid(ls=':')
ax.legend()
ax.set_title('Ad Type Breakdown for Participants ≥ 25 Contributed Ads')

# plt.savefig('../figures/global-vs-contextual-counts.pdf', bbox_inches='tight', dpi=150)
# Out:
# Text(0.5, 1.0, 'Ad Type Breakdown for Participants ≥ 25 Contributed Ads')

# %%
part_code_props = {}

joiner = pid_adid[pid_adid['pid'] == pid]
    joined = joiner.merge(codes, how='inner', left_on='adid', right_on='adid')
    
    code_props = count_code_props(dict(joined[['adid', 'codes']].values), norm=True)

# %%
# what does the distribution for top 20% consumers for these harms look like?
f, axs = plt.subplots(1, 2, figsize=(15, 8))
currpart = ord('A')
partnames = {}
bar_order = ['Benign', 'Financial', 'Healthcare', 'Opportunity', 'Sensitive',
             'Potentially Harmful', 'Potentially Prohibited', 'Clickbait']

global_harm_top_consumers, cont_harm_top_consumers = [], []
percentile_80_global = np.percentile(global_counts, 90)
percentile_80_cont = np.percentile(cont_counts, 90)

for pid in part_order:
    if global_harm_counts[pid] >= percentile_80_global:
        global_harm_top_consumers.append((pid, global_harm_counts[pid]))
        # generate name for this participant
        if pid not in partnames:
            partnames[pid] = chr(currpart)
            currpart += 1
    if cont_harm_counts[pid] >= percentile_80_cont:
        cont_harm_top_consumers.append((pid, cont_harm_counts[pid]))
        if pid not in partnames:
            partnames[pid] = chr(currpart)
            currpart += 1
            
global_harm_top_consumers = sorted(global_harm_top_consumers, key=lambda tup: tup[1], reverse=True)
global_harm_top_consumers = [tup[0] for tup in global_harm_top_consumers]
cont_harm_top_consumers = sorted(cont_harm_top_consumers, key=lambda tup: tup[1], reverse=True)
cont_harm_top_consumers = [tup[0] for tup in cont_harm_top_consumers]

overlap = set(global_harm_top_consumers) & set(cont_harm_top_consumers)
print(f'OVERLAP: {overlap} \n#: {len(overlap)}')

# plot global harms
last = np.zeros(len(global_harm_top_consumers))
for code in bar_order:
#     curr = [part_code_props[p].get(code, 0) for p in global_harm_top_consumers]
    curr = [part_code_counts[p].get(code, 0) for p in global_harm_top_consumers]
            
    errs = None
    axs[1].bar(np.arange(len(curr)), curr, .5, label=code, bottom=last,
              color=analysis_utils.colors[code], alpha=.8, yerr=errs, ecolor=analysis_utils.colors[code])
    last += np.array(curr)
# Out:
# OVERLAP: {'5ae5b7e26735bd0001d7dfe3', '5f786ddd6f28d63e71e631b6', '588623', '5c315f577626080001a88cb2'}
# #: 4

# %% [markdown]
# #### Export fraction of harmful (global + contextual) for regression analysis

# %%
allrows = []
for pid in pids:
    row = [pid, part_ad_counts[pid]]
    # counts
    row.append(global_harm_counts[pid])
    row.append(cont_harm_counts[pid])
    row.append(healthcare_harm_counts[pid])
    # proportions (of all ads)
    row.append(global_harm_counts[pid]/part_ad_counts[pid])
    row.append(cont_harm_counts[pid]/part_ad_counts[pid])
    row.append(healthcare_harm_counts[pid]/part_ad_counts[pid])
    allrows.append(row)
    
df = pd.DataFrame(allrows,
        columns=['pid', 'total_ads', 'global_harm_counts', 'cont_harms_counts', 'healthcare_harm_counts',
                 'global_harm_prop', 'cont_harm_prop', 'healthcare_harm_prop'])
df.to_csv('participant_harm_props.csv', index=False)

# %% [markdown]
# ## Deep-dive into targeting

# %%
top_consumers = sorted(totals.items(), key=lambda x: x[1], reverse=True)[:20]
print(top_consumers)
# Out:
# [('588623', 58), ('805102', 43), ('6130e3db169db34eb3cde8cc', 39), ('981199', 21), ('825119', 17), ('60ee4077cdf4f24a1c607783', 16), ('441420', 15), ('5c315f577626080001a88cb2', 14), ('298154', 12), ('100538', 12), ('636433', 11), ('372771', 11), ('5a349be43e523d000194399e', 10), ('978584', 10), ('557046', 10), ('5f786ddd6f28d63e71e631b6', 9), ('5c4af67cdccaa800016b3192', 9), ('504234', 9), ('597658', 9), ('340465', 8)]

# %%
# who is this person seeing most of harmful and clickbait ads?
# worst_off = part_order[77]
# worst_off = part_order[40]
worst_off = part_order[-1]
print(worst_off)
print(part_code_counts[worst_off])
# Out:
# 372771
# defaultdict(<function count_code_props.<locals>.<lambda> at 0x114fd8820>, {'Opportunity': 5, 'Benign': 4, 'Clickbait': 7, 'Potentially Prohibited': 2, 'Sensitive': 2, 'Potentially Harmful': 4, 'Financial': 3, 'Healthcare': 1})

# %%
joiner = pid_adid[pid_adid['pid'] == worst_off]
joined = joiner.merge(codes, how='inner', left_on='adid', right_on='adid')
 
bad_ads = joined[joined['codes'].str.contains('Clickbait')]
print(bad_ads[['adid', 'codes']])
# Out:
#                  adid                                         codes
# 2   23849560881690267  Clickbait;Opportunity;Potentially Prohibited
# 3   23850023298760020              Clickbait;Potentially Prohibited
# 7   23849417687970082                 Clickbait;Potentially Harmful
# 11  23849528056380733       Clickbait;Financial;Potentially Harmful
# 12  23849379700900691                 Clickbait;Potentially Harmful
# 16  23850044844480427                                     Clickbait
# 17  23849379622490691                 Clickbait;Potentially Harmful

# %%
# questions:
# - how many of these were targeted broadly? when targeted via interests, which ones were picked?

# %%
for adid in bad_ads['adid']:
    print(adid, get_targeting(ad_targetings[str(adid)], adid), '\n')
# Out:
# 23849560881690267 {'id': 23849560881690267, 'age-gender': {'age_min': 6, 'age_max': 53, 'gender': 'ANY'}, 'location': {'loc': 'Nigeria', 'gran': 'country'}}
#
# 23850023298760020 {'id': 23850023298760020, 'age-gender': {'age_min': 8, 'age_max': 46, 'gender': 'ANY'}, 'location': {'loc': 'Nigeria', 'gran': 'country'}}
#
# 23849417687970082 {'id': 23849417687970082, 'age-gender': {'age_min': 8, 'age_max': 38, 'gender': 'ANY'}, 'location': {'loc': 'Nigeria', 'gran': 'country'}}
#
# 23849528056380733 {'id': 23849528056380733, 'age-gender': {'age_min': 8, 'age_max': 33, 'gender': 'ANY'}, 'location': {'loc': 'Nigeria', 'gran': 'country'}}
#
# 23849379700900691 {'id': 23849379700900691, 'age-gender': {'age_min': 6, 'age_max': 53, 'gender': 'ANY'}, 'location': {'loc': 'Nigeria', 'gran': 'country'}}
#
# 23850044844480427 {'id': 23850044844480427, 'age-gender': {'age_min': 8, 'age_max': 38, 'gender': 'ANY'}, 'location': {'loc': 'Nigeria', 'gran': 'country'}}
#
# 23849379622490691 {'id': 23849379622490691, 'custom': True, 'age-gender': {'age_min': 6, 'age_max': 53, 'gender': 'ANY'}, 'location': {'loc': 'Nigeria', 'gran': 'country'}}

# %%
# top consumers of clickbait -- how much of their ads were broadly targeted?
n_interest, n_custom, total = 0, 0, 0
for pid in pids:
    joiner = pid_adid[pid_adid['pid'] == pid]
    joined = joiner.merge(codes, how='inner', left_on='adid', right_on='adid')
#     clickbait = joined[joined['codes'].str.contains('Clickbait|Harmful|Prohibited')]
    clickbait = joined[joined['codes'].str.contains('Benign')]
    
    for adid in clickbait['adid']:
        tar = get_targeting(ad_targetings[str(adid)], adid)        
        print(adid, tar, '\n')
        if 'interests' in tar:
            n_interest += 1            
        if 'custom' in tar:
            n_custom += 1    
        total += 1

n_generic = total - n_interest - n_custom
# Out:
# 23849466337740695 {'id': 23849466337740695, 'custom': True, 'age-gender': {'age_min': 6, 'age_max': 53, 'gender': 'ANY'}, 'location': {'loc': 'the United States', 'gran': 'country'}}
#
# 23849636650270391 {'id': 23849636650270391, 'interests': {'Animal rescue group', 'Cats'}, 'age-gender': {'age_min': 13, 'age_max': 53, 'gender': 'ANY'}, 'location': {'loc': 'the United States', 'gran': 'country'}}
#
# 6258460120302 {'id': 6258460120302, 'interests': {'Dog health', 'Dog food', 'Dog training', 'Dogs'}, 'age-gender': {'age_min': 13, 'age_max': 53, 'gender': 'ANY'}, 'location': {'loc': 'the United States', 'gran': 'country'}}
#
# 23849273567750632 {'id': 23849273567750632, 'interests': {'Lululemon Athletica', 'Motivation', 'Brain'}, 'age-gender': {'age_min': 6, 'age_max': 53, 'gender': 'ANY'}, 'location': {'loc': 'the United States', 'gran': 'country'}}
#
# 6285835302409 {'id': 6285835302409, 'custom': True, 'age-gender': {'age_min': 13, 'age_max': 53, 'gender': 'ANY'}, 'location': {'loc': 'the United States', 'gran': 'country'}}
#
# 6277754462886 {'id': 6277754462886, 'interests': {'Dog food', 'Dogs'}, 'age-gender': {'age_min': 13, 'age_max': 32, 'gender': 'ANY'}, 'location': {'loc': 'Florida', 'gran': 'region'}}
#
# 23849004042630055 {'id': 23849004042630055, 'interests': {'Pets', 'Dog park', 'Dog food', 'Puppy', 'Dog health', 'Pet store', 'Dog walking'}, 'age-gender': {'age_min': 13, 'age_max': 33, 'gender': 'ANY'}, 'location': {'loc': 'the United States', 'gran': 'country'}}
#
# 23849871357850591 {'id': 23849871357850591, 'custom': True, 'age-gender': {'age_min': 6, 'age_max': 53, 'gender': 'ANY'}, 'location': {'loc': 'the United States', 'gran': 'country'}}
#
# 6271415138511 {'id': 6271415138511, 'custom': True, 'age-gender': {'age_min': 6, 'age_max': 53, 'gender': 'ANY'}, 'location': {'loc': 'the United States', 'gran': 'country'}}
#
# 23849314587120294 {'id': 23849314587120294, 'interests': {'Dog grooming', 'Dog park', 'Dog food', 'Dog training', 'Dog health', 'Dog toy', 'Dog walking'}, 'age-gender': {'age_min': 18, 'age_max': 53, 'gender': 'ANY'}, 'location': {'loc': 'the United States', 'gran': 'country'}}
#
# 23849889395830259 {'id': 23849889395830259, 'custom': True, 'age-gender': {'age_min': 13, 'age_max': 43, 'gender': 'ANY'}, 'location': {'loc': 'the United States', 'gran': 'country'}}
#
# 23849363653410372 {'id': 23849363653410372, 'custom': True, 'age-gender': {'age_min': 13, 'age_max': 53, 'gender': 'ANY'}, 'location': {'loc': 'the United States', 'gran': 'country'}}
#
# 6262690340185 {'id': 6262690340185, 'age-gender': {'age_min': 6, 'age_max': 53, 'gender': 'ANY'}, 'location': {'loc': 'the United States', 'gran': 'country'}}
#
# 23849056105670171 {'id': 23849056105670171, 'age-gender': {'age_min': 6, 'age_max': 53, 'gender': 'ANY'}, 'location': {'loc': 'the United States', 'gran': 'country'}}
#
# 23849499785340683 {'id': 23849499785340683, 'interests': {'Dog grooming', 'Pets', 'Pets at Home', 'Dog park', 'Puppy', 'Dog food', 'Dog training', 'Puppy love', 'Dog health', 'Pet store', 'Dog toy', 'Animal shelter', 'Gift', 'Dog walking', 'Pet adoption', 'Rescue dog', 'Cat food', 'Dog breed'}, 'age-gender': {'age_min': 13, 'age_max': 42, 'gender': 'ANY'}, 'location': {'loc': 'the United States', 'gran': 'country'}}
#
# 23849378205150762 {'id': 23849378205150762, 'interests': {'Dog grooming', 'Pets', 'Dog food', 'Puppy', 'Dog training', 'Dog health', 'Pet store', 'Dog toy', 'Animal shelter', 'Pet adoption', 'Rescue dog', 'Cat food'}, 'age-gender': {'age_min': 13, 'age_max': 28, 'gender': 'ANY'}, 'location': {'loc': 'the United States', 'gran': 'country'}}
#
# 23848961949580779 {'id': 23848961949580779, 'custom': True, 'age-gender': {'age_min': 6, 'age_max': 53, 'gender': 'ANY'}, 'location': {'loc': 'the United States', 'gran': 'country'}}
#
# 23849488893900016 {'id': 23849488893900016, 'interests': {'Digital marketing', 'Design', 'Marketing research', 'Market research'}, 'age-gender': {'age_min': 6, 'age_max': 53, 'gender': 'ANY'}, 'location': {'loc': 'the United States', 'gran': 'country'}}
#
# 6263508752383 {'id': 6263508752383, 'age-gender': {'age_min': 6, 'age_max': 22, 'gender': 'ANY'}, 'location': {'loc': 'the United States', 'gran': 'country'}}
#
# 23850186498660495 {'id': 23850186498660495, 'interests': {'Sports and outdoors'}, 'age-gender': {'age_min': 18, 'age_max': 38, 'gender': 'ANY'}, 'location': {'loc': 'Florida', 'gran': 'region'}}
#
# 23849808989450298 {'id': 23849808989450298, 'interests': {'Spas', 'Skin', 'Personal care', 'Beauty salons', 'Online shopping', 'Beauty'}, 'age-gender': {'age_min': 6, 'age_max': 53, 'gender': 'FEMALE'}, 'location': {'loc': 'the United States', 'gran': 'country'}}
#
# 6276717473801 {'id': 6276717473801, 'interests': {'Amazon.com'}, 'age-gender': {'age_min': 6, 'age_max': 53, 'gender': 'ANY'}, 'location': {'loc': 'the United States', 'gran': 'country'}}
#
# 23850003591490536 {'id': 23850003591490536, 'interests': {'Old Navy', 'Celebrity', 'Shopping and fashion', 'Online shopping', 'Market research'}, 'age-gender': {'age_min': 6, 'age_max': 53, 'gender': 'ANY'}, 'location': {'loc': 'the United States', 'gran': 'country'}}
#
# 23849188393730308 {'id': 23849188393730308, 'interests': {'Online shopping', 'Amazon.com'}, 'age-gender': {'age_min': 9, 'age_max': 38, 'gender': 'ANY'}, 'location': {'loc': 'the United States', 'gran': 'country'}}
#
# 23848402723610425 {'id': 23848402723610425, 'interests': {'Platform game'}, 'age-gender': {'age_min': 6, 'age_max': 33, 'gender': 'ANY'}, 'location': {'loc': 'the United States', 'gran': 'country'}}
#
# 23849087696610073 {'id': 23849087696610073, 'age-gender': {'age_min': 6, 'age_max': 23, 'gender': 'ANY'}, 'location': {'loc': 'the United States', 'gran': 'country'}}
#
# 6252919297001 {'id': 6252919297001, 'age-gender': {'age_min': 6, 'age_max': 53, 'gender': 'ANY'}, 'location': {'loc': 'the United States', 'gran': 'country'}}
#
# 23849908038850070 {'id': 23849908038850070, 'age-gender': {'age_min': 6, 'age_max': 32, 'gender': 'ANY'}, 'location': {'loc': 'the United States', 'gran': 'country'}}
#
# 23849064100570289 {'id': 23849064100570289, 'custom': True, 'age-gender': {'age_min': 18, 'age_max': 53, 'gender': 'ANY'}, 'location': {'loc': 'the United States', 'gran': 'country'}}
#
# 6275946655801 {'id': 6275946655801, 'interests': {'Social media marketing', 'Advertising', 'Display advertising', 'Digital marketing', 'Email marketing', 'Online advertising', 'Marketing'}, 'age-gender': {'age_min': 12, 'age_max': 43, 'gender': 'ANY'}, 'location': {'loc': 'the United States', 'gran': 'country'}}
#
# 6275946600001 {'id': 6275946600001, 'interests': {'Business-to-business', 'Social media marketing', 'Advertising', 'Display advertising', 'Digital marketing', 'Email marketing', 'Online advertising', 'Marketing'}, 'age-gender': {'age_min': 12, 'age_max': 43, 'gender': 'ANY'}, 'location': {'loc': 'the United States', 'gran': 'country'}}
#
# 23849394909420713 {'id': 23849394909420713, 'custom': True, 'age-gender': {'age_min': 6, 'age_max': 53, 'gender': 'ANY'}, 'location': {'loc': 'Florida', 'gran': 'region'}}
#
# 23849385805100452 {'id': 23849385805100452, 'age-gender': {'age_min': 6, 'age_max': 42, 'gender': 'ANY'}, 'location': {'loc': 'Florida', 'gran': 'region'}}
#
# 23849385805100452 {'id': 23849385805100452, 'age-gender': {'age_min': 6, 'age_max': 42, 'gender': 'ANY'}, 'location': {'loc': 'Florida', 'gran': 'region'}}
#
# 23848393780970425 {'id': 23848393780970425, 'interests': {'Platform game'}, 'age-gender': {'age_min': 6, 'age_max': 33, 'gender': 'ANY'}, 'location': {'loc': 'the United States', 'gran': 'country'}}
#
# 23849580875890015 {'id': 23849580875890015, 'custom': True, 'age-gender': {'age_min': 6, 'age_max': 53, 'gender': 'ANY'}, 'location': {'loc': 'the United States', 'gran': 'country'}}
#
# 23849737153490579 {'id': 23849737153490579, 'interests': {'Pets at Home', 'Dog park', 'Dog training', 'Puppy love', 'Dog health', 'Organic farming', 'honest kitchen', 'Raw feeding'}, 'age-gender': {'age_min': 12, 'age_max': 53, 'gender': 'ANY'}, 'location': {'loc': 'the United States', 'gran': 'country'}}
#
# 23849177320850375 {'id': 23849177320850375, 'interests': {'Investment', 'Personal finance'}, 'age-gender': {'age_min': 6, 'age_max': 18, 'gender': 'ANY'}, 'location': {'loc': 'the United States', 'gran': 'country'}}
#
# 6284722470088 {'id': 6284722470088, 'interests': {'Dog grooming', 'Pets', 'Pets at Home', 'Dog park', 'Dog food', 'Puppy', 'Dog training', 'Puppy love', 'Dog health', 'Pet store', 'Dog toy', 'Dog walking', 'Pet adoption', 'Rescue dog', 'Cat food'}, 'age-gender': {'age_min': 13, 'age_max': 53, 'gender': 'ANY'}, 'location': {'loc': 'Cape Coral, Florida', 'gran': 'city'}}
#
# 6265841165104 {'id': 6265841165104, 'interests': {'Drop shipping', 'Reseller'}, 'age-gender': {'age_min': 13, 'age_max': 43, 'gender': 'ANY'}, 'location': {'loc': 'the United States', 'gran': 'country'}}
#
# 23849148147430132 {'id': 23849148147430132, 'age-gender': {'age_min': 6, 'age_max': 23, 'gender': 'ANY'}, 'location': {'loc': 'the United States', 'gran': 'country'}}
#
# 23849353057020411 {'id': 23849353057020411, 'interests': {'Pets'}, 'age-gender': {'age_min': 10, 'age_max': 48, 'gender': 'ANY'}, 'location': {'loc': 'Florida', 'gran': 'region'}}
#
# 23849181800790690 {'id': 23849181800790690, 'age-gender': {'age_min': 6, 'age_max': 53, 'gender': 'ANY'}, 'location': {'loc': 'the United States', 'gran': 'country'}}
#
# 23849197033780373 {'id': 23849197033780373, 'interests': {'Online shopping', 'Beauty'}, 'age-gender': {'age_min': 6, 'age_max': 53, 'gender': 'ANY'}, 'location': {'loc': 'the United States', 'gran': 'country'}}
#
# 23849110597310132 {'id': 23849110597310132, 'age-gender': {'age_min': 13, 'age_max': 42, 'gender': 'ANY'}, 'location': {'loc': 'the United States', 'gran': 'country'}}
#
# 6266847794087 {'id': 6266847794087, 'age-gender': {'age_min': 13, 'age_max': 43, 'gender': 'ANY'}, 'location': {'loc': 'the United States', 'gran': 'country'}}
#
# 23848919785960638 {'id': 23848919785960638, 'interests': {'Digital marketing', 'Canva', 'Social media marketing'}, 'age-gender': {'age_min': 6, 'age_max': 28, 'gender': 'ANY'}, 'location': {'loc': 'the United States', 'gran': 'country'}}
#
# 6242814886105 {'id': 6242814886105, 'interests': {'Dog training'}, 'age-gender': {'age_min': 10, 'age_max': 48, 'gender': 'FEMALE'}, 'location': {'loc': 'the United States', 'gran': 'country'}}
#
# 23849162557460151 {'id': 23849162557460151, 'age-gender': {'age_min': 9, 'age_max': 53, 'gender': 'FEMALE'}, 'location': {'loc': 'the United States', 'gran': 'country'}}
#
# 23849504789020782 {'id': 23849504789020782, 'interests': {'Advertising agency', 'Online advertising'}, 'age-gender': {'age_min': 12, 'age_max': 38, 'gender': 'ANY'}, 'location': {'loc': 'the United States', 'gran': 'country'}}
#
# 23849506642970282 {'id': 23849506642970282, 'interests': {'Dog walking'}, 'age-gender': {'age_min': 12, 'age_max': 53, 'gender': 'ANY'}, 'location': {'loc': 'the United States', 'gran': 'country'}}
#
# 23848621200210733 {'id': 23848621200210733, 'age-gender': {'age_min': 6, 'age_max': 53, 'gender': 'ANY'}, 'location': {'loc': 'the United States', 'gran': 'country'}}
#
# 6273146350667 {'id': 6273146350667, 'age-gender': {'age_min': 8, 'age_max': 53, 'gender': 'ANY'}, 'location': {'loc': 'the United States', 'gran': 'country'}}
#
# 23848460308600646 {'id': 23848460308600646, 'interests': {'Yahoo! Finance'}, 'age-gender': {'age_min': 6, 'age_max': 53, 'gender': 'ANY'}, 'location': {'loc': 'the United States', 'gran': 'country'}}
#
# 23849667559670411 {'id': 23849667559670411, 'age-gender': {'age_min': 10, 'age_max': 48, 'gender': 'ANY'}, 'location': {'loc': 'Florida', 'gran': 'region'}}
#
# 23849245483060166 {'id': 23849245483060166, 'age-gender': {'age_min': 18, 'age_max': 53, 'gender': 'ANY'}, 'location': {'loc': 'the United States', 'gran': 'country'}}
#
# 23849073801630073 {'id': 23849073801630073, 'interests': {'Out (magazine)'}, 'age-gender': {'age_min': 6, 'age_max': 24, 'gender': 'ANY'}, 'location': {'loc': 'the United States', 'gran': 'country'}}
#
# 23850318559560133 {'id': 23850318559560133, 'age-gender': {'age_min': 18, 'age_max': 43, 'gender': 'ANY'}, 'location': {'loc': 'the United States', 'gran': 'country'}}
#
# 23849747157030695 {'id': 23849747157030695, 'age-gender': {'age_min': 10, 'age_max': 38, 'gender': 'ANY'}, 'location': {'loc': 'Florida', 'gran': 'region'}}
#
# 23849882874540340 {'id': 23849882874540340, 'age-gender': {'age_min': 13, 'age_max': 38, 'gender': 'ANY'}, 'location': {'loc': 'the United States', 'gran': 'country'}}
#
# 23849452450700151 {'id': 23849452450700151, 'interests': {'Advertising campaign', 'Advertising agency', 'LinkedIn'}, 'age-gender': {'age_min': 13, 'age_max': 38, 'gender': 'ANY'}, 'location': {'loc': 'the United States', 'gran': 'country'}}
#
# 23849578657940611 {'id': 23849578657940611, 'interests': {'Pet food', 'Cat food', 'Dog food'}, 'age-gender': {'age_min': 6, 'age_max': 53, 'gender': 'ANY'}, 'location': {'loc': 'Cape Coral, Florida', 'gran': 'city'}}
#
# 23849399991540305 {'id': 23849399991540305, 'age-gender': {'age_min': 6, 'age_max': 53, 'gender': 'ANY'}, 'location': {'loc': 'Florida', 'gran': 'region'}}
#
# 23849683490510683 {'id': 23849683490510683, 'interests': {'Dog grooming', 'Pets', 'Pets at Home', 'Dog park', 'Puppy', 'Dog food', 'Dog training', 'Puppy love', 'Dog health', 'Pet store', 'Dog toy', 'Animal shelter', 'Dog walking', 'Pet adoption', 'Rescue dog', 'Cat food', 'Dog breed'}, 'age-gender': {'age_min': 13, 'age_max': 42, 'gender': 'ANY'}, 'location': {'loc': 'the United States', 'gran': 'country'}}
#
# 23850243942540587 {'id': 23850243942540587, 'age-gender': {'age_min': 13, 'age_max': 32, 'gender': 'ANY'}, 'location': {'loc': 'the United States', 'gran': 'country'}}
#
# 23849931818340540 {'id': 23849931818340540, 'interests': {'Home'}, 'age-gender': {'age_min': 6, 'age_max': 53, 'gender': 'ANY'}, 'location': {'loc': 'South Carolina', 'gran': 'region'}}
#
# 23849735416800077 {'id': 23849735416800077, 'interests': {'Cooking'}, 'age-gender': {'age_min': 6, 'age_max': 53, 'gender': 'ANY'}, 'location': {'loc': 'the United States', 'gran': 'country'}}
#
# 23849620169850523 {'id': 23849620169850523, 'interests': {'Puppy', 'Dog food', 'Pet food', 'Dog training', 'Dog health', 'Pet store', 'Cat food', 'Animal shelter', 'Dog toy', 'Dogs', 'Pet adoption', 'Rescue dog', 'Cats'}, 'age-gender': {'age_min': 13, 'age_max': 53, 'gender': 'ANY'}, 'location': {'loc': 'the United States', 'gran': 'country'}}
#
# 23849442089890588 {'id': 23849442089890588, 'age-gender': {'age_min': 6, 'age_max': 28, 'gender': 'ANY'}, 'location': {'loc': 'the United States', 'gran': 'country'}}
#
# 23849731785550125 {'id': 23849731785550125, 'custom': True, 'age-gender': {'age_min': 8, 'age_max': 53, 'gender': 'ANY'}, 'location': {'loc': 'the United States', 'gran': 'country'}}
#
# 23849347114400334 {'id': 23849347114400334, 'custom': True, 'age-gender': {'age_min': 6, 'age_max': 37, 'gender': 'ANY'}, 'location': {'loc': 'the United States', 'gran': 'country'}}
#
# 23849332388890132 {'id': 23849332388890132, 'age-gender': {'age_min': 6, 'age_max': 30, 'gender': 'ANY'}, 'location': {'loc': 'Florida', 'gran': 'region'}}
#
# 23849547393320452 {'id': 23849547393320452, 'age-gender': {'age_min': 6, 'age_max': 48, 'gender': 'ANY'}, 'location': {'loc': 'the United States', 'gran': 'country'}}
#
# 23849600046000660 {'id': 23849600046000660, 'age-gender': {'age_min': 13, 'age_max': 53, 'gender': 'ANY'}, 'location': {'loc': 'the United States', 'gran': 'country'}}
#
# 23849544992920607 {'id': 23849544992920607, 'custom': True, 'age-gender': {'age_min': 6, 'age_max': 42, 'gender': 'ANY'}, 'location': {'loc': 'the United States', 'gran': 'country'}}
#
# 23849635017310061 {'id': 23849635017310061, 'age-gender': {'age_min': 6, 'age_max': 53, 'gender': 'ANY'}, 'location': {'loc': 'Cape Coral, Florida', 'gran': 'city'}}
#
# 23849908429210595 {'id': 23849908429210595, 'interests': {'Air fryer', 'Washing machine', 'Frying'}, 'age-gender': {'age_min': 6, 'age_max': 18, 'gender': 'ANY'}, 'location': {'loc': 'the United States', 'gran': 'country'}}
#
# 23849325897410166 {'id': 23849325897410166, 'age-gender': {'age_min': 18, 'age_max': 53, 'gender': 'ANY'}, 'location': {'loc': 'the United States', 'gran': 'country'}}
#
# 23850339796860133 {'id': 23850339796860133, 'age-gender': {'age_min': 6, 'age_max': 53, 'gender': 'FEMALE'}, 'location': {'loc': 'the United States', 'gran': 'country'}}
#
# 23849708261200762 {'id': 23849708261200762, 'interests': {'Dog grooming', 'Pets', 'Dog food', 'Puppy', 'Dog training', 'Dog health', 'Pet store', 'Dog toy', 'Animal shelter', 'Pet adoption', 'Rescue dog', 'Cat food'}, 'age-gender': {'age_min': 13, 'age_max': 28, 'gender': 'ANY'}, 'location': {'loc': 'the United States', 'gran': 'country'}}
#
# 23849676649340104 {'id': 23849676649340104, 'custom': True, 'age-gender': {'age_min': 6, 'age_max': 53, 'gender': 'ANY'}, 'location': {'loc': 'the United States', 'gran': 'country'}}
#
# 23849450332550722 {'id': 23849450332550722, 'age-gender': {'age_min': 6, 'age_max': 53, 'gender': 'ANY'}, 'location': {'loc': 'Florida', 'gran': 'region'}}
#
# 23849720153560554 {'id': 23849720153560554, 'age-gender': {'age_min': 14, 'age_max': 32, 'gender': 'FEMALE'}, 'location': {'loc': 'the United States', 'gran': 'country'}}
#
# 23849755979420683 {'id': 23849755979420683, 'interests': {'Pets', 'Humane society', 'Dog breed'}, 'age-gender': {'age_min': 13, 'age_max': 42, 'gender': 'ANY'}, 'location': {'loc': 'the United States', 'gran': 'country'}}
#
# 23849326297360166 {'id': 23849326297360166, 'age-gender': {'age_min': 18, 'age_max': 53, 'gender': 'ANY'}, 'location': {'loc': 'the United States', 'gran': 'country'}}
#
# 23849628773390551 {'id': 23849628773390551, 'interests': {'Sustainability', 'Mobile app'}, 'age-gender': {'age_min': 6, 'age_max': 48, 'gender': 'ANY'}, 'location': {'loc': 'the United States', 'gran': 'country'}}
#
# 23849676217140579 {'id': 23849676217140579, 'interests': {'Pets at Home', 'Dog park', 'Dog training', 'Puppy love', 'Dog health', 'Organic farming', 'honest kitchen', 'Raw feeding'}, 'age-gender': {'age_min': 12, 'age_max': 53, 'gender': 'ANY'}, 'location': {'loc': 'the United States', 'gran': 'country'}}
#
# 23849839871310298 {'id': 23849839871310298, 'age-gender': {'age_min': 6, 'age_max': 53, 'gender': 'ANY'}, 'location': {'loc': 'the United States', 'gran': 'country'}}
#
# 23849414791260412 {'id': 23849414791260412, 'age-gender': {'age_min': 6, 'age_max': 42, 'gender': 'ANY'}, 'location': {'loc': 'Cape Coral, Florida', 'gran': 'city'}}
#
# 23850367136460133 {'id': 23850367136460133, 'age-gender': {'age_min': 14, 'age_max': 43, 'gender': 'ANY'}, 'location': {'loc': 'the United States', 'gran': 'country'}}
#
# 23849535024490452 {'id': 23849535024490452, 'age-gender': {'age_min': 6, 'age_max': 48, 'gender': 'ANY'}, 'location': {'loc': 'the United States', 'gran': 'country'}}
#
# 6242765374576 {'id': 6242765374576, 'age-gender': {'age_min': 9, 'age_max': 53, 'gender': 'ANY'}, 'location': {'loc': 'Texas', 'gran': 'region'}}
#
# 6262969197714 {'id': 6262969197714, 'age-gender': {'age_min': 6, 'age_max': 53, 'gender': 'ANY'}, 'location': {'loc': 'Crystal, Minnesota', 'gran': 'city'}}
#
# 23849441672710413 {'id': 23849441672710413, 'age-gender': {'age_min': 6, 'age_max': 53, 'gender': 'ANY'}, 'location': {'loc': 'the United States', 'gran': 'country'}}
#
# 23849478556750548 {'id': 23849478556750548, 'age-gender': {'age_min': 6, 'age_max': 53, 'gender': 'ANY'}, 'location': {'loc': 'the United States', 'gran': 'country'}}
#
# 23849321191020365 {'id': 23849321191020365, 'custom': True, 'age-gender': {'age_min': 6, 'age_max': 53, 'gender': 'ANY'}, 'location': {'loc': 'Crystal, Minnesota', 'gran': 'city'}}
#
# 6285408012045 {'id': 6285408012045, 'age-gender': {'age_min': 9, 'age_max': 52, 'gender': 'ANY'}, 'location': {'loc': 'Crystal, Minnesota', 'gran': 'city'}}
#
# 23849374712790548 {'id': 23849374712790548, 'age-gender': {'age_min': 6, 'age_max': 53, 'gender': 'ANY'}, 'location': {'loc': 'the United States', 'gran': 'country'}}
#
# 23849298923700235 {'id': 23849298923700235, 'age-gender': {'age_min': 6, 'age_max': 53, 'gender': 'ANY'}, 'location': {'loc': 'the United States', 'gran': 'country'}}
#
# 23849455740010496 {'id': 23849455740010496, 'custom': True, 'age-gender': {'age_min': 13, 'age_max': 53, 'gender': 'ANY'}, 'location': {'loc': 'Wake Forest, North Carolina', 'gran': 'city'}}
#
# 23849645962100483 {'id': 23849645962100483, 'custom': True, 'age-gender': {'age_min': 6, 'age_max': 53, 'gender': 'ANY'}, 'location': {'loc': 'the United States', 'gran': 'country'}}
#
# 23849322817790507 {'id': 23849322817790507, 'custom': True, 'age-gender': {'age_min': 6, 'age_max': 53, 'gender': 'FEMALE'}, 'location': {'loc': 'the United States', 'gran': 'country'}}
#
# 23850968483830287 {'id': 23850968483830287, 'custom': True, 'age-gender': {'age_min': 6, 'age_max': 53, 'gender': 'ANY'}, 'location': {'loc': 'the United States', 'gran': 'country'}}
#
# 23850391937700426 {'id': 23850391937700426, 'interests': {'Pet adoption', 'Pets', 'Cat food', 'Dog food'}, 'age-gender': {'age_min': 13, 'age_max': 53, 'gender': 'ANY'}, 'location': {'loc': 'the United States', 'gran': 'country'}}
#
# 23849569860290713 {'id': 23849569860290713, 'custom': True, 'age-gender': {'age_min': 6, 'age_max': 53, 'gender': 'ANY'}, 'location': {'loc': 'North Carolina', 'gran': 'region'}}
#
# 23849551848720713 {'id': 23849551848720713, 'age-gender': {'age_min': 6, 'age_max': 53, 'gender': 'ANY'}, 'location': {'loc': 'Rolesville, North Carolina', 'gran': 'city'}}
#
# 23849538375910019 {'id': 23849538375910019, 'interests': {'Health & wellness'}, 'age-gender': {'age_min': 6, 'age_max': 53, 'gender': 'ANY'}, 'location': {'loc': 'the United States', 'gran': 'country'}}
#
# 23849490528450449 {'id': 23849490528450449, 'custom': True, 'age-gender': {'age_min': 6, 'age_max': 53, 'gender': 'ANY'}, 'location': {'loc': 'the United States', 'gran': 'country'}}
#
# 23849956180040591 {'id': 23849956180040591, 'custom': True, 'age-gender': {'age_min': 6, 'age_max': 53, 'gender': 'FEMALE'}, 'location': {'loc': 'the United States', 'gran': 'country'}}
#
# 23850968486540287 {'id': 23850968486540287, 'custom': True, 'age-gender': {'age_min': 6, 'age_max': 53, 'gender': 'ANY'}, 'location': {'loc': 'the United States', 'gran': 'country'}}
#
# 23850105735250666 {'id': 23850105735250666, 'custom': True, 'age-gender': {'age_min': 6, 'age_max': 53, 'gender': 'FEMALE'}, 'location': {'loc': 'the United States', 'gran': 'country'}}
#
# 23849326281400166 {'id': 23849326281400166, 'age-gender': {'age_min': 18, 'age_max': 53, 'gender': 'ANY'}, 'location': {'loc': 'the United States', 'gran': 'country'}}
#
# 23849712872350713 {'id': 23849712872350713, 'interests': {'Renting'}, 'age-gender': {'age_min': 6, 'age_max': 53, 'gender': 'ANY'}, 'location': {'loc': 'California', 'gran': 'region'}}
#
# 23849654151450508 {'id': 23849654151450508, 'age-gender': {'age_min': 8, 'age_max': 43, 'gender': 'ANY'}, 'location': {'loc': 'the United States', 'gran': 'country'}}
#
# 23849712872520713 {'id': 23849712872520713, 'interests': {'Renting'}, 'age-gender': {'age_min': 6, 'age_max': 53, 'gender': 'ANY'}, 'location': {'loc': 'Texas', 'gran': 'region'}}
#
# 23849647006380528 {'id': 23849647006380528, 'interests': {'Probiotic'}, 'age-gender': {'age_min': 6, 'age_max': 38, 'gender': 'ANY'}, 'location': {'loc': 'Anaheim, California', 'gran': 'city'}}
#
# 6272216280721 {'id': 6272216280721, 'custom': True, 'age-gender': {'age_min': 6, 'age_max': 53, 'gender': 'FEMALE'}, 'location': {'loc': 'the United States', 'gran': 'country'}}
#
# 23848646787860273 {'id': 23848646787860273, 'age-gender': {'age_min': 9, 'age_max': 38, 'gender': 'ANY'}, 'location': {'loc': 'the United States', 'gran': 'country'}}
#
# 23848734352550048 {'id': 23848734352550048, 'custom': True, 'age-gender': {'age_min': 6, 'age_max': 53, 'gender': 'ANY'}, 'location': {'loc': 'the United States', 'gran': 'country'}}
#
# 23848706118400607 {'id': 23848706118400607, 'age-gender': {'age_min': 6, 'age_max': 53, 'gender': 'ANY'}, 'location': {'loc': 'Lubbock, Texas', 'gran': 'city'}}
#
# 23848706118400607 {'id': 23848706118400607, 'age-gender': {'age_min': 6, 'age_max': 53, 'gender': 'ANY'}, 'location': {'loc': 'Lubbock, Texas', 'gran': 'city'}}
#
# 23849017137840235 {'id': 23849017137840235, 'custom': True, 'age-gender': {'age_min': 6, 'age_max': 53, 'gender': 'ANY'}, 'location': {'loc': 'the United States', 'gran': 'country'}}
#
# 23848754373680420 {'id': 23848754373680420, 'age-gender': {'age_min': 6, 'age_max': 53, 'gender': 'ANY'}, 'location': {'loc': 'the United States', 'gran': 'country'}}
#
# 23849254345680365 {'id': 23849254345680365, 'age-gender': {'age_min': 6, 'age_max': 53, 'gender': 'FEMALE'}, 'location': {'loc': 'the United States', 'gran': 'country'}}
#
# 23849157985940311 {'id': 23849157985940311, 'custom': True, 'age-gender': {'age_min': 6, 'age_max': 53, 'gender': 'ANY'}, 'location': {'loc': 'the United States', 'gran': 'country'}}
#
# 6245186351788 {'id': 6245186351788, 'age-gender': {'age_min': 6, 'age_max': 53, 'gender': 'FEMALE'}, 'location': {'loc': 'the United States', 'gran': 'country'}}
#
# 6258183763387 {'id': 6258183763387, 'interests': {'Food and drink'}, 'age-gender': {'age_min': 6, 'age_max': 22, 'gender': 'FEMALE'}, 'location': {'loc': 'the United States', 'gran': 'country'}}
#
# 23848592796950724 {'id': 23848592796950724, 'age-gender': {'age_min': 6, 'age_max': 53, 'gender': 'ANY'}, 'location': {'loc': 'the United States', 'gran': 'country'}}
#
# 23848814990770420 {'id': 23848814990770420, 'age-gender': {'age_min': 6, 'age_max': 53, 'gender': 'ANY'}, 'location': {'loc': 'the United States', 'gran': 'country'}}
#
# 23849619323790579 {'id': 23849619323790579, 'age-gender': {'age_min': 13, 'age_max': 53, 'gender': 'FEMALE'}, 'location': {'loc': 'the United States', 'gran': 'country'}}
#
# 6260870762447 {'id': 6260870762447, 'age-gender': {'age_min': 6, 'age_max': 53, 'gender': 'FEMALE'}, 'location': {'loc': 'the United States', 'gran': 'country'}}
#
# 23848701897650261 {'id': 23848701897650261, 'custom': True, 'age-gender': {'age_min': 6, 'age_max': 53, 'gender': 'ANY'}, 'location': {'loc': 'the United States', 'gran': 'country'}}
#
# 6265929342259 {'id': 6265929342259, 'age-gender': {'age_min': 9, 'age_max': 53, 'gender': 'ANY'}, 'location': {'loc': 'the United States', 'gran': 'country'}}
#
# 23849252451220661 {'id': 23849252451220661, 'custom': True, 'age-gender': {'age_min': 6, 'age_max': 53, 'gender': 'FEMALE'}, 'location': {'loc': 'the United States', 'gran': 'country'}}
#
# 23848568547400724 {'id': 23848568547400724, 'age-gender': {'age_min': 6, 'age_max': 53, 'gender': 'ANY'}, 'location': {'loc': 'the United States', 'gran': 'country'}}
#
# 6258125474499 {'id': 6258125474499, 'age-gender': {'age_min': 6, 'age_max': 33, 'gender': 'FEMALE'}, 'location': {'loc': 'the United States', 'gran': 'country'}}
#
# 23848652755360724 {'id': 23848652755360724, 'custom': True, 'age-gender': {'age_min': 6, 'age_max': 53, 'gender': 'ANY'}, 'location': {'loc': 'the United States', 'gran': 'country'}}
#
# 23848613760370471 {'id': 23848613760370471, 'age-gender': {'age_min': 6, 'age_max': 43, 'gender': 'FEMALE'}, 'location': {'loc': 'Lubbock, Texas', 'gran': 'city'}}
#
# 6245572593976 {'id': 6245572593976, 'age-gender': {'age_min': 6, 'age_max': 53, 'gender': 'ANY'}, 'location': {'loc': 'the United States', 'gran': 'country'}}
#
# 23849095620060373 {'id': 23849095620060373, 'age-gender': {'age_min': 6, 'age_max': 53, 'gender': 'FEMALE'}, 'location': {'loc': 'the United States', 'gran': 'country'}}
#
# 6242255996105 {'id': 6242255996105, 'custom': True, 'age-gender': {'age_min': 6, 'age_max': 48, 'gender': 'FEMALE'}, 'location': {'loc': 'the United States', 'gran': 'country'}}
#
# 6269566859772 {'id': 6269566859772, 'age-gender': {'age_min': 6, 'age_max': 42, 'gender': 'FEMALE'}, 'location': {'loc': 'the United States', 'gran': 'country'}}
#
# 6265197811612 {'id': 6265197811612, 'age-gender': {'age_min': 6, 'age_max': 43, 'gender': 'ANY'}, 'location': {'loc': 'the United States', 'gran': 'country'}}
#
# 6247235873376 {'id': 6247235873376, 'age-gender': {'age_min': 6, 'age_max': 53, 'gender': 'ANY'}, 'location': {'loc': 'the United States', 'gran': 'country'}}
#
# 6271242212921 {'id': 6271242212921, 'custom': True, 'age-gender': {'age_min': 6, 'age_max': 53, 'gender': 'ANY'}, 'location': {'loc': 'the United States', 'gran': 'country'}}
#
# 23848878768010228 {'id': 23848878768010228, 'age-gender': {'age_min': 6, 'age_max': 43, 'gender': 'FEMALE'}, 'location': {'loc': 'the United States', 'gran': 'country'}}
#
# 23848675411950235 {'id': 23848675411950235, 'custom': True, 'age-gender': {'age_min': 6, 'age_max': 53, 'gender': 'ANY'}, 'location': {'loc': 'the United States', 'gran': 'country'}}
#
# 6279030185534 {'id': 6279030185534, 'custom': True, 'age-gender': {'age_min': 6, 'age_max': 52, 'gender': 'FEMALE'}}
#
# 6278172788820 {'id': 6278172788820, 'custom': True, 'age-gender': {'age_min': 9, 'age_max': 53, 'gender': 'ANY'}, 'location': {'loc': 'the United States', 'gran': 'country'}}
#
# 23848959726950235 {'id': 23848959726950235, 'custom': True, 'age-gender': {'age_min': 6, 'age_max': 53, 'gender': 'ANY'}, 'location': {'loc': 'the United States', 'gran': 'country'}}
#
# 23848643118830724 {'id': 23848643118830724, 'age-gender': {'age_min': 6, 'age_max': 53, 'gender': 'ANY'}, 'location': {'loc': 'the United States', 'gran': 'country'}}
#
# 6269153706788 {'id': 6269153706788, 'custom': True, 'age-gender': {'age_min': 6, 'age_max': 53, 'gender': 'ANY'}, 'location': {'loc': 'the United States', 'gran': 'country'}}
#
# 23849114520160759 {'id': 23849114520160759, 'age-gender': {'age_min': 6, 'age_max': 32, 'gender': 'ANY'}, 'location': {'loc': 'the United States', 'gran': 'country'}}
#
# 6286451690220 {'id': 6286451690220, 'age-gender': {'age_min': 9, 'age_max': 53, 'gender': 'ANY'}, 'location': {'loc': 'the United States', 'gran': 'country'}}
#
# 6275816212366 {'id': 6275816212366, 'age-gender': {'age_min': 6, 'age_max': 53, 'gender': 'FEMALE'}, 'location': {'loc': 'the United States', 'gran': 'country'}}
#
# 23848493878510352 {'id': 23848493878510352, 'custom': True, 'age-gender': {'age_min': 6, 'age_max': 28, 'gender': 'ANY'}, 'location': {'loc': 'the United States', 'gran': 'country'}}
#
# 23848615362650352 {'id': 23848615362650352, 'custom': True, 'age-gender': {'age_min': 6, 'age_max': 48, 'gender': 'ANY'}, 'location': {'loc': 'the United States', 'gran': 'country'}}
#
# 23848682564320724 {'id': 23848682564320724, 'age-gender': {'age_min': 6, 'age_max': 53, 'gender': 'ANY'}, 'location': {'loc': 'the United States', 'gran': 'country'}}
#
# 6276798698220 {'id': 6276798698220, 'custom': True, 'age-gender': {'age_min': 9, 'age_max': 53, 'gender': 'ANY'}, 'location': {'loc': 'the United States', 'gran': 'country'}}
#
# 6257672321187 {'id': 6257672321187, 'interests': {'Food and drink'}, 'age-gender': {'age_min': 6, 'age_max': 22, 'gender': 'FEMALE'}, 'location': {'loc': 'the United States', 'gran': 'country'}}
#
# 23848494069560352 {'id': 23848494069560352, 'custom': True, 'age-gender': {'age_min': 13, 'age_max': 33, 'gender': 'ANY'}, 'location': {'loc': 'the United States', 'gran': 'country'}}
#
# 23849240466540374 {'id': 23849240466540374, 'custom': True, 'age-gender': {'age_min': 6, 'age_max': 53, 'gender': 'ANY'}, 'location': {'loc': 'the United States', 'gran': 'country'}}
#
# 23848519180300261 {'id': 23848519180300261, 'custom': True, 'age-gender': {'age_min': 6, 'age_max': 53, 'gender': 'ANY'}, 'location': {'loc': 'the United States', 'gran': 'country'}}
#
# 23848613057090352 {'id': 23848613057090352, 'custom': True, 'age-gender': {'age_min': 6, 'age_max': 48, 'gender': 'ANY'}, 'location': {'loc': 'the United States', 'gran': 'country'}}
#
# 6289094580620 {'id': 6289094580620, 'age-gender': {'age_min': 9, 'age_max': 53, 'gender': 'ANY'}, 'location': {'loc': 'the United States', 'gran': 'country'}}
#
# 6274797384851 {'id': 6274797384851, 'age-gender': {'age_min': 10, 'age_max': 43, 'gender': 'ANY'}, 'location': {'loc': 'Texas', 'gran': 'region'}}
#
# 23848813798360467 {'id': 23848813798360467, 'age-gender': {'age_min': 6, 'age_max': 53, 'gender': 'FEMALE'}, 'location': {'loc': 'the United States', 'gran': 'country'}}
#
# 23849231741470525 {'id': 23849231741470525, 'age-gender': {'age_min': 13, 'age_max': 53, 'gender': 'FEMALE'}, 'location': {'loc': 'the United States', 'gran': 'country'}}
#
# 23848775680060420 {'id': 23848775680060420, 'custom': True, 'age-gender': {'age_min': 6, 'age_max': 53, 'gender': 'ANY'}, 'location': {'loc': 'the United States', 'gran': 'country'}}
#
# 23849234828740365 {'id': 23849234828740365, 'age-gender': {'age_min': 6, 'age_max': 53, 'gender': 'FEMALE'}, 'location': {'loc': 'the United States', 'gran': 'country'}}
#
# 23849367891600104 {'id': 23849367891600104, 'age-gender': {'age_min': 13, 'age_max': 32, 'gender': 'ANY'}, 'location': {'loc': 'the United States', 'gran': 'country'}}
#
# 6270315753188 {'id': 6270315753188, 'age-gender': {'age_min': 6, 'age_max': 53, 'gender': 'FEMALE'}, 'location': {'loc': 'the United States', 'gran': 'country'}}
#
# 6262526380893 {'id': 6262526380893, 'age-gender': {'age_min': 12, 'age_max': 53, 'gender': 'ANY'}, 'location': {'loc': 'the United States', 'gran': 'country'}}
#
# 23849088925240572 {'id': 23849088925240572, 'age-gender': {'age_min': 6, 'age_max': 48, 'gender': 'ANY'}, 'location': {'loc': 'Texas', 'gran': 'region'}}
#
# 23848974514090162 {'id': 23848974514090162, 'interests': {'Sunglasses', 'Glasses'}, 'age-gender': {'age_min': 13, 'age_max': 42, 'gender': 'ANY'}, 'location': {'loc': 'the United States', 'gran': 'country'}}
#
# 23849127846670471 {'id': 23849127846670471, 'age-gender': {'age_min': 6, 'age_max': 43, 'gender': 'FEMALE'}, 'location': {'loc': 'Lubbock, Texas', 'gran': 'city'}}
#
# 23849591839720413 {'id': 23849591839720413, 'custom': True, 'age-gender': {'age_min': 6, 'age_max': 52, 'gender': 'ANY'}, 'location': {'loc': 'the United States', 'gran': 'country'}}
#
# 23849663624160365 {'id': 23849663624160365, 'age-gender': {'age_min': 6, 'age_max': 53, 'gender': 'FEMALE'}, 'location': {'loc': 'the United States', 'gran': 'country'}}
#
# 23849330616880235 {'id': 23849330616880235, 'interests': {'Chanel', 'Anthropologie', 'Fitness and wellness', 'Louis Vuitton', 'Tory Burch', 'Estée Lauder Companies', 'Michael Kors', 'Kate Spade', 'Saks Fifth Avenue', 'Gucci', 'Clinique', 'Nordstrom'}, 'age-gender': {'age_min': 6, 'age_max': 53, 'gender': 'ANY'}, 'location': {'loc': 'the United States', 'gran': 'country'}}
#
# 23849021892160235 {'id': 23849021892160235, 'age-gender': {'age_min': 6, 'age_max': 53, 'gender': 'ANY'}, 'location': {'loc': 'the United States', 'gran': 'country'}}
#
# 23849015525300030 {'id': 23849015525300030, 'interests': {'National Football League'}, 'age-gender': {'age_min': 6, 'age_max': 53, 'gender': 'MALE'}, 'location': {'loc': 'the United States', 'gran': 'country'}}
#
# 6275116610686 {'id': 6275116610686, 'custom': True, 'age-gender': {'age_min': 6, 'age_max': 53, 'gender': 'ANY'}, 'location': {'loc': 'the United States', 'gran': 'country'}}
#
# 23847900196500112 {'id': 23847900196500112, 'age-gender': {'age_min': 9, 'age_max': 32, 'gender': 'ANY'}, 'location': {'loc': 'the United States', 'gran': 'country'}}
#
# 23848916279400658 {'id': 23848916279400658, 'age-gender': {'age_min': 13, 'age_max': 38, 'gender': 'ANY'}, 'location': {'loc': 'the United States', 'gran': 'country'}}
#
# 23849245852970041 {'id': 23849245852970041, 'custom': True, 'age-gender': {'age_min': 6, 'age_max': 53, 'gender': 'ANY'}, 'location': {'loc': 'the United States', 'gran': 'country'}}
#
# 23848155319320561 {'id': 23848155319320561, 'age-gender': {'age_min': 18, 'age_max': 43, 'gender': 'ANY'}}
#
# 23849172755140001 {'id': 23849172755140001, 'custom': True, 'age-gender': {'age_min': 6, 'age_max': 53, 'gender': 'ANY'}, 'location': {'loc': 'the United States', 'gran': 'country'}}
#
# 23848922059910366 {'id': 23848922059910366, 'age-gender': {'age_min': 6, 'age_max': 53, 'gender': 'MALE'}, 'location': {'loc': 'the United States', 'gran': 'country'}}
#
# 23848613600350191 {'id': 23848613600350191, 'age-gender': {'age_min': 9, 'age_max': 53, 'gender': 'ANY'}, 'location': {'loc': 'Eden, North Carolina', 'gran': 'city'}}
#
# 23848856163460007 {'id': 23848856163460007, 'age-gender': {'age_min': 6, 'age_max': 52, 'gender': 'ANY'}, 'location': {'loc': 'the United States', 'gran': 'country'}}
#
# 23849606774670615 {'id': 23849606774670615, 'custom': True, 'age-gender': {'age_min': 6, 'age_max': 53, 'gender': 'ANY'}, 'location': {'loc': 'the United States', 'gran': 'country'}}
#
# 6261171494981 {'id': 6261171494981, 'custom': True, 'age-gender': {'age_min': 6, 'age_max': 53, 'gender': 'ANY'}, 'location': {'loc': 'the United States', 'gran': 'country'}}
#
# 23848602528170473 {'id': 23848602528170473, 'age-gender': {'age_min': 13, 'age_max': 53, 'gender': 'ANY'}, 'location': {'loc': 'Eden, North Carolina', 'gran': 'city'}}
#
# 6270010359584 {'id': 6270010359584, 'age-gender': {'age_min': 13, 'age_max': 52, 'gender': 'ANY'}, 'location': {'loc': 'the United States', 'gran': 'country'}}
#
# 23849553858200333 {'id': 23849553858200333, 'age-gender': {'age_min': 6, 'age_max': 53, 'gender': 'ANY'}, 'location': {'loc': 'North Carolina', 'gran': 'region'}}
#
# 23849123545440100 {'id': 23849123545440100, 'custom': True, 'age-gender': {'age_min': 6, 'age_max': 53, 'gender': 'ANY'}, 'location': {'loc': 'Eden, North Carolina', 'gran': 'city'}}
#
# 23850128716320628 {'id': 23850128716320628, 'age-gender': {'age_min': 8, 'age_max': 33, 'gender': 'ANY'}, 'location': {'loc': 'the United States', 'gran': 'country'}}
#
# 23849502733150227 {'id': 23849502733150227, 'age-gender': {'age_min': 6, 'age_max': 53, 'gender': 'ANY'}, 'location': {'loc': 'the United States', 'gran': 'country'}}
#
# 23848700146200007 {'id': 23848700146200007, 'age-gender': {'age_min': 6, 'age_max': 52, 'gender': 'ANY'}, 'location': {'loc': 'the United States', 'gran': 'country'}}
#
# 23848997102840235 {'id': 23848997102840235, 'age-gender': {'age_min': 6, 'age_max': 53, 'gender': 'ANY'}, 'location': {'loc': 'the United States', 'gran': 'country'}}
#
# 23849001104880092 {'id': 23849001104880092, 'age-gender': {'age_min': 6, 'age_max': 53, 'gender': 'ANY'}, 'location': {'loc': 'the United States', 'gran': 'country'}}
#
# 23849553858650333 {'id': 23849553858650333, 'age-gender': {'age_min': 6, 'age_max': 53, 'gender': 'ANY'}, 'location': {'loc': 'North Carolina', 'gran': 'region'}}
#
# 23849323582690534 {'id': 23849323582690534, 'age-gender': {'age_min': 9, 'age_max': 43, 'gender': 'ANY'}, 'location': {'loc': 'the United States', 'gran': 'country'}}
#
# 23849435674440578 {'id': 23849435674440578, 'age-gender': {'age_min': 13, 'age_max': 32, 'gender': 'ANY'}, 'location': {'loc': 'the United States', 'gran': 'country'}}
#
# 23848880725160659 {'id': 23848880725160659, 'interests': {'National Football League'}, 'age-gender': {'age_min': 6, 'age_max': 53, 'gender': 'MALE'}, 'location': {'loc': 'the United States', 'gran': 'country'}}
#
# 23848881180290711 {'id': 23848881180290711, 'interests': {'Family', 'Entertainment', 'Netflix', 'Drama movies', 'Horror movies', 'CBS', 'College football', 'HBO', 'Streaming media', 'American football', 'Association football (Soccer)', 'Current events'}, 'age-gender': {'age_min': 6, 'age_max': 53, 'gender': 'ANY'}, 'location': {'loc': 'the United States', 'gran': 'country'}}
#
# 23848840616510316 {'id': 23848840616510316, 'custom': True, 'age-gender': {'age_min': 6, 'age_max': 53, 'gender': 'ANY'}, 'location': {'loc': 'the United States', 'gran': 'country'}}
#
# 23848797037270007 {'id': 23848797037270007, 'age-gender': {'age_min': 6, 'age_max': 52, 'gender': 'ANY'}, 'location': {'loc': 'the United States', 'gran': 'country'}}
#
# 23849629387620227 {'id': 23849629387620227, 'custom': True, 'age-gender': {'age_min': 6, 'age_max': 53, 'gender': 'ANY'}, 'location': {'loc': 'the United States', 'gran': 'country'}}
#
# 6258435809004 {'id': 6258435809004, 'custom': True, 'age-gender': {'age_min': 6, 'age_max': 53, 'gender': 'ANY'}, 'location': {'loc': 'the United States', 'gran': 'country'}}
#
# 23849525245040246 {'id': 23849525245040246, 'age-gender': {'age_min': 13, 'age_max': 53, 'gender': 'ANY'}, 'location': {'loc': 'the United States', 'gran': 'country'}}
#
# 6259139366170 {'id': 6259139366170, 'age-gender': {'age_min': 6, 'age_max': 53, 'gender': 'ANY'}, 'location': {'loc': 'the United States', 'gran': 'country'}}
#
# 23849083001310406 {'id': 23849083001310406, 'age-gender': {'age_min': 6, 'age_max': 53, 'gender': 'ANY'}}
#
# 23849553858540333 {'id': 23849553858540333, 'age-gender': {'age_min': 6, 'age_max': 53, 'gender': 'ANY'}, 'location': {'loc': 'North Carolina', 'gran': 'region'}}
#
# 23849052610670753 {'id': 23849052610670753, 'custom': True, 'age-gender': {'age_min': 6, 'age_max': 53, 'gender': 'ANY'}, 'location': {'loc': 'the United States', 'gran': 'country'}}
#
# 6261910913381 {'id': 6261910913381, 'custom': True, 'age-gender': {'age_min': 6, 'age_max': 53, 'gender': 'ANY'}, 'location': {'loc': 'the United States', 'gran': 'country'}}
#
# 23848720521990054 {'id': 23848720521990054, 'custom': True, 'age-gender': {'age_min': 6, 'age_max': 53, 'gender': 'ANY'}, 'location': {'loc': 'the United States', 'gran': 'country'}}
#
# 23848898918100204 {'id': 23848898918100204, 'age-gender': {'age_min': 6, 'age_max': 53, 'gender': 'MALE'}, 'location': {'loc': 'the United States', 'gran': 'country'}}
#
# 23849137101340252 {'id': 23849137101340252, 'custom': True, 'age-gender': {'age_min': 12, 'age_max': 53, 'gender': 'ANY'}, 'location': {'loc': 'the United States', 'gran': 'country'}}
#
# 23847737143030595 {'id': 23847737143030595, 'age-gender': {'age_min': 13, 'age_max': 52, 'gender': 'ANY'}, 'location': {'loc': 'the United States', 'gran': 'country'}}
#
# 23848611334870179 {'id': 23848611334870179, 'interests': {'Gambling'}, 'age-gender': {'age_min': 13, 'age_max': 53, 'gender': 'ANY'}, 'location': {'loc': 'the United States', 'gran': 'country'}}
#
# 23848846270420014 {'id': 23848846270420014, 'age-gender': {'age_min': 1, 'age_max': 53, 'gender': 'ANY'}, 'location': {'loc': 'the United States', 'gran': 'country'}}
#
# 6275020096886 {'id': 6275020096886, 'custom': True, 'age-gender': {'age_min': 1, 'age_max': 53, 'gender': 'ANY'}, 'location': {'loc': 'the United States', 'gran': 'country'}}
#
# 23848703218410473 {'id': 23848703218410473, 'age-gender': {'age_min': 12, 'age_max': 53, 'gender': 'ANY'}, 'location': {'loc': 'Eden, North Carolina', 'gran': 'city'}}
#
# 23848993482640605 {'id': 23848993482640605, 'interests': {'Vacation rental', 'Adventure travel'}, 'age-gender': {'age_min': 13, 'age_max': 53, 'gender': 'ANY'}, 'location': {'loc': 'North Carolina', 'gran': 'region'}}
#
# 23849035586410595 {'id': 23849035586410595, 'age-gender': {'age_min': 13, 'age_max': 52, 'gender': 'ANY'}, 'location': {'loc': 'the United States', 'gran': 'country'}}
#
# 6263985622184 {'id': 6263985622184, 'interests': {'E-commerce'}, 'age-gender': {'age_min': 13, 'age_max': 52, 'gender': 'ANY'}, 'location': {'loc': 'the United States', 'gran': 'country'}}
#
# 23848703206720473 {'id': 23848703206720473, 'custom': True, 'age-gender': {'age_min': 6, 'age_max': 53, 'gender': 'ANY'}, 'location': {'loc': 'Eden, North Carolina', 'gran': 'city'}}
#
# 6263350455370 {'id': 6263350455370, 'age-gender': {'age_min': 6, 'age_max': 53, 'gender': 'ANY'}, 'location': {'loc': 'the United States', 'gran': 'country'}}
#
# 6261429304632 {'id': 6261429304632, 'custom': True, 'age-gender': {'age_min': 6, 'age_max': 53, 'gender': 'ANY'}, 'location': {'loc': 'the United States', 'gran': 'country'}}
#
# 23849273414180236 {'id': 23849273414180236, 'interests': {'College football', 'High school football', 'American football'}, 'age-gender': {'age_min': 6, 'age_max': 53, 'gender': 'ANY'}, 'location': {'loc': 'Eden, North Carolina', 'gran': 'city'}}
#
# 23849169654510714 {'id': 23849169654510714, 'custom': True, 'age-gender': {'age_min': 6, 'age_max': 53, 'gender': 'ANY'}, 'location': {'loc': 'the United States', 'gran': 'country'}}
#
# 23848945336860607 {'id': 23848945336860607, 'age-gender': {'age_min': 6, 'age_max': 42, 'gender': 'ANY'}, 'location': {'loc': 'the United States', 'gran': 'country'}}
#
# 23849605113210227 {'id': 23849605113210227, 'age-gender': {'age_min': 6, 'age_max': 53, 'gender': 'ANY'}, 'location': {'loc': 'the United States', 'gran': 'country'}}
#
# 6271954726259 {'id': 6271954726259, 'custom': True, 'age-gender': {'age_min': 6, 'age_max': 53, 'gender': 'ANY'}, 'location': {'loc': 'the United States', 'gran': 'country'}}
#
# 23849941881360158 {'id': 23849941881360158, 'age-gender': {'age_min': 13, 'age_max': 53, 'gender': 'ANY'}, 'location': {'loc': 'the United States', 'gran': 'country'}}
#
# 23848157518220035 {'id': 23848157518220035, 'age-gender': {'age_min': 9, 'age_max': 53, 'gender': 'ANY'}, 'location': {'loc': 'the United States', 'gran': 'country'}}
#
# 23848957369810235 {'id': 23848957369810235, 'age-gender': {'age_min': 6, 'age_max': 53, 'gender': 'ANY'}, 'location': {'loc': 'the United States', 'gran': 'country'}}
#
# 23849954586090628 {'id': 23849954586090628, 'age-gender': {'age_min': 6, 'age_max': 53, 'gender': 'ANY'}, 'location': {'loc': 'the United States', 'gran': 'country'}}
#
# 23848996995280607 {'id': 23848996995280607, 'age-gender': {'age_min': 6, 'age_max': 53, 'gender': 'ANY'}, 'location': {'loc': 'the United States', 'gran': 'country'}}
#
# 23849052166430753 {'id': 23849052166430753, 'interests': {'Entrepreneurship', 'Small business', 'Software', 'Retail', 'Business', 'Management', 'Sales'}, 'age-gender': {'age_min': 6, 'age_max': 53, 'gender': 'ANY'}, 'location': {'loc': 'the United States', 'gran': 'country'}}
#
# 23849282722030004 {'id': 23849282722030004, 'custom': True, 'age-gender': {'age_min': 9, 'age_max': 53, 'gender': 'ANY'}, 'location': {'loc': 'the United States', 'gran': 'country'}}
#
# 6256375319696 {'id': 6256375319696, 'custom': True, 'age-gender': {'age_min': 13, 'age_max': 53, 'gender': 'ANY'}, 'location': {'loc': 'the United States', 'gran': 'country'}}
#
# 23849331538540004 {'id': 23849331538540004, 'custom': True, 'age-gender': {'age_min': 9, 'age_max': 53, 'gender': 'ANY'}, 'location': {'loc': 'the United States', 'gran': 'country'}}
#
# 23849021896250235 {'id': 23849021896250235, 'interests': {'Yoga'}, 'age-gender': {'age_min': 6, 'age_max': 53, 'gender': 'ANY'}, 'location': {'loc': 'the United States', 'gran': 'country'}}
#
# 23849439591030227 {'id': 23849439591030227, 'interests': {'Mobile app'}, 'age-gender': {'age_min': 6, 'age_max': 53, 'gender': 'ANY'}, 'location': {'loc': 'the United States', 'gran': 'country'}}
#
# 23849489109590163 {'id': 23849489109590163, 'interests': {'Southern College of Optometry'}, 'age-gender': {'age_min': 18, 'age_max': 53, 'gender': 'ANY'}, 'location': {'loc': 'the United States', 'gran': 'country'}}
#
# 23848982249310180 {'id': 23848982249310180, 'custom': True, 'age-gender': {'age_min': 6, 'age_max': 43, 'gender': 'ANY'}, 'location': {'loc': 'the United States', 'gran': 'country'}}
#
# 6260702106581 {'id': 6260702106581, 'custom': True, 'age-gender': {'age_min': 6, 'age_max': 53, 'gender': 'ANY'}, 'location': {'loc': 'the United States', 'gran': 'country'}}
#
# 23849052072090753 {'id': 23849052072090753, 'custom': True, 'age-gender': {'age_min': 6, 'age_max': 53, 'gender': 'ANY'}, 'location': {'loc': 'the United States', 'gran': 'country'}}
#
# 23849605113590227 {'id': 23849605113590227, 'age-gender': {'age_min': 6, 'age_max': 53, 'gender': 'ANY'}, 'location': {'loc': 'the United States', 'gran': 'country'}}
#
# 23849009009580624 {'id': 23849009009580624, 'interests': {'Hip hop music', 'Nicki Minaj', 'Pop music'}, 'age-gender': {'age_min': 6, 'age_max': 38, 'gender': 'ANY'}, 'location': {'loc': 'Florida', 'gran': 'region'}}
#
# 23849052071060753 {'id': 23849052071060753, 'custom': True, 'age-gender': {'age_min': 6, 'age_max': 53, 'gender': 'ANY'}, 'location': {'loc': 'the United States', 'gran': 'country'}}
#
# ...
#
# 23848636634440122 {'id': 23848636634440122, 'age-gender': {'age_min': 6, 'age_max': 23, 'gender': 'ANY'}, 'location': {'loc': 'Dripping Springs, Texas', 'gran': 'city'}}
#
# 6286227720424 {'id': 6286227720424, 'age-gender': {'age_min': 6, 'age_max': 53, 'gender': 'ANY'}, 'location': {'loc': 'the United States', 'gran': 'country'}}
#
# 23849480949310244 {'id': 23849480949310244, 'age-gender': {'age_min': 6, 'age_max': 53, 'gender': 'ANY'}, 'location': {'loc': 'the United States', 'gran': 'country'}}
#
# 6252223078357 {'id': 6252223078357, 'age-gender': {'age_min': 13, 'age_max': 53, 'gender': 'ANY'}, 'location': {'loc': 'the United States', 'gran': 'country'}}
#
# 23848336779070673 {'id': 23848336779070673, 'age-gender': {'age_min': 6, 'age_max': 53, 'gender': 'ANY'}, 'location': {'loc': 'the United States', 'gran': 'country'}}
#
# 23848738109440170 {'id': 23848738109440170, 'custom': True, 'age-gender': {'age_min': 6, 'age_max': 53, 'gender': 'ANY'}, 'location': {'loc': 'the United States', 'gran': 'country'}}
#
# 23848720313480170 {'id': 23848720313480170, 'custom': True, 'age-gender': {'age_min': 6, 'age_max': 53, 'gender': 'ANY'}, 'location': {'loc': 'the United States', 'gran': 'country'}}
#
# 6229993434698 {'id': 6229993434698, 'age-gender': {'age_min': 6, 'age_max': 53, 'gender': 'ANY'}, 'location': {'loc': 'the United States', 'gran': 'country'}}
#
# 6250361317422 {'id': 6250361317422, 'interests': {'Furniture', 'Interior design', 'Home Décor Products'}, 'age-gender': {'age_min': 13, 'age_max': 42, 'gender': 'FEMALE'}, 'location': {'loc': 'Dripping Springs, Texas', 'gran': 'city'}}
#
# 6222563576487 {'id': 6222563576487, 'age-gender': {'age_min': 8, 'age_max': 48, 'gender': 'ANY'}, 'location': {'loc': 'the United States', 'gran': 'country'}}
#
# 6233269112263 {'id': 6233269112263, 'age-gender': {'age_min': 13, 'age_max': 53, 'gender': 'ANY'}, 'location': {'loc': 'the United States', 'gran': 'country'}}
#
# 23848664366240101 {'id': 23848664366240101, 'interests': {'Food', 'Fast food'}, 'age-gender': {'age_min': 6, 'age_max': 52, 'gender': 'ANY'}, 'location': {'loc': 'Dripping Springs, Texas', 'gran': 'city'}}
#
# 6256640397387 {'id': 6256640397387, 'interests': {'Food and drink'}, 'age-gender': {'age_min': 6, 'age_max': 22, 'gender': 'FEMALE'}, 'location': {'loc': 'the United States', 'gran': 'country'}}
#
# 23849140105110268 {'id': 23849140105110268, 'age-gender': {'age_min': 4, 'age_max': 53, 'gender': 'FEMALE'}, 'location': {'loc': 'the United States', 'gran': 'country'}}
#
# 23849730317340369 {'id': 23849730317340369, 'age-gender': {'age_min': 13, 'age_max': 42, 'gender': 'ANY'}, 'location': {'loc': 'the United States', 'gran': 'country'}}
#
# 23849232881280091 {'id': 23849232881280091, 'custom': True, 'age-gender': {'age_min': 6, 'age_max': 53, 'gender': 'ANY'}, 'location': {'loc': 'the United States', 'gran': 'country'}}
#
# 23848521124490470 {'id': 23848521124490470, 'age-gender': {'age_min': 6, 'age_max': 53, 'gender': 'ANY'}, 'location': {'loc': 'the United States', 'gran': 'country'}}
#
# 23848626134110297 {'id': 23848626134110297, 'age-gender': {'age_min': 13, 'age_max': 42, 'gender': 'FEMALE'}, 'location': {'loc': 'El Campo, Texas', 'gran': 'city'}}
#
# 23849406004640246 {'id': 23849406004640246, 'age-gender': {'age_min': 4, 'age_max': 22, 'gender': 'FEMALE'}, 'location': {'loc': 'the United States', 'gran': 'country'}}
#
# 6286443344020 {'id': 6286443344020, 'age-gender': {'age_min': 9, 'age_max': 53, 'gender': 'ANY'}, 'location': {'loc': 'the United States', 'gran': 'country'}}
#
# 6239991821221 {'id': 6239991821221, 'age-gender': {'age_min': 13, 'age_max': 52, 'gender': 'FEMALE'}, 'location': {'loc': 'the United States', 'gran': 'country'}}
#
# 6268730010906 {'id': 6268730010906, 'age-gender': {'age_min': 6, 'age_max': 53, 'gender': 'ANY'}, 'location': {'loc': 'the United States', 'gran': 'country'}}
#
# 6279620160630 {'id': 6279620160630, 'age-gender': {'age_min': 6, 'age_max': 53, 'gender': 'ANY'}, 'location': {'loc': 'the United States', 'gran': 'country'}}
#
# 23848774522920170 {'id': 23848774522920170, 'custom': True, 'age-gender': {'age_min': 6, 'age_max': 53, 'gender': 'ANY'}, 'location': {'loc': 'the United States', 'gran': 'country'}}
#
# 23848977465540293 {'id': 23848977465540293, 'age-gender': {'age_min': 6, 'age_max': 53, 'gender': 'FEMALE'}, 'location': {'loc': 'the United States', 'gran': 'country'}}
#
# 23848578140090293 {'id': 23848578140090293, 'interests': {'The Home Depot'}, 'age-gender': {'age_min': 12, 'age_max': 52, 'gender': 'ANY'}, 'location': {'loc': 'the United States', 'gran': 'country'}}
# 23848362406500011 {'id': 23848362406500011, 'age-gender': {'age_min': 6, 'age_max': 52, 'gender': 'ANY'}, 'location': {'loc': 'the United States', 'gran': 'country'}}
#
# 23848683400370170 {'id': 23848683400370170, 'custom': True, 'age-gender': {'age_min': 6, 'age_max': 53, 'gender': 'ANY'}, 'location': {'loc': 'the United States', 'gran': 'country'}}
#
# 6256640392387 {'id': 6256640392387, 'interests': {'Online shopping'}, 'age-gender': {'age_min': 6, 'age_max': 22, 'gender': 'FEMALE'}, 'location': {'loc': 'the United States', 'gran': 'country'}}
#
# 6256458232585 {'id': 6256458232585, 'interests': {'Alcoholic beverages'}, 'age-gender': {'age_min': 9, 'age_max': 22, 'gender': 'ANY'}, 'location': {'loc': 'Texas', 'gran': 'region'}}
#
# 6279492132050 {'id': 6279492132050, 'age-gender': {'age_min': 6, 'age_max': 52, 'gender': 'ANY'}, 'location': {'loc': 'the United States', 'gran': 'country'}}
#
# 23849238589780455 {'id': 23849238589780455, 'age-gender': {'age_min': 6, 'age_max': 53, 'gender': 'ANY'}, 'location': {'loc': 'the United States', 'gran': 'country'}}
#
# 6250439077202 {'id': 6250439077202, 'age-gender': {'age_min': 6, 'age_max': 53, 'gender': 'FEMALE'}, 'location': {'loc': 'the United States', 'gran': 'country'}}
#
# 6267665707342 {'id': 6267665707342, 'interests': {'Yoga'}, 'age-gender': {'age_min': 6, 'age_max': 43, 'gender': 'FEMALE'}, 'location': {'loc': 'the United States', 'gran': 'country'}}
#
# 23849775661370342 {'id': 23849775661370342, 'age-gender': {'age_min': 6, 'age_max': 53, 'gender': 'ANY'}, 'location': {'loc': 'the United States', 'gran': 'country'}}
#
# 23849025190010170 {'id': 23849025190010170, 'custom': True, 'age-gender': {'age_min': 6, 'age_max': 53, 'gender': 'ANY'}, 'location': {'loc': 'the United States', 'gran': 'country'}}
#
# 6262516500247 {'id': 6262516500247, 'age-gender': {'age_min': 6, 'age_max': 53, 'gender': 'FEMALE'}, 'location': {'loc': 'the United States', 'gran': 'country'}}
#
# 23849035360360170 {'id': 23849035360360170, 'custom': True, 'age-gender': {'age_min': 6, 'age_max': 53, 'gender': 'ANY'}, 'location': {'loc': 'the United States', 'gran': 'country'}}
#
# 23848966274660170 {'id': 23848966274660170, 'custom': True, 'age-gender': {'age_min': 6, 'age_max': 53, 'gender': 'ANY'}, 'location': {'loc': 'the United States', 'gran': 'country'}}
#
# 23848915645590170 {'id': 23848915645590170, 'custom': True, 'age-gender': {'age_min': 6, 'age_max': 53, 'gender': 'ANY'}, 'location': {'loc': 'the United States', 'gran': 'country'}}
#
# 23848940556530170 {'id': 23848940556530170, 'custom': True, 'age-gender': {'age_min': 6, 'age_max': 53, 'gender': 'ANY'}, 'location': {'loc': 'the United States', 'gran': 'country'}}
#
# 23848773138620007 {'id': 23848773138620007, 'age-gender': {'age_min': 6, 'age_max': 53, 'gender': 'ANY'}, 'location': {'loc': 'the United States', 'gran': 'country'}}
#
# 23848958907770192 {'id': 23848958907770192, 'interests': {'Fashion accessories'}, 'age-gender': {'age_min': 13, 'age_max': 53, 'gender': 'FEMALE'}, 'location': {'loc': 'the United States', 'gran': 'country'}}
#
# 23849386933610749 {'id': 23849386933610749, 'interests': {'Online shopping'}, 'age-gender': {'age_min': 8, 'age_max': 48, 'gender': 'ANY'}, 'location': {'loc': 'the United States', 'gran': 'country'}}
#
# 6265591073061 {'id': 6265591073061, 'age-gender': {'age_min': 10, 'age_max': 42, 'gender': 'FEMALE'}, 'location': {'loc': 'the United States', 'gran': 'country'}}
#
# 23850181110910543 {'id': 23850181110910543, 'age-gender': {'age_min': 6, 'age_max': 53, 'gender': 'FEMALE'}, 'location': {'loc': 'the United States', 'gran': 'country'}}
#
# 23849506459010160 {'id': 23849506459010160, 'age-gender': {'age_min': 6, 'age_max': 53, 'gender': 'FEMALE'}, 'location': {'loc': 'Texas', 'gran': 'region'}}
#
# 6283410682420 {'id': 6283410682420, 'interests': {'Wine'}, 'age-gender': {'age_min': 9, 'age_max': 53, 'gender': 'FEMALE'}, 'location': {'loc': 'the United States', 'gran': 'country'}}
#
# 23848966278460170 {'id': 23848966278460170, 'custom': True, 'age-gender': {'age_min': 6, 'age_max': 53, 'gender': 'ANY'}, 'location': {'loc': 'the United States', 'gran': 'country'}}
#
# 6255803702402 {'id': 6255803702402, 'age-gender': {'age_min': 6, 'age_max': 43, 'gender': 'FEMALE'}, 'location': {'loc': 'the United States', 'gran': 'country'}}
#
# 23849872124510543 {'id': 23849872124510543, 'age-gender': {'age_min': 6, 'age_max': 53, 'gender': 'FEMALE'}, 'location': {'loc': 'the United States', 'gran': 'country'}}
#
# 23848917071030170 {'id': 23848917071030170, 'custom': True, 'age-gender': {'age_min': 6, 'age_max': 53, 'gender': 'ANY'}, 'location': {'loc': 'the United States', 'gran': 'country'}}
#
# 23848966173010170 {'id': 23848966173010170, 'custom': True, 'age-gender': {'age_min': 6, 'age_max': 53, 'gender': 'ANY'}, 'location': {'loc': 'the United States', 'gran': 'country'}}
#
# 23849330392050268 {'id': 23849330392050268, 'interests': {'Cosmetics'}, 'age-gender': {'age_min': 4, 'age_max': 53, 'gender': 'FEMALE'}, 'location': {'loc': 'the United States', 'gran': 'country'}}
#
# 23849118441920606 {'id': 23849118441920606, 'custom': True, 'age-gender': {'age_min': 6, 'age_max': 53, 'gender': 'ANY'}, 'location': {'loc': 'the United States', 'gran': 'country'}}
#
# 23849005739260170 {'id': 23849005739260170, 'custom': True, 'age-gender': {'age_min': 6, 'age_max': 53, 'gender': 'ANY'}, 'location': {'loc': 'the United States', 'gran': 'country'}}
#
# 23848802381030281 {'id': 23848802381030281, 'age-gender': {'age_min': 9, 'age_max': 43, 'gender': 'ANY'}, 'location': {'loc': 'the United States', 'gran': 'country'}}
#
# 6288743283820 {'id': 6288743283820, 'age-gender': {'age_min': 9, 'age_max': 53, 'gender': 'ANY'}, 'location': {'loc': 'the United States', 'gran': 'country'}}
#
# 23848784686400339 {'id': 23848784686400339, 'age-gender': {'age_min': 13, 'age_max': 53, 'gender': 'FEMALE'}, 'location': {'loc': 'the United States', 'gran': 'country'}}
#
# 6258141596085 {'id': 6258141596085, 'age-gender': {'age_min': 9, 'age_max': 53, 'gender': 'ANY'}, 'location': {'loc': 'the United States', 'gran': 'country'}}
#
# 6245516204021 {'id': 6245516204021, 'age-gender': {'age_min': 6, 'age_max': 53, 'gender': 'ANY'}, 'location': {'loc': 'the United States', 'gran': 'country'}}
#
# 23847072947740328 {'id': 23847072947740328, 'age-gender': {'age_min': 6, 'age_max': 53, 'gender': 'ANY'}, 'location': {'loc': 'the United States', 'gran': 'country'}}
#
# 6238984474021 {'id': 6238984474021, 'age-gender': {'age_min': 9, 'age_max': 53, 'gender': 'ANY'}, 'location': {'loc': 'the United States', 'gran': 'country'}}
#
# 23848579574530026 {'id': 23848579574530026, 'interests': {'The Motley Fool', 'Health care industry', 'Investing online', 'Equity crowdfunding', 'Physician', 'Crowdfunding', 'Investment', 'Health care'}, 'age-gender': {'age_min': 6, 'age_max': 53, 'gender': 'ANY'}, 'location': {'loc': 'the United States', 'gran': 'country'}}
#
# 23849224683410663 {'id': 23849224683410663, 'interests': {'Investing online'}, 'age-gender': {'age_min': 6, 'age_max': 53, 'gender': 'ANY'}, 'location': {'loc': 'the United States', 'gran': 'country'}}
#
# 23849085060400226 {'id': 23849085060400226, 'age-gender': {'age_min': 12, 'age_max': 53, 'gender': 'ANY'}, 'location': {'loc': 'the United States', 'gran': 'country'}}
#
# 6258345162345 {'id': 6258345162345, 'interests': {'Small and medium enterprises', 'Entrepreneurship', 'Small business'}, 'age-gender': {'age_min': 6, 'age_max': 53, 'gender': 'ANY'}, 'location': {'loc': 'Johns Creek, Georgia', 'gran': 'city'}}
#
# 23848889851150779 {'id': 23848889851150779, 'age-gender': {'age_min': 6, 'age_max': 53, 'gender': 'ANY'}, 'location': {'loc': 'the United States', 'gran': 'country'}}
#
# 23849130384540694 {'id': 23849130384540694, 'age-gender': {'age_min': 10, 'age_max': 42, 'gender': 'ANY'}, 'location': {'loc': 'Johns Creek, Georgia', 'gran': 'city'}}
#
# 6262280515299 {'id': 6262280515299, 'age-gender': {'age_min': 33, 'age_max': 53, 'gender': 'ANY'}, 'location': {'loc': 'Johns Creek, Georgia', 'gran': 'city'}}
#
# 23849432613480104 {'id': 23849432613480104, 'age-gender': {'age_min': 10, 'age_max': 53, 'gender': 'ANY'}, 'location': {'loc': 'the United States', 'gran': 'country'}}
#
# 6260667718608 {'id': 6260667718608, 'interests': {'The Motley Fool', 'Fair', 'Yahoo! Finance', 'Daymond John', 'NASDAQ'}, 'age-gender': {'age_min': 33, 'age_max': 53, 'gender': 'ANY'}, 'location': {'loc': 'the United States', 'gran': 'country'}}
#
# 6253291288644 {'id': 6253291288644, 'age-gender': {'age_min': 6, 'age_max': 53, 'gender': 'ANY'}, 'location': {'loc': 'the United States', 'gran': 'country'}}
#
# 23849859384020666 {'id': 23849859384020666, 'age-gender': {'age_min': 13, 'age_max': 43, 'gender': 'ANY'}, 'location': {'loc': 'the United States', 'gran': 'country'}}
#
# 23849384937720110 {'id': 23849384937720110, 'age-gender': {'age_min': 13, 'age_max': 52, 'gender': 'ANY'}, 'location': {'loc': 'the United States', 'gran': 'country'}}
#
# 23849397527900757 {'id': 23849397527900757, 'age-gender': {'age_min': 6, 'age_max': 53, 'gender': 'ANY'}, 'location': {'loc': 'the United States', 'gran': 'country'}}
#
# 23849361619180378 {'id': 23849361619180378, 'age-gender': {'age_min': 13, 'age_max': 42, 'gender': 'ANY'}, 'location': {'loc': 'the United States', 'gran': 'country'}}
#
# 23850080112280456 {'id': 23850080112280456, 'custom': True, 'age-gender': {'age_min': 10, 'age_max': 52, 'gender': 'ANY'}, 'location': {'loc': 'the United States', 'gran': 'country'}}
#
# 23849697345180713 {'id': 23849697345180713, 'interests': {'Music'}, 'age-gender': {'age_min': 9, 'age_max': 53, 'gender': 'ANY'}, 'location': {'loc': 'Pinckney, Michigan', 'gran': 'city'}}
#
# 23850055982260337 {'id': 23850055982260337, 'custom': True, 'age-gender': {'age_min': 6, 'age_max': 53, 'gender': 'ANY'}, 'location': {'loc': 'Garland, Texas', 'gran': 'city'}}
#
# 23849531711140151 {'id': 23849531711140151, 'age-gender': {'age_min': 13, 'age_max': 53, 'gender': 'ANY'}, 'location': {'loc': 'the United States', 'gran': 'country'}}
#
# 23849507448360042 {'id': 23849507448360042, 'age-gender': {'age_min': 6, 'age_max': 53, 'gender': 'ANY'}, 'location': {'loc': 'the United States', 'gran': 'country'}}
#
# 23849591839720413 {'id': 23849591839720413, 'custom': True, 'age-gender': {'age_min': 6, 'age_max': 52, 'gender': 'ANY'}, 'location': {'loc': 'the United States', 'gran': 'country'}}
#
# 23849900583260558 {'id': 23849900583260558, 'age-gender': {'age_min': 43, 'age_max': 53, 'gender': 'ANY'}, 'location': {'loc': 'Pinckney, Michigan', 'gran': 'city'}}
#
# 23849329870100048 {'id': 23849329870100048, 'age-gender': {'age_min': 6, 'age_max': 53, 'gender': 'ANY'}, 'location': {'loc': 'the United States', 'gran': 'country'}}
#
# 23849731973780403 {'id': 23849731973780403, 'interests': {'Documentary movies', 'Time (magazine)', 'Fine art', 'Art museum', 'Wine', 'Broadway theatre', 'Books', 'Visual arts', 'Musical theatre', 'Ballet tutu', 'Performing arts', 'Ballet'}, 'age-gender': {'age_min': 13, 'age_max': 53, 'gender': 'ANY'}, 'location': {'loc': 'Pinckney, Michigan', 'gran': 'city'}}
#
# 23849325581100040 {'id': 23849325581100040, 'age-gender': {'age_min': 6, 'age_max': 53, 'gender': 'FEMALE'}, 'location': {'loc': 'the United States', 'gran': 'country'}}
#
# 23849717448060411 {'id': 23849717448060411, 'custom': True, 'age-gender': {'age_min': 6, 'age_max': 53, 'gender': 'ANY'}, 'location': {'loc': 'the United States', 'gran': 'country'}}

# %%
# benign
print('Total, Generic, Interest, Custom')
print(total, n_generic, n_interest, n_custom)
# Out:
# Total, Generic, Interest, Custom
# 10421 5074 2693 2654

# %%
# sensitive
print('Total, Generic, Interest, Custom')
print(total, n_generic, n_interest, n_custom)
# Out:
# Total, Generic, Interest, Custom
# 314 129 87 98

# %%
## clickbait + harmful + prohibited. TODO: need to unpack and see how this overall number is computed
print('Total, Generic, Interest, Custom')
print(total, n_generic, n_interest, n_custom)
# Out:
# Total, Generic, Interest, Custom
# 611 444 91 76

# %%
plot_codes = ['Benign', 'Harmful / Prohibited / Clickbait', 'Sensitive', 'Healthcare+Sensitive',
              'Clickbait', 'Potentially Harmful', 'Potentially Prohibited']
f, ax = plt.subplots(1, 1, figsize=(10, 6))

labels = ['Generic', 'Interest', 'Custom']
labels_loc = ['city', 'region', 'country']
colors = ['tab:blue', 'tab:orange', 'tab:red']
colors_loc = ['tab:red', 'tab:orange', 'goldenrod']
all_interest_counts = []
for i, c in enumerate(plot_codes):        
    if c == 'Harmful / Prohibited / Clickbait':
        curr_code_ads = list(global_harms['adid'])
    elif c == 'Healthcare+Sensitive':
        curr_code_ads = list(healthcare_harms['adid'])        
    else:
        curr_code_ads = list(codes[codes['codes'].str.contains(c)]['adid'])
        
    total = len(curr_code_ads)
        
    n_interest, n_custom, n_generic = 0, 0, 0
    interest_counts = []
    locgran_counts = {'city': 0, 'region': 0, 'country': 0}
    for aid in curr_code_ads:
        # preprocess targeting json
        tar = get_targeting(ad_targetings[str(aid)], aid)
        if 'location' in tar:
            locgran_counts[tar['location']['gran']] += 1
        if 'interests' in tar:
            interest_counts.append(len(tar['interests']))
            n_interest += 1
        if 'custom' in tar:
            n_custom += 1
    n_generic = total - n_interest - n_custom        
    
    # === plotting fractions ===
#     for j, frac in enumerate([n_generic/total, n_interest/total, n_custom/total]):
#         err = analysis_utils.normal_bin_conf(frac, total)
#         ax.errorbar([i + random.uniform(0, 0.2)], [frac], marker='o', label=labels[j],
#                   color=colors[j], alpha=.8, yerr=err)
#         labels[j] = ''
        
    # === plotting location specificity ===
    print(c, locgran_counts)
    for j, gran in enumerate(['city', 'region', 'country']):
        total = sum(locgran_counts.values())
        frac = locgran_counts[gran] / total
        err = analysis_utils.normal_bin_conf(frac, total)
        ax.errorbar([i + random.uniform(0, 0.2)], [frac], marker='o', label=labels_loc[j],
                   color=colors_loc[j], yerr =err)
        labels_loc[j] = ''
    
    # === plotting boxplot of number of interests ===
#     all_interest_counts.append(interest_counts)
#     print('Median interests', c, np.median(interest_counts))
    
    
# === difference of targeting settings ===
# ax.legend()
# ax.set_ylabel('Fraction of Ads', fontsize=12)
# ax.set_ylim(top=1.02)
# ax.grid(ls=':')
# ax.set_xticks(range(len(plot_codes)))
# ax.set_xticklabels(plot_codes, rotation=90, fontsize=12)    
# plt.savefig('../figures/global-vs-harmful-targeting-differences.pdf', dpi=150, bbox_inches='tight')

# === location specificity ===
ax.legend()
ax.set_ylabel('Fraction of Ads', fontsize=12)
ax.set_ylim(top=1.02)
ax.grid(ls=':')
ax.set_xticks(range(len(plot_codes)))
ax.set_xticklabels(plot_codes, rotation=90, fontsize=12)    
plt.savefig('../figures/global-vs-harmful-targeting-locgran.pdf', dpi=150, bbox_inches='tight')

# === differences in number of interests ===
# ax.grid(ls=':')
# ax.set_ylim(top=20)
# ax.set_ylabel('Number of Interests (cropped off @ 20)')
# ax.boxplot(all_interest_counts)
# ax.set_xticks(range(1, len(plot_codes)+1))
# ax.set_xticklabels(plot_codes, rotation=90, fontsize=12)    
# plt.savefig('../figures/global-vs-harmful-interest-differences.pdf', dpi=150, bbox_inches='tight')
# Out:
# Benign {'city': 1187, 'region': 491, 'country': 7375}
# Harmful / Prohibited / Clickbait {'city': 62, 'region': 61, 'country': 403}
# Sensitive {'city': 33, 'region': 76, 'country': 179}
# Healthcare+Sensitive {'city': 12, 'region': 22, 'country': 77}
# Clickbait {'city': 57, 'region': 20, 'country': 334}
# Potentially Harmful {'city': 4, 'region': 7, 'country': 41}
# Potentially Prohibited {'city': 13, 'region': 40, 'country': 106}

# %% [markdown]
# **NOTE**: I'm onto something here -- the globally harmful ads have a higher fraction of generically targeted ads than benign (~72% vs. 48.6%), this is where FB is doing most of the work. For contextual harms, custom targeting makes up 31% of the targeting, compared to 25% for benign ones; 27% sensitive are targeted with interest compared to 25% benign. I think these are almost fundamental insights about the algorithm vs. advertiser equation.
#
# It would be amazing to unpack the median/mean number of interests, and the average location specificity, and compare that across these 3 categories too.
#
# It is extremely valuable to stick to the benign vs. globally harmful vs. contextually harmful ads.

# %% [markdown]
# ## What are the demographics (race, SES) for top 20% of clickbait's consumers?
#
# Question from notes: there are interesting differences by individual participant by looking at distributions, how are the demographic differences along age, gender, education, ethnicity?

# %% [markdown]
# ### Contextual Harms, investigating
#
# The hypothesis to test is whether people with sensitive triggers see more content targeted as sensitive. A linear model would be a perfect way to find this out. Even if there isn't enough statistical power to say this, a combination of regression + descriptive analyses looking at the targeting and content of ads themselves would be a killer result.
#
# `lm(p_sensitive ~ alcohol + gambling + dieting + woman + older, data=data)`

# %%
# from the additional_demographics file, some people have mentioned issues with eating disorders etc.
# what do their ad diets look like?

# sensitive = '5ea3310bf9c4f828f0c909c5'  # only one healthcare+sensitive ad
# sensitive = '5f969b802a498b000aab2571'    # had eating disorder and sees Lark ads
sensitive = '60a69e84d2f871b61d608e89'    # gambling
joiner = pid_adid[pid_adid['pid'] == sensitive]
joined = joiner.merge(codes, how='inner', left_on='adid', right_on='adid')

bad_ads = joined[joined['codes'].str.contains('Sensitive')]
bad_ads
# Out:
# Empty DataFrame
# Columns: [pid, adid, codes_manjot, codes]
# Index: []

# %% [markdown]
# **Question**: Who is getting all these DraftKings Sportsbook ads, do they like them?

# %%
saw_relationship_scam = '557046'

# bad ad IDs whose users should be investigated
purple_mattress_adid = '23849363028240755'
free_vacation_ad = '23849372823430048'
caleb_is_marketing_scam = '23849372849040378'
