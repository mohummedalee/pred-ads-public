# %% [markdown]
# ### Extending earlier `survey1-targeting-differences` analysis (from ConPro) to see targeting differences from all annotated ads

# %%
import csv, json
from collections import defaultdict, Counter
import matplotlib.pyplot as plt
import matplotlib.patches as patches
import scipy.stats
plt.rcParams['font.family'] = 'Helvetica'
import matplotlib.lines as mlines
from math import sqrt
import numpy as np
import pandas as pd

# %%
# load targetings
ad_targetings = {}
with open('../../db-processing/ad-targetings.tsv', 'r') as fh:
    for line in fh:
        ad_id, targeting = line.split('\t')
        targeting = json.loads(targeting.strip())
        ad_targetings[ad_id] = targeting

# %%
from collections import defaultdict

def count_code_props(codes, norm=True):
    # takes dict from adid -> codes and returns dict of code proportions
    counts = defaultdict(lambda: 0)
    for aid in codes:
        # in case of multiple codes, count each one -- essentially computing fraction of codes and not ads here
        for code in codes[aid].split(';'):
            if code not in ['Political'] and "Can't determine" not in code:
                counts[code] += 1
                
    if norm:
        return {c: counts[c]/sum(counts.values()) for c in counts}
    else:
        return counts
    
def find_code_ads(codes):
    # takes dict from adid -> codes and inverts it to return code -> [adid] dict
    # input dict can be computed e.g. by dict(codes[['adid', 'codes_angelica']].values)
    flipped = defaultdict(list)
    for aid in codes:
        for code in codes[aid].split(';'):
            if code not in ['Political'] and "Can't determine" not in code:
                flipped[code].append(aid)
                
    return flipped

# %%
# load PID, AD_ID mapping
pid_adid_files = ['../../db-processing/surveys/survey-1/pid_adid_survey1.tsv',
                  '../../db-processing/surveys/survey-1/pid_adid_survey1_batch2.tsv',
                 '../../db-processing/surveys/survey-2/pid_adid_survey2.tsv',
                 '../../db-processing/surveys/survey-3/pid_adid_survey3.tsv']
#                  '../../db-processing/surveys/survey-4/pid_adid_survey4.tsv']
pid_adid = pd.read_csv(pid_adid_files[0], sep='\t')
for f in pid_adid_files[1:]:
    pid_adid = pd.concat([pid_adid, pd.read_csv(f, sep='\t')], ignore_index=True)
print(pid_adid.shape)
survey1_pids = set(pid_adid['pid'])

codes_file = '../../db-processing/ad_codes.tsv'
codes = pd.read_csv(codes_file, sep='\t')

# load codes and compute user-level fractions too
part_code_props = {}
part_code_counts = {}

for pid in survey1_pids:
    joiner = pid_adid[pid_adid['pid'] == pid]
    joined = joiner.merge(codes, how='inner', left_on='adid', right_on='adid')
    
    code_props = count_code_props(dict(joined[['adid', 'codes']].values), norm=True)
    part_code_props[pid] = code_props
    
    code_counts = count_code_props(dict(joined[['adid', 'codes']].values), norm=False)
    part_code_counts[pid] = code_counts
# Out:
# (54399, 2)

# %%
ca_advertisers = {}
# 'ca_owner_name': 'Klarna'

def get_targeting(ut, aid):
    # also updates global list of CA advertisers
    global ca_advertisers
    
    # there is always an el['__typename'] == 'WAISTUIAgeGenderType'
    all_targetings = {'id': aid}
    for el in ut['data']['waist_targeting_data']:
        if el['__typename'] == 'WAISTUIInterestsType':
            all_targetings['interests'] = set([i['name'] for i in el['interests']])
        elif el['__typename'] == 'WAISTUICustomAudienceType':
            ca_advertisers[aid] = el['dfca_data']['ca_owner_name']
            all_targetings['custom'] = True
        elif el['__typename'] == 'WAISTUILocationType':
            gran = json.loads(el['serialized_data'])['location_granularity']
            loc = el['location_name']
            all_targetings['location'] = {'loc': loc, 'gran': gran}
        elif el['__typename'] == 'WAISTUIAgeGenderType':
            all_targetings['age-gender'] = {
                'age_min': el['age_min'],
                'age_max': el['age_max'],
                'gender': el['gender']
            }        
        
    return all_targetings

# %%
# QUESTIONS WORTH LOOKING AT
# 1. how different is targeting by code?
# 2. how different is targeting by user? (can be compared to their non-benign ratio) -- DONE
# 3. any specific peculiarities with the negative codes?

# %%
# pull out all targeting interests seen in the data
user_interests = defaultdict(list)
user_targetings = defaultdict(list)
for uid in survey1_pids:
    for aid in pid_adid[pid_adid['pid'] == uid]['adid']:
        # process targeting json to extract info
        tar = get_targeting(ad_targetings[str(aid)], aid)
        user_targetings[uid].append(tar)
        if 'interests' in tar:
            user_interests[uid].extend(list(tar['interests']))

# %%
user_targetings['6112cec057db665aefdd7a85']
# Out:
# [{'id': 23848721522540460,
#   'interests': {"Tilly's"},
#   'age-gender': {'age_min': 6, 'age_max': 53, 'gender': 'ANY'},
#   'location': {'loc': 'the United States', 'gran': 'country'}},
#  {'id': 6254413481299,
#   'age-gender': {'age_min': 9, 'age_max': 53, 'gender': 'ANY'},
#   'location': {'loc': 'the United States', 'gran': 'country'}},
#  {'id': 23849178994590365,
#   'custom': True,
#   'age-gender': {'age_min': 6, 'age_max': 53, 'gender': 'ANY'},
#   'location': {'loc': 'the United States', 'gran': 'country'}},
#  {'id': 23849587673510743,
#   'age-gender': {'age_min': 6, 'age_max': 53, 'gender': 'ANY'},
#   'location': {'loc': 'the United States', 'gran': 'country'}},
#  {'id': 6282218739351,
#   'interests': {'Beauty', 'Health & wellness'},
#   'age-gender': {'age_min': 6, 'age_max': 22, 'gender': 'FEMALE'},
#   'location': {'loc': 'the United States', 'gran': 'country'}},
#  {'id': 6266244850944,
#   'age-gender': {'age_min': 6, 'age_max': 31, 'gender': 'FEMALE'},
#   'location': {'loc': 'Florida', 'gran': 'region'}},
#  {'id': 6247512864330,
#   'interests': {'Black Friday (shopping)',
#    'Coupons',
#    'Cyber Monday',
#    'Gift',
#    'Sales promotion'},
#   'age-gender': {'age_min': 8, 'age_max': 53, 'gender': 'ANY'},
#   'location': {'loc': 'the United States', 'gran': 'country'}},
#  {'id': 23850250471380426,
#   'age-gender': {'age_min': 6, 'age_max': 53, 'gender': 'ANY'},
#   'location': {'loc': 'the United States', 'gran': 'country'}},
#  {'id': 23848378636440195,
#   'age-gender': {'age_min': 8, 'age_max': 20, 'gender': 'ANY'},
#   'location': {'loc': 'the United States', 'gran': 'country'}},
#  {'id': 23848697185960466,
#   'custom': True,
#   'age-gender': {'age_min': 6, 'age_max': 53, 'gender': 'ANY'},
#   'location': {'loc': 'the United States', 'gran': 'country'}},
#  {'id': 23848931055520640,
#   'age-gender': {'age_min': 6, 'age_max': 53, 'gender': 'ANY'},
#   'location': {'loc': 'the United States', 'gran': 'country'}},
#  {'id': 23849273049650391,
#   'age-gender': {'age_min': 8, 'age_max': 43, 'gender': 'ANY'},
#   'location': {'loc': 'the United States', 'gran': 'country'}},
#  {'id': 23849345914300020,
#   'age-gender': {'age_min': 6, 'age_max': 53, 'gender': 'ANY'},
#   'location': {'loc': 'the United States', 'gran': 'country'}},
#  {'id': 23848938165720633,
#   'age-gender': {'age_min': 6, 'age_max': 53, 'gender': 'ANY'},
#   'location': {'loc': 'the United States', 'gran': 'country'}},
#  {'id': 23847239765590387,
#   'interests': {'Residency (medicine)'},
#   'age-gender': {'age_min': 6, 'age_max': 43, 'gender': 'FEMALE'},
#   'location': {'loc': 'the United States', 'gran': 'country'}},
#  {'id': 23848679458920451,
#   'custom': True,
#   'age-gender': {'age_min': 6, 'age_max': 53, 'gender': 'ANY'},
#   'location': {'loc': 'Gainesville, Florida', 'gran': 'city'}},
#  {'id': 23848743882590354,
#   'interests': {'Labrador Retriever'},
#   'age-gender': {'age_min': 6, 'age_max': 53, 'gender': 'FEMALE'},
#   'location': {'loc': 'the United States', 'gran': 'country'}},
#  {'id': 6282218692151,
#   'interests': {'Beauty', 'Health & wellness'},
#   'age-gender': {'age_min': 6, 'age_max': 22, 'gender': 'FEMALE'},
#   'location': {'loc': 'the United States', 'gran': 'country'}},
#  {'id': 6257672283187,
#   'interests': {'Shopping and fashion'},
#   'age-gender': {'age_min': 6, 'age_max': 12, 'gender': 'FEMALE'},
#   'location': {'loc': 'the United States', 'gran': 'country'}},
#  {'id': 23848924286580606,
#   'custom': True,
#   'age-gender': {'age_min': 6, 'age_max': 53, 'gender': 'ANY'},
#   'location': {'loc': 'the United States', 'gran': 'country'}},
#  {'id': 6248928650929,
#   'age-gender': {'age_min': 6, 'age_max': 53, 'gender': 'ANY'},
#   'location': {'loc': 'the United States', 'gran': 'country'}},
#  {'id': 23849821125640543,
#   'age-gender': {'age_min': 6, 'age_max': 53, 'gender': 'FEMALE'},
#   'location': {'loc': 'the United States', 'gran': 'country'}},
#  {'id': 23849991665920426,
#   'age-gender': {'age_min': 6, 'age_max': 53, 'gender': 'ANY'},
#   'location': {'loc': 'the United States', 'gran': 'country'}},
#  {'id': 6234793709694,
#   'custom': True,
#   'age-gender': {'age_min': 9, 'age_max': 38, 'gender': 'ANY'},
#   'location': {'loc': 'the United States', 'gran': 'country'}},
#  {'id': 23848789366720466,
#   'interests': {'Beauty', 'Foodie', 'Travel'},
#   'age-gender': {'age_min': 6, 'age_max': 43, 'gender': 'FEMALE'},
#   'location': {'loc': 'the United States', 'gran': 'country'}},
#  {'id': 6250779816399,
#   'age-gender': {'age_min': 6, 'age_max': 13, 'gender': 'ANY'},
#   'location': {'loc': 'the United States', 'gran': 'country'}},
#  {'id': 6266093459964,
#   'age-gender': {'age_min': 6, 'age_max': 16, 'gender': 'FEMALE'},
#   'location': {'loc': 'the United States', 'gran': 'country'}},
#  {'id': 23849197905360309,
#   'custom': True,
#   'age-gender': {'age_min': 6, 'age_max': 53, 'gender': 'ANY'},
#   'location': {'loc': 'the United States', 'gran': 'country'}},
#  {'id': 23848988683430129,
#   'age-gender': {'age_min': 6, 'age_max': 13, 'gender': 'FEMALE'},
#   'location': {'loc': 'the United States', 'gran': 'country'}},
#  {'id': 6242520792763,
#   'age-gender': {'age_min': 8, 'age_max': 13, 'gender': 'ANY'},
#   'location': {'loc': 'the United States', 'gran': 'country'}},
#  {'id': 23850152383960426,
#   'interests': {'Dog breed', 'Pets'},
#   'age-gender': {'age_min': 6, 'age_max': 53, 'gender': 'ANY'},
#   'location': {'loc': 'the United States', 'gran': 'country'}},
#  {'id': 23849631214930190,
#   'age-gender': {'age_min': 8, 'age_max': 28, 'gender': 'ANY'},
#   'location': {'loc': 'Florida', 'gran': 'region'}},
#  {'id': 6282219300151,
#   'age-gender': {'age_min': 6, 'age_max': 32, 'gender': 'FEMALE'},
#   'location': {'loc': 'the United States', 'gran': 'country'}},
#  {'id': 6256412523536,
#   'custom': True,
#   'age-gender': {'age_min': 6, 'age_max': 53, 'gender': 'ANY'},
#   'location': {'loc': 'the United States', 'gran': 'country'}},
#  {'id': 6288276008464,
#   'age-gender': {'age_min': 6, 'age_max': 53, 'gender': 'ANY'},
#   'location': {'loc': 'the United States', 'gran': 'country'}},
#  {'id': 23848922506790720,
#   'interests': {'Business', 'Web development'},
#   'age-gender': {'age_min': 6, 'age_max': 28, 'gender': 'ANY'},
#   'location': {'loc': 'Florida', 'gran': 'region'}},
#  {'id': 6287387963780,
#   'custom': True,
#   'age-gender': {'age_min': 6, 'age_max': 53, 'gender': 'ANY'},
#   'location': {'loc': 'the United States', 'gran': 'country'}},
#  {'id': 23848735551200788,
#   'age-gender': {'age_min': 1, 'age_max': 53, 'gender': 'ANY'},
#   'location': {'loc': 'the United States', 'gran': 'country'}},
#  {'id': 23850111923920426,
#   'custom': True,
#   'age-gender': {'age_min': 6, 'age_max': 53, 'gender': 'ANY'},
#   'location': {'loc': 'the United States', 'gran': 'country'}},
#  {'id': 23849991672650426,
#   'age-gender': {'age_min': 6, 'age_max': 53, 'gender': 'ANY'},
#   'location': {'loc': 'the United States', 'gran': 'country'}},
#  {'id': 23848287515790627,
#   'age-gender': {'age_min': 6, 'age_max': 52, 'gender': 'FEMALE'},
#   'location': {'loc': 'the United States', 'gran': 'country'}},
#  {'id': 23849582804290333,
#   'age-gender': {'age_min': 6, 'age_max': 22, 'gender': 'FEMALE'},
#   'location': {'loc': 'the United States', 'gran': 'country'}},
#  {'id': 6272261657835,
#   'custom': True,
#   'age-gender': {'age_min': 6, 'age_max': 53, 'gender': 'ANY'},
#   'location': {'loc': 'the United States', 'gran': 'country'}},
#  {'id': 6265196326964,
#   'custom': True,
#   'age-gender': {'age_min': 6, 'age_max': 16, 'gender': 'FEMALE'},
#   'location': {'loc': 'the United States', 'gran': 'country'}},
#  {'id': 23848821119930072,
#   'age-gender': {'age_min': 6, 'age_max': 52, 'gender': 'ANY'},
#   'location': {'loc': 'Florida', 'gran': 'region'}},
#  {'id': 23848857667430599,
#   'interests': {'Activism',
#    'Alternative rock',
#    'Arts and music',
#    'Concerts',
#    'Contemporary R&B',
#    'Fine art',
#    'Online shopping',
#    'Photography',
#    'Pop music',
#    'Shoes',
#    'Shopping and fashion',
#    'Sneakers (footwear)',
#    'Visual arts'},
#   'age-gender': {'age_min': 6, 'age_max': 53, 'gender': 'ANY'},
#   'location': {'loc': 'the United States', 'gran': 'country'}},
#  {'id': 23848910252150682,
#   'custom': True,
#   'age-gender': {'age_min': 6, 'age_max': 53, 'gender': 'ANY'},
#   'location': {'loc': 'the United States', 'gran': 'country'}},
#  {'id': 23848728465490204,
#   'age-gender': {'age_min': 6, 'age_max': 53, 'gender': 'FEMALE'},
#   'location': {'loc': 'the United States', 'gran': 'country'}},
#  {'id': 6250870957529,
#   'custom': True,
#   'age-gender': {'age_min': 6, 'age_max': 53, 'gender': 'ANY'},
#   'location': {'loc': 'the United States', 'gran': 'country'}},
#  {'id': 6282220153751,
#   'age-gender': {'age_min': 6, 'age_max': 32, 'gender': 'FEMALE'},
#   'location': {'loc': 'the United States', 'gran': 'country'}},
#  {'id': 23848904481150097,
#   'custom': True,
#   'age-gender': {'age_min': 6, 'age_max': 53, 'gender': 'ANY'},
#   'location': {'loc': 'the United States', 'gran': 'country'}},
#  {'id': 23850112472810426,
#   'interests': {'Adidas',
#    'Dog breed',
#    'Dog collar',
#    'Dog harness',
#    'Forever 21',
#    'H&M',
#    'Leash',
#    'Old Navy',
#    'Pets'},
#   'age-gender': {'age_min': 6, 'age_max': 53, 'gender': 'ANY'},
#   'location': {'loc': 'the United States', 'gran': 'country'}},
#  {'id': 23847901561410382,
#   'interests': {'BarkBox', 'Dog collar', 'Dog harness', 'Dogs'},
#   'age-gender': {'age_min': 6, 'age_max': 42, 'gender': 'ANY'},
#   'location': {'loc': 'the United States', 'gran': 'country'}},
#  {'id': 6272326047121,
#   'age-gender': {'age_min': 6, 'age_max': 53, 'gender': 'ANY'},
#   'location': {'loc': 'the United States', 'gran': 'country'}},
#  {'id': 6265218550206,
#   'age-gender': {'age_min': 6, 'age_max': 53, 'gender': 'FEMALE'},
#   'location': {'loc': 'the United States', 'gran': 'country'}},
#  {'id': 6269075266372,
#   'age-gender': {'age_min': 6, 'age_max': 53, 'gender': 'ANY'},
#   'location': {'loc': 'the United States', 'gran': 'country'}},
#  {'id': 23848365883570392,
#   'age-gender': {'age_min': 6, 'age_max': 53, 'gender': 'ANY'},
#   'location': {'loc': 'the United States', 'gran': 'country'}},
#  {'id': 6253107086011,
#   'age-gender': {'age_min': 6, 'age_max': 13, 'gender': 'ANY'},
#   'location': {'loc': 'the United States', 'gran': 'country'}},
#  {'id': 23848679458950451,
#   'age-gender': {'age_min': 6, 'age_max': 53, 'gender': 'ANY'},
#   'location': {'loc': 'Gainesville, Florida', 'gran': 'city'}},
#  {'id': 23849152813010713,
#   'age-gender': {'age_min': 6, 'age_max': 53, 'gender': 'ANY'},
#   'location': {'loc': 'the United States', 'gran': 'country'}},
#  {'id': 6285759590809,
#   'age-gender': {'age_min': 8, 'age_max': 43, 'gender': 'ANY'},
#   'location': {'loc': 'the United States', 'gran': 'country'}},
#  {'id': 6248376158730,
#   'interests': {'Adidas', 'H&M'},
#   'age-gender': {'age_min': 6, 'age_max': 53, 'gender': 'ANY'},
#   'location': {'loc': 'the United States', 'gran': 'country'}},
#  {'id': 6257333088827,
#   'age-gender': {'age_min': 6, 'age_max': 53, 'gender': 'ANY'},
#   'location': {'loc': 'the United States', 'gran': 'country'}},
#  {'id': 6257672328387,
#   'interests': {'Online shopping'},
#   'age-gender': {'age_min': 6, 'age_max': 12, 'gender': 'FEMALE'},
#   'location': {'loc': 'the United States', 'gran': 'country'}},
#  {'id': 23848684355290788,
#   'age-gender': {'age_min': 6, 'age_max': 38, 'gender': 'ANY'},
#   'location': {'loc': 'Gainesville, Florida', 'gran': 'city'}},
#  {'id': 6256130036810,
#   'interests': {'Bars',
#    'Cocktail',
#    'Cosmetics',
#    'Costco',
#    'Gift',
#    'Interior design',
#    'Reading',
#    'Social media'},
#   'age-gender': {'age_min': 9, 'age_max': 53, 'gender': 'ANY'},
#   'location': {'loc': 'the United States', 'gran': 'country'}},
#  {'id': 23848632041940296,
#   'custom': True,
#   'age-gender': {'age_min': 6, 'age_max': 53, 'gender': 'FEMALE'},
#   'location': {'loc': 'the United States', 'gran': 'country'}},
#  {'id': 6280814233151,
#   'interests': {'Beauty', 'Health & wellness'},
#   'age-gender': {'age_min': 6, 'age_max': 22, 'gender': 'FEMALE'},
#   'location': {'loc': 'the United States', 'gran': 'country'}},
#  {'id': 23848703045000473,
#   'age-gender': {'age_min': 6, 'age_max': 32, 'gender': 'ANY'},
#   'location': {'loc': 'the United States', 'gran': 'country'}},
#  {'id': 23849609077780540,
#   'age-gender': {'age_min': 6, 'age_max': 32, 'gender': 'ANY'},
#   'location': {'loc': 'the United States', 'gran': 'country'}},
#  {'id': 23848821336050057,
#   'custom': True,
#   'age-gender': {'age_min': 6, 'age_max': 53, 'gender': 'ANY'},
#   'location': {'loc': 'the United States', 'gran': 'country'}},
#  {'id': 23849892899110342,
#   'custom': True,
#   'age-gender': {'age_min': 6, 'age_max': 53, 'gender': 'ANY'},
#   'location': {'loc': 'the United States', 'gran': 'country'}},
#  {'id': 6282218489751,
#   'age-gender': {'age_min': 6, 'age_max': 32, 'gender': 'FEMALE'},
#   'location': {'loc': 'the United States', 'gran': 'country'}},
#  {'id': 23849180781090600,
#   'custom': True,
#   'age-gender': {'age_min': 6, 'age_max': 53, 'gender': 'ANY'},
#   'location': {'loc': 'the United States', 'gran': 'country'}},
#  {'id': 23848279226930627,
#   'custom': True,
#   'age-gender': {'age_min': 6, 'age_max': 52, 'gender': 'FEMALE'},
#   'location': {'loc': 'the United States', 'gran': 'country'}},
#  {'id': 23848665545260529,
#   'age-gender': {'age_min': 6, 'age_max': 53, 'gender': 'ANY'},
#   'location': {'loc': 'the United States', 'gran': 'country'}},
#  {'id': 23848622661740598,
#   'age-gender': {'age_min': 6, 'age_max': 52, 'gender': 'ANY'},
#   'location': {'loc': 'Gainesville, Florida', 'gran': 'city'}},
#  {'id': 6287049659774,
#   'age-gender': {'age_min': 6, 'age_max': 53, 'gender': 'ANY'},
#   'location': {'loc': 'the United States', 'gran': 'country'}},
#  {'id': 6259011901429,
#   'custom': True,
#   'age-gender': {'age_min': 6, 'age_max': 53, 'gender': 'ANY'},
#   'location': {'loc': 'the United States', 'gran': 'country'}},
#  {'id': 23848904496770097,
#   'custom': True,
#   'age-gender': {'age_min': 6, 'age_max': 53, 'gender': 'ANY'},
#   'location': {'loc': 'the United States', 'gran': 'country'}},
#  {'id': 23849825129350342,
#   'custom': True,
#   'age-gender': {'age_min': 6, 'age_max': 53, 'gender': 'ANY'},
#   'location': {'loc': 'the United States', 'gran': 'country'}},
#  {'id': 23848819237160231,
#   'age-gender': {'age_min': 6, 'age_max': 53, 'gender': 'ANY'},
#   'location': {'loc': 'the United States', 'gran': 'country'}},
#  {'id': 23849619139410333,
#   'age-gender': {'age_min': 6, 'age_max': 22, 'gender': 'FEMALE'},
#   'location': {'loc': 'the United States', 'gran': 'country'}},
#  {'id': 23849872006870342,
#   'custom': True,
#   'age-gender': {'age_min': 6, 'age_max': 53, 'gender': 'ANY'},
#   'location': {'loc': 'the United States', 'gran': 'country'}},
#  {'id': 6276453931566,
#   'custom': True,
#   'age-gender': {'age_min': 6, 'age_max': 53, 'gender': 'FEMALE'},
#   'location': {'loc': 'the United States', 'gran': 'country'}},
#  {'id': 23849340500960233,
#   'interests': {'Gift'},
#   'age-gender': {'age_min': 6, 'age_max': 53, 'gender': 'FEMALE'},
#   'location': {'loc': 'the United States', 'gran': 'country'}},
#  {'id': 23848582710780466,
#   'age-gender': {'age_min': 6, 'age_max': 53, 'gender': 'ANY'},
#   'location': {'loc': 'the United States', 'gran': 'country'}},
#  {'id': 23848702957510451,
#   'age-gender': {'age_min': 8, 'age_max': 38, 'gender': 'ANY'},
#   'location': {'loc': 'Florida', 'gran': 'region'}},
#  {'id': 6260238820381,
#   'age-gender': {'age_min': 9, 'age_max': 53, 'gender': 'ANY'},
#   'location': {'loc': 'Florida', 'gran': 'region'}},
#  {'id': 23849743683090342,
#   'age-gender': {'age_min': 6, 'age_max': 53, 'gender': 'ANY'},
#   'location': {'loc': 'the United States', 'gran': 'country'}},
#  {'id': 23849729033990459,
#   'age-gender': {'age_min': 6, 'age_max': 53, 'gender': 'FEMALE'},
#   'location': {'loc': 'the United States', 'gran': 'country'}},
#  {'id': 23849194305820181,
#   'age-gender': {'age_min': 6, 'age_max': 53, 'gender': 'ANY'},
#   'location': {'loc': 'the United States', 'gran': 'country'}},
#  {'id': 23848774254690788,
#   'age-gender': {'age_min': 1, 'age_max': 53, 'gender': 'ANY'},
#   'location': {'loc': 'the United States', 'gran': 'country'}},
#  {'id': 23849127356540148,
#   'interests': {'Laboratory'},
#   'age-gender': {'age_min': 9, 'age_max': 42, 'gender': 'ANY'},
#   'location': {'loc': 'the United States', 'gran': 'country'}},
#  {'id': 6258183705187,
#   'interests': {'Shopping and fashion'},
#   'age-gender': {'age_min': 6, 'age_max': 12, 'gender': 'FEMALE'},
#   'location': {'loc': 'the United States', 'gran': 'country'}},
#  {'id': 23849745299210331,
#   'age-gender': {'age_min': 6, 'age_max': 53, 'gender': 'ANY'},
#   'location': {'loc': 'the United States', 'gran': 'country'}},
#  {'id': 23848550498030261,
#   'age-gender': {'age_min': 6, 'age_max': 53, 'gender': 'ANY'},
#   'location': {'loc': 'the United States', 'gran': 'country'}},
#  {'id': 6242765307776,
#   'age-gender': {'age_min': 9, 'age_max': 53, 'gender': 'ANY'},
#   'location': {'loc': 'Texas', 'gran': 'region'}},
#  {'id': 23849321864750411,
#   'age-gender': {'age_min': 6, 'age_max': 53, 'gender': 'ANY'},
#   'location': {'loc': 'the United States', 'gran': 'country'}},
#  {'id': 23848426884750526,
#   'interests': {'Higher education', 'Medicine'},
#   'age-gender': {'age_min': 6, 'age_max': 12, 'gender': 'ANY'},
#   'location': {'loc': 'the United States', 'gran': 'country'}},
#  {'id': 6245979231546,
#   'age-gender': {'age_min': 6, 'age_max': 53, 'gender': 'ANY'},
#   'location': {'loc': 'the United States', 'gran': 'country'}},
#  {'id': 6247887450530,
#   'interests': {'Black Friday (shopping)',
#    'Coupons',
#    'Cyber Monday',
#    'Gift',
#    'Sales promotion'},
#   'age-gender': {'age_min': 8, 'age_max': 53, 'gender': 'ANY'},
#   'location': {'loc': 'the United States', 'gran': 'country'}},
#  {'id': 6285759506809,
#   'age-gender': {'age_min': 8, 'age_max': 43, 'gender': 'ANY'},
#   'location': {'loc': 'the United States', 'gran': 'country'}},
#  {'id': 23848305084330724,
#   'age-gender': {'age_min': 6, 'age_max': 53, 'gender': 'ANY'},
#   'location': {'loc': 'the United States', 'gran': 'country'}},
#  {'id': 23848797502640085,
#   'age-gender': {'age_min': 6, 'age_max': 53, 'gender': 'ANY'},
#   'location': {'loc': 'the United States', 'gran': 'country'}},
#  {'id': 6258183705787,
#   'interests': {'Food and drink'},
#   'age-gender': {'age_min': 6, 'age_max': 12, 'gender': 'FEMALE'},
#   'location': {'loc': 'the United States', 'gran': 'country'}},
#  {'id': 23849619140980333,
#   'age-gender': {'age_min': 6, 'age_max': 22, 'gender': 'FEMALE'},
#   'location': {'loc': 'the United States', 'gran': 'country'}},
#  {'id': 23849821125620543,
#   'age-gender': {'age_min': 6, 'age_max': 53, 'gender': 'FEMALE'},
#   'location': {'loc': 'the United States', 'gran': 'country'}},
#  {'id': 23848488424660724,
#   'age-gender': {'age_min': 6, 'age_max': 22, 'gender': 'ANY'},
#   'location': {'loc': 'the United States', 'gran': 'country'}},
#  {'id': 6269262481586,
#   'interests': {'Movies'},
#   'age-gender': {'age_min': 6, 'age_max': 53, 'gender': 'ANY'},
#   'location': {'loc': 'the United States', 'gran': 'country'}},
#  {'id': 23848743409840170,
#   'age-gender': {'age_min': 6, 'age_max': 53, 'gender': 'ANY'},
#   'location': {'loc': 'the United States', 'gran': 'country'}},
#  {'id': 23849743673050342,
#   'custom': True,
#   'age-gender': {'age_min': 6, 'age_max': 53, 'gender': 'ANY'},
#   'location': {'loc': 'the United States', 'gran': 'country'}},
#  {'id': 23849455794600190,
#   'age-gender': {'age_min': 8, 'age_max': 28, 'gender': 'ANY'},
#   'location': {'loc': 'Florida', 'gran': 'region'}},
#  {'id': 23849375947070411,
#   'age-gender': {'age_min': 6, 'age_max': 53, 'gender': 'ANY'},
#   'location': {'loc': 'the United States', 'gran': 'country'}},
#  {'id': 6255717073752,
#   'custom': True,
#   'age-gender': {'age_min': 6, 'age_max': 53, 'gender': 'ANY'},
#   'location': {'loc': 'the United States', 'gran': 'country'}},
#  {'id': 23849631234030190,
#   'custom': True,
#   'age-gender': {'age_min': 8, 'age_max': 28, 'gender': 'ANY'},
#   'location': {'loc': 'Florida', 'gran': 'region'}},
#  {'id': 23849350944360391,
#   'age-gender': {'age_min': 8, 'age_max': 43, 'gender': 'FEMALE'},
#   'location': {'loc': 'the United States', 'gran': 'country'}},
#  {'id': 23849172822750686,
#   'custom': True,
#   'age-gender': {'age_min': 8, 'age_max': 53, 'gender': 'FEMALE'},
#   'location': {'loc': 'the United States', 'gran': 'country'}},
#  {'id': 23848904496760097,
#   'age-gender': {'age_min': 6, 'age_max': 53, 'gender': 'ANY'},
#   'location': {'loc': 'the United States', 'gran': 'country'}},
#  {'id': 23849213227450391,
#   'interests': {'Adidas'},
#   'age-gender': {'age_min': 8, 'age_max': 43, 'gender': 'ANY'},
#   'location': {'loc': 'the United States', 'gran': 'country'}},
#  {'id': 23848612917190352,
#   'custom': True,
#   'age-gender': {'age_min': 6, 'age_max': 23, 'gender': 'FEMALE'},
#   'location': {'loc': 'the United States', 'gran': 'country'}},
#  {'id': 6239703011935,
#   'custom': True,
#   'age-gender': {'age_min': 6, 'age_max': 53, 'gender': 'ANY'},
#   'location': {'loc': 'the United States', 'gran': 'country'}},
#  {'id': 23850169925590426,
#   'interests': {'Adidas',
#    'Dog breed',
#    'Dog collar',
#    'Dog harness',
#    'Forever 21',
#    'H&M',
#    'Leash',
#    'Old Navy',
#    'Pets'},
#   'age-gender': {'age_min': 6, 'age_max': 53, 'gender': 'ANY'},
#   'location': {'loc': 'the United States', 'gran': 'country'}},
#  {'id': 6249134669705,
#   'custom': True,
#   'age-gender': {'age_min': 6, 'age_max': 53, 'gender': 'ANY'},
#   'location': {'loc': 'the United States', 'gran': 'country'}},
#  {'id': 6265168305544,
#   'age-gender': {'age_min': 6, 'age_max': 31, 'gender': 'FEMALE'},
#   'location': {'loc': 'Florida', 'gran': 'region'}},
#  {'id': 6255513115946,
#   'age-gender': {'age_min': 6, 'age_max': 53, 'gender': 'ANY'},
#   'location': {'loc': 'the United States', 'gran': 'country'}},
#  {'id': 6243732414821,
#   'custom': True,
#   'age-gender': {'age_min': 6, 'age_max': 53, 'gender': 'ANY'},
#   'location': {'loc': 'the United States', 'gran': 'country'}},
#  {'id': 23848943129390544,
#   'age-gender': {'age_min': 6, 'age_max': 53, 'gender': 'ANY'},
#   'location': {'loc': 'the United States', 'gran': 'country'}},
#  {'id': 23849748242690568,
#   'interests': {'H&M', 'Nordstrom'},
#   'age-gender': {'age_min': 6, 'age_max': 53, 'gender': 'ANY'},
#   'location': {'loc': 'the United States', 'gran': 'country'}},
#  {'id': 23849715862640342,
#   'custom': True,
#   'age-gender': {'age_min': 6, 'age_max': 53, 'gender': 'ANY'},
#   'location': {'loc': 'the United States', 'gran': 'country'}},
#  {'id': 23849401161770103,
#   'interests': {'Dogs'},
#   'age-gender': {'age_min': 6, 'age_max': 53, 'gender': 'ANY'},
#   'location': {'loc': 'the United States', 'gran': 'country'}},
#  {'id': 23850112470690426,
#   'interests': {'Adidas',
#    'Dog breed',
#    'Dog collar',
#    'Dog harness',
#    'Forever 21',
#    'H&M',
#    'Leash',
#    'Old Navy',
#    'Pets'},
#   'age-gender': {'age_min': 6, 'age_max': 53, 'gender': 'ANY'},
#   'location': {'loc': 'the United States', 'gran': 'country'}},
#  {'id': 23848804454030620,
#   'age-gender': {'age_min': 6, 'age_max': 53, 'gender': 'ANY'},
#   'location': {'loc': 'the United States', 'gran': 'country'}},
#  {'id': 23849270881600297,
#   'interests': {'Chick-fil-A', 'Delivery order', "Wendy's"},
#   'age-gender': {'age_min': 6, 'age_max': 53, 'gender': 'ANY'},
#   'location': {'loc': 'the United States', 'gran': 'country'}},
#  {'id': 23849804602430543,
#   'age-gender': {'age_min': 6, 'age_max': 53, 'gender': 'FEMALE'},
#   'location': {'loc': 'the United States', 'gran': 'country'}},
#  {'id': 23849871977710342,
#   'custom': True,
#   'age-gender': {'age_min': 6, 'age_max': 53, 'gender': 'ANY'},
#   'location': {'loc': 'the United States', 'gran': 'country'}},
#  {'id': 23848270963450328,
#   'age-gender': {'age_min': 6, 'age_max': 53, 'gender': 'ANY'},
#   'location': {'loc': 'the United States', 'gran': 'country'}},
#  {'id': 6245287798067,
#   'age-gender': {'age_min': 8, 'age_max': 28, 'gender': 'FEMALE'},
#   'location': {'loc': 'the United States', 'gran': 'country'}},
#  {'id': 23847954764010571,
#   'age-gender': {'age_min': 7, 'age_max': 14, 'gender': 'ANY'},
#   'location': {'loc': 'the United States', 'gran': 'country'}},
#  {'id': 6257347986995,
#   'age-gender': {'age_min': 6, 'age_max': 53, 'gender': 'ANY'},
#   'location': {'loc': 'the United States', 'gran': 'country'}},
#  {'id': 23849340502650233,
#   'interests': {'Gift'},
#   'age-gender': {'age_min': 6, 'age_max': 53, 'gender': 'FEMALE'},
#   'location': {'loc': 'the United States', 'gran': 'country'}},
#  {'id': 6245287798067,
#   'age-gender': {'age_min': 8, 'age_max': 28, 'gender': 'FEMALE'},
#   'location': {'loc': 'the United States', 'gran': 'country'}},
#  {'id': 6246248219654,
#   'custom': True,
#   'age-gender': {'age_min': 6, 'age_max': 53, 'gender': 'ANY'},
#   'location': {'loc': 'the United States', 'gran': 'country'}},
#  {'id': 6248826559203,
#   'interests': {'University of Florida'},
#   'age-gender': {'age_min': 9, 'age_max': 48, 'gender': 'FEMALE'},
#   'location': {'loc': 'the United States', 'gran': 'country'}},
#  {'id': 6255514102346,
#   'age-gender': {'age_min': 6, 'age_max': 53, 'gender': 'ANY'},
#   'location': {'loc': 'the United States', 'gran': 'country'}},
#  {'id': 6259926795787,
#   'interests': {'Hobbies and activities'},
#   'age-gender': {'age_min': 6, 'age_max': 22, 'gender': 'FEMALE'},
#   'location': {'loc': 'the United States', 'gran': 'country'}},
#  {'id': 6260748892387,
#   'interests': {'Shopping and fashion'},
#   'age-gender': {'age_min': 6, 'age_max': 12, 'gender': 'FEMALE'},
#   'location': {'loc': 'the United States', 'gran': 'country'}},
#  {'id': 6262315314742,
#   'custom': True,
#   'age-gender': {'age_min': 6, 'age_max': 53, 'gender': 'ANY'},
#   'location': {'loc': 'the United States', 'gran': 'country'}},
#  {'id': 6264251193629,
#   'custom': True,
#   'age-gender': {'age_min': 6, 'age_max': 53, 'gender': 'ANY'},
#   'location': {'loc': 'the United States', 'gran': 'country'}},
#  {'id': 6265594210769,
#   'custom': True,
#   'interests': {'Dog breed', 'Dogs'},
#   'age-gender': {'age_min': 9, 'age_max': 53, 'gender': 'ANY'},
#   'location': {'loc': 'the United States', 'gran': 'country'}},
#  {'id': 6267666093542,
#   'custom': True,
#   'age-gender': {'age_min': 6, 'age_max': 53, 'gender': 'ANY'},
#   'location': {'loc': 'the United States', 'gran': 'country'}},
#  {'id': 6275061723968,
#   'age-gender': {'age_min': 6, 'age_max': 53, 'gender': 'FEMALE'}},
#  {'id': 6277604594719,
#   'interests': {'Engagement ring'},
#   'age-gender': {'age_min': 6, 'age_max': 33, 'gender': 'ANY'},
#   'location': {'loc': 'the United States', 'gran': 'country'}},
#  {'id': 23848774012540481,
#   'interests': {'Streetwear'},
#   'age-gender': {'age_min': 6, 'age_max': 53, 'gender': 'ANY'},
#   'location': {'loc': 'the United States', 'gran': 'country'}},
#  {'id': 23848792657430600,
#   'age-gender': {'age_min': 6, 'age_max': 53, 'gender': 'ANY'},
#   'location': {'loc': 'the United States', 'gran': 'country'}},
#  {'id': 23848936267270045,
#   'custom': True,
#   'age-gender': {'age_min': 6, 'age_max': 53, 'gender': 'ANY'},
#   'location': {'loc': 'the United States', 'gran': 'country'}},
#  {'id': 23848938165720633,
#   'age-gender': {'age_min': 6, 'age_max': 53, 'gender': 'ANY'},
#   'location': {'loc': 'the United States', 'gran': 'country'}},
#  {'id': 23849059462440064,
#   'age-gender': {'age_min': 6, 'age_max': 53, 'gender': 'ANY'},
#   'location': {'loc': 'the United States', 'gran': 'country'}},
#  {'id': 23849151450580606,
#   'custom': True,
#   'age-gender': {'age_min': 6, 'age_max': 53, 'gender': 'ANY'},
#   'location': {'loc': 'the United States', 'gran': 'country'}},
#  {'id': 23849164934200600,
#   'custom': True,
#   'age-gender': {'age_min': 6, 'age_max': 53, 'gender': 'ANY'},
#   'location': {'loc': 'the United States', 'gran': 'country'}},
#  {'id': 23849178994590365,
#   'custom': True,
#   'age-gender': {'age_min': 6, 'age_max': 53, 'gender': 'ANY'},
#   'location': {'loc': 'the United States', 'gran': 'country'}},
#  {'id': 23849255470690057,
#   'custom': True,
#   'age-gender': {'age_min': 6, 'age_max': 42, 'gender': 'FEMALE'},
#   'location': {'loc': 'the United States', 'gran': 'country'}},
#  {'id': 23849260644100606,
#   'custom': True,
#   'age-gender': {'age_min': 6, 'age_max': 53, 'gender': 'ANY'},
#   'location': {'loc': 'the United States', 'gran': 'country'}},
#  {'id': 23849277116650057,
#   'custom': True,
#   'age-gender': {'age_min': 6, 'age_max': 53, 'gender': 'ANY'},
#   'location': {'loc': 'the United States', 'gran': 'country'}},
#  {'id': 23849335663700633,
#   'custom': True,
#   'age-gender': {'age_min': 6, 'age_max': 53, 'gender': 'ANY'},
#   'location': {'loc': 'the United States', 'gran': 'country'}},
#  {'id': 23849775651870342,
#   'custom': True,
#   'age-gender': {'age_min': 6, 'age_max': 53, 'gender': 'ANY'},
#   'location': {'loc': 'the United States', 'gran': 'country'}},
#  {'id': 23849836940410333,
#   'age-gender': {'age_min': 6, 'age_max': 22, 'gender': 'FEMALE'},
#   'location': {'loc': 'the United States', 'gran': 'country'}},
#  {'id': 23850030764040342,
#   'age-gender': {'age_min': 6, 'age_max': 53, 'gender': 'ANY'},
#   'location': {'loc': 'the United States', 'gran': 'country'}},
#  {'id': 23850030876850342,
#   'custom': True,
#   'age-gender': {'age_min': 6, 'age_max': 53, 'gender': 'ANY'},
#   'location': {'loc': 'the United States', 'gran': 'country'}},
#  {'id': 23850169392740342,
#   'age-gender': {'age_min': 6, 'age_max': 53, 'gender': 'ANY'},
#   'location': {'loc': 'the United States', 'gran': 'country'}},
#  {'id': 23850442067940426,
#   'age-gender': {'age_min': 6, 'age_max': 53, 'gender': 'ANY'},
#   'location': {'loc': 'the United States', 'gran': 'country'}},
#  {'id': 23846983001210102,
#   'interests': {'Engagement', 'Weddings'},
#   'age-gender': {'age_min': 6, 'age_max': 38, 'gender': 'FEMALE'},
#   'location': {'loc': 'the United States', 'gran': 'country'}},
#  {'id': 23849335663700633,
#   'custom': True,
#   'age-gender': {'age_min': 6, 'age_max': 53, 'gender': 'ANY'},
#   'location': {'loc': 'the United States', 'gran': 'country'}},
#  {'id': 23849836940170333,
#   'age-gender': {'age_min': 6, 'age_max': 22, 'gender': 'FEMALE'},
#   'location': {'loc': 'the United States', 'gran': 'country'}},
#  {'id': 23849957764080195,
#   'interests': {'Nordstrom Rack'},
#   'age-gender': {'age_min': 8, 'age_max': 33, 'gender': 'FEMALE'},
#   'location': {'loc': 'the United States', 'gran': 'country'}}]

# %%
# helpers to pull out info from targeting dict
tar_interest = lambda uid: sum([1 for t in user_targetings[uid] if 'interests'in t])
tar_custom = lambda uid: sum([1 for t in user_targetings[uid] if 'custom' in t])

# %%
from math import sqrt

def normal_bin_conf(p, n, alpha=.95):
    tab = {0.90: 1.645, 0.95: 1.96, 0.99: 2.58}
    z = tab[alpha]
    # binomial proportion confidence interval
    return z * sqrt((p * (1-p))/n)

# %% [markdown]
# ### Targeting Differences by User/Participant

# %%
# PLOTTING USER LEVEL STACKED BAR PLOT
custom_total, generic_total, interest_total = 0, 0, 0
f, axs = plt.subplots(1, 1, figsize=(15, 6))
colors = ['tab:blue', 'tab:orange', 'tab:red']
labels = ['Generic', 'Interest', 'Custom']

interest_fracs, custom_fracs, total_fracs = [], [], []
part_ad_counts = pid_adid.groupby('pid').count().to_dict()['adid']
last = np.zeros(len(survey1_pids))
part_order = sorted(survey1_pids, key=lambda pid: part_code_props[pid].get('Benign', 0), reverse=True)
# exclude participants with < 25 ads
part_order = [p for p in part_order if part_ad_counts[p] >= 25]

for i, uid in enumerate(part_order):
    total = pid_adid[pid_adid['pid'] == uid].shape[0]
    interest_targeted = tar_interest(uid)
    custom = tar_custom(uid)
    generic = total - interest_targeted - custom
    interest_total += interest_targeted; custom_total += custom; generic_total += generic
    
    # convert to fractions
    interest_targeted /= total; custom /= total; generic /= total    
    
#     err = [normal_bin_conf(curr[i], totals[p]) if (totals[p]*curr[i]) >= 5 else 0 \
#         for i, p in enumerate(hor_order)]
    last = 0
    for j, frac in enumerate([generic, interest_targeted, custom]):
        err = normal_bin_conf(frac, total)
        err = None
        axs.bar([i], [frac], .5, bottom=last, ecolor=colors[j],
                  color=colors[j], alpha=.8, yerr=err, label=labels[j])
        labels[j] = ''
        last += frac
        
axs.legend()
axs.set_ylim(top=1.02)
axs.grid(ls=':', axis='y')
axs.set_ylabel('Fraction of ad targeting')
axs.set_xlabel('Participant')

# plt.savefig('targeting-differences-user.jpg', dpi=200, bbox_inches='tight')
# Out:
# Text(0.5, 0, 'Participant')

# %% [markdown]
# ### Targeting Differences by Code

# %%
# unpack by code
code_ads = find_code_ads(dict(codes[['adid', 'codes']].values))

# %%
plot_codes = ['Benign', 'Healthcare', 'Opportunity', 'Clickbait', 'Financial',
              'Potentially Harmful', 'Potentially Prohibited']
f, axs = plt.subplots(1, 2, figsize=(15, 6))

labels = ['Generic', 'Interest', 'Custom']
for i, c in enumerate(plot_codes):    
    n_interest, n_custom, n_generic = 0, 0, 0
#     if c == 'Harmful':
#         total = len(code_ads['Potentially Prohibited']) + len(code_ads['Potentially Harmful'])
#         curr_code_ads = code_ads['Potentially Prohibited'] + code_ads['Potentially Harmful']
#     else:
    total = len(code_ads[c])
    curr_code_ads = code_ads[c]        
        
    for aid in curr_code_ads:
        # preprocess targeting json
        tar = get_targeting(ad_targetings[str(aid)], aid)
        if 'interests' in tar:
            n_interest += 1
        if 'custom' in tar:
            n_custom += 1

    n_generic = total - n_interest - n_custom
            
    # counts on left plot
    last = 0
    for j, count in enumerate([n_generic, n_interest, n_custom]):
        axs[0].bar([i], [count], .5, bottom=last, ecolor=colors[j],
                  color=colors[j], alpha=.8, yerr=err, label=labels[j])
        labels[j] = ''
        last += count

    # fractions on right plot
    last = 0
    for j, frac in enumerate([n_generic/total, n_interest/total, n_custom/total]):
        err = normal_bin_conf(frac, total)
        axs[1].bar([i], [frac], .5, bottom=last, ecolor=colors[j],
                  color=colors[j], alpha=.8, yerr=err)
        
        last += frac
      
axs[0].legend()
axs[0].set_ylabel('Count of targetings')
axs[1].set_ylabel('Fraction of targetings')
axs[1].set_ylim(top=1.02)
for ax in axs:
    ax.grid(ls=':', axis='y')
    ax.set_xticks(range(len(plot_codes)))
    ax.set_xticklabels(plot_codes, rotation=45)
    
# plt.savefig('targeting-differences-code-2.jpg', dpi=200, bbox_inches='tight')

# %%
codes[codes['codes'].str.contains('Potentially Harmful')]
# .iloc[:20]
# Out:
#                     adid                                      codes
# 3206       6275513875993              Potentially Harmful;Sensitive
# 3417   23847356524530423              Clickbait;Potentially Harmful
# 3551   23848503752320581                        Potentially Harmful
# 3750   23848723144570407              Clickbait;Potentially Harmful
# 5054   23849772514710031              Clickbait;Potentially Harmful
# ...                  ...                                        ...
# 18288  23849914265270272              Clickbait;Potentially Harmful
# 18425  23850095311930681  Clickbait;Opportunity;Potentially Harmful
# 18535  23850342785410369             Healthcare;Potentially Harmful
# 18545  23850377862010090              Clickbait;Potentially Harmful
# 18550  23850391699480771              Clickbait;Potentially Harmful
#
# [167 rows x 2 columns]
